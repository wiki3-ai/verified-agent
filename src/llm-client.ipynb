# %% [raw]
# ; LLM Client -- HTTP client for LLM API calls
# ;
# ; Copyright (C) 2025
# ;
# ; License: See LICENSE file
# ;
# ; Author: AI Assistant with human guidance
# ;
# ; This book provides a verified LLM client using properly-guarded HTTP JSON
# ; functions. All guards are maintained for formal verification.

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(in-package "ACL2")
# Out:
#  "ACL2"

# %%
(include-book "llm-types")
(include-book "http-json" 
              :ttags ((:quicklisp) (:quicklisp.dexador) (:http-json)))
(include-book "std/strings/explode-nonnegative-integer" :dir :system)
(include-book "kestrel/json-parser/parse-json" :dir :system)
; (depends-on "llm-client-raw.lsp")
# Out:
# Summary
# Form:  ( INCLUDE-BOOK "llm-types" ...)
# Rules: NIL
# Time:  0.45 seconds (prove: 0.00, print: 0.00, other: 0.45)
#  "/workspaces/verified-agent/src/llm-types.lisp"
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP from book /home/acl2/books/quicklisp/base.
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP.DEXADOR from book /home/acl2/books/quicklisp/dexador.
#
# TTAG NOTE (for included book): Adding ttag :HTTP-JSON from book /workspaces/verified-agent/src/http-json.
#
# Summary
# Form:  ( INCLUDE-BOOK "http-json" ...)
# Rules: NIL
# Time:  0.28 seconds (prove: 0.00, print: 0.00, other: 0.28)
#  "/workspaces/verified-agent/src/http-json.lisp"
#
# Summary
# Form:  ( INCLUDE-BOOK "std/strings/explode-nonnegative-integer" ...)
# Rules: NIL
# Time:  0.05 seconds (prove: 0.00, print: 0.00, other: 0.05)
#  "/home/acl2/books/std/strings/explode-nonnegative-integer.lisp"
#
# Summary
# Form:  ( INCLUDE-BOOK "kestrel/json-parser/parse-json" ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
#  "/home/acl2/books/kestrel/json-parser/parse-json.lisp"

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Configuration
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; LM Studio (local) endpoints
(defconst *lm-studio-endpoint* 
  "http://host.docker.internal:1234/v1/chat/completions")
# Out:
# Summary
# Form:  ( DEFCONST *LM-STUDIO-ENDPOINT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LM-STUDIO-ENDPOINT*

# %%
;; OpenAI-compatible models endpoint (basic info only)
(defconst *lm-studio-models-endpoint*
  "http://host.docker.internal:1234/v1/models")
# Out:
# Summary
# Form:  ( DEFCONST *LM-STUDIO-MODELS-ENDPOINT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LM-STUDIO-MODELS-ENDPOINT*

# %%
;; LM Studio native API (full model info with type, state, context length)
(defconst *lm-studio-v0-models-endpoint*
  "http://host.docker.internal:1234/api/v0/models")
# Out:
# Summary
# Form:  ( DEFCONST *LM-STUDIO-V0-MODELS-ENDPOINT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LM-STUDIO-V0-MODELS-ENDPOINT*

# %%
;; OpenAI cloud endpoints
(defconst *openai-endpoint*
  "https://api.openai.com/v1/chat/completions")
# Out:
# Summary
# Form:  ( DEFCONST *OPENAI-ENDPOINT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *OPENAI-ENDPOINT*

# %%
(defconst *openai-completions-endpoint*
  "https://api.openai.com/v1/completions")
# Out:
# Summary
# Form:  ( DEFCONST *OPENAI-COMPLETIONS-ENDPOINT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *OPENAI-COMPLETIONS-ENDPOINT*

# %%
(defconst *openai-models-endpoint*
  "https://api.openai.com/v1/models")
# Out:
# Summary
# Form:  ( DEFCONST *OPENAI-MODELS-ENDPOINT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *OPENAI-MODELS-ENDPOINT*

# %%
(defconst *llm-connect-timeout* 30)   ; seconds
(defconst *llm-read-timeout* 120)     ; seconds (higher for slow local models)
# Out:
# Summary
# Form:  ( DEFCONST *LLM-CONNECT-TIMEOUT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LLM-CONNECT-TIMEOUT*
#
# Summary
# Form:  ( DEFCONST *LLM-READ-TIMEOUT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LLM-READ-TIMEOUT*

# %%
;; Default provider configs (for convenience)
(defconst *local-provider-config*
  (make-llm-provider-config
   :provider (llm-provider-local)
   :endpoint *lm-studio-endpoint*
   :api-key ""
   :model ""
   :org-id ""))
# Out:
# Summary
# Form:  ( DEFCONST *LOCAL-PROVIDER-CONFIG* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LOCAL-PROVIDER-CONFIG*

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; JSON Serialization Helpers
# ;;
# ;; Logical specifications - raw Lisp provides actual implementation.
# ;; These maintain proper guards (stringp returns).
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Serialize a single chat message to JSON object string
;; Input: chat-message-p
;; Output: stringp like {"role":"user","content":"hello"}
(defun serialize-chat-message (msg)
  (declare (xargs :guard (chat-message-p msg))
           (ignore msg))
  (prog2$ (er hard? 'serialize-chat-message "Raw Lisp definition not installed?")
          "{}"))
# Out:
# Since SERIALIZE-CHAT-MESSAGE is non-recursive, its admission is trivial.
# We observe that the type of SERIALIZE-CHAT-MESSAGE is described by
# the theorem (STRINGP (SERIALIZE-CHAT-MESSAGE MSG)).
#
# Computing the guard conjecture for SERIALIZE-CHAT-MESSAGE....
#
# The guard conjecture for SERIALIZE-CHAT-MESSAGE is trivial to prove.
# SERIALIZE-CHAT-MESSAGE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SERIALIZE-CHAT-MESSAGE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  SERIALIZE-CHAT-MESSAGE

# %%
(defthm stringp-of-serialize-chat-message
  (stringp (serialize-chat-message msg)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-MESSAGE
# ...):  A :REWRITE rule generated from STRINGP-OF-SERIALIZE-CHAT-MESSAGE
# will be triggered only by terms containing the function symbol
# SERIALIZE-CHAT-MESSAGE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-SERIALIZE-CHAT-MESSAGE depends upon the :type-
# prescription rule SERIALIZE-CHAT-MESSAGE.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-MESSAGE ...)
# Rules: ((:TYPE-PRESCRIPTION SERIALIZE-CHAT-MESSAGE))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-SERIALIZE-CHAT-MESSAGE

# %%
;; Serialize a list of chat messages to JSON array string
;; Input: chat-message-list-p
;; Output: stringp like [{"role":"user","content":"hello"}]
(defun serialize-chat-messages (messages)
  (declare (xargs :guard (chat-message-list-p messages))
           (ignore messages))
  (prog2$ (er hard? 'serialize-chat-messages "Raw Lisp definition not installed?")
          "[]"))
# Out:
# Since SERIALIZE-CHAT-MESSAGES is non-recursive, its admission is trivial.
# We observe that the type of SERIALIZE-CHAT-MESSAGES is described by
# the theorem (STRINGP (SERIALIZE-CHAT-MESSAGES MESSAGES)).
#
# Computing the guard conjecture for SERIALIZE-CHAT-MESSAGES....
#
# The guard conjecture for SERIALIZE-CHAT-MESSAGES is trivial to prove.
# SERIALIZE-CHAT-MESSAGES is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SERIALIZE-CHAT-MESSAGES ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  SERIALIZE-CHAT-MESSAGES

# %%
(defthm stringp-of-serialize-chat-messages
  (stringp (serialize-chat-messages messages)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-MESSAGES
# ...):  A :REWRITE rule generated from STRINGP-OF-SERIALIZE-CHAT-MESSAGES
# will be triggered only by terms containing the function symbol
# SERIALIZE-CHAT-MESSAGES, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-SERIALIZE-CHAT-MESSAGES depends upon the
# :type-prescription rule SERIALIZE-CHAT-MESSAGES.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-MESSAGES ...)
# Rules: ((:TYPE-PRESCRIPTION SERIALIZE-CHAT-MESSAGES))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-SERIALIZE-CHAT-MESSAGES

# %%
;; Serialize full chat completion request to JSON string
;; Input: model (stringp), messages (chat-message-list-p)
;; Output: stringp like {"model":"...","messages":[...]}
(defun serialize-chat-request (model messages)
  (declare (xargs :guard (and (stringp model) (chat-message-list-p messages)))
           (ignore model messages))
  (prog2$ (er hard? 'serialize-chat-request "Raw Lisp definition not installed?")
          "{}"))
# Out:
# Since SERIALIZE-CHAT-REQUEST is non-recursive, its admission is trivial.
# We observe that the type of SERIALIZE-CHAT-REQUEST is described by
# the theorem (STRINGP (SERIALIZE-CHAT-REQUEST MODEL MESSAGES)).
#
# Computing the guard conjecture for SERIALIZE-CHAT-REQUEST....
#
# The guard conjecture for SERIALIZE-CHAT-REQUEST is trivial to prove.
# SERIALIZE-CHAT-REQUEST is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SERIALIZE-CHAT-REQUEST ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  SERIALIZE-CHAT-REQUEST

# %%
(defthm stringp-of-serialize-chat-request
  (stringp (serialize-chat-request model messages)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-REQUEST
# ...):  A :REWRITE rule generated from STRINGP-OF-SERIALIZE-CHAT-REQUEST
# will be triggered only by terms containing the function symbol
# SERIALIZE-CHAT-REQUEST, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-SERIALIZE-CHAT-REQUEST depends upon the :type-
# prescription rule SERIALIZE-CHAT-REQUEST.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-REQUEST ...)
# Rules: ((:TYPE-PRESCRIPTION SERIALIZE-CHAT-REQUEST))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-SERIALIZE-CHAT-REQUEST

# %%
;; Serialize completions request (for Codex models)
;; Input: model (stringp), messages (chat-message-list-p), max-tokens (natp)
;; Output: stringp like {"model":"...","prompt":"...","max_tokens":...}
(defun serialize-completions-request (model messages max-tokens)
  (declare (xargs :guard (and (stringp model) 
                              (chat-message-list-p messages)
                              (natp max-tokens)))
           (ignore model messages max-tokens))
  (prog2$ (er hard? 'serialize-completions-request "Raw Lisp definition not installed?")
          "{}"))
# Out:
# Since SERIALIZE-COMPLETIONS-REQUEST is non-recursive, its admission
# is trivial.  We observe that the type of SERIALIZE-COMPLETIONS-REQUEST
# is described by the theorem
# (STRINGP (SERIALIZE-COMPLETIONS-REQUEST MODEL MESSAGES MAX-TOKENS)).
#
# Computing the guard conjecture for SERIALIZE-COMPLETIONS-REQUEST....
#
# The guard conjecture for SERIALIZE-COMPLETIONS-REQUEST is trivial to
# prove.  SERIALIZE-COMPLETIONS-REQUEST is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SERIALIZE-COMPLETIONS-REQUEST ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  SERIALIZE-COMPLETIONS-REQUEST

# %%
(defthm stringp-of-serialize-completions-request
  (stringp (serialize-completions-request model messages max-tokens)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-SERIALIZE-COMPLETIONS-REQUEST
# ...):  A :REWRITE rule generated from
# STRINGP-OF-SERIALIZE-COMPLETIONS-REQUEST will be triggered only by
# terms containing the function symbol SERIALIZE-COMPLETIONS-REQUEST,
# which has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-SERIALIZE-COMPLETIONS-REQUEST depends upon
# the :type-prescription rule SERIALIZE-COMPLETIONS-REQUEST.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-SERIALIZE-COMPLETIONS-REQUEST ...)
# Rules: ((:TYPE-PRESCRIPTION SERIALIZE-COMPLETIONS-REQUEST))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-SERIALIZE-COMPLETIONS-REQUEST

# %%
;; Parse chat completion response JSON, extract assistant message content
;; Input: json response string
;; Output: content string (empty on parse failure)
;; Note: Implementation in llm-client-raw.lsp uses kestrel/json-parser
(defun parse-chat-response (json)
  (declare (xargs :guard (stringp json))
           (ignore json))
  (prog2$ (er hard? 'parse-chat-response "Raw Lisp definition not installed?")
          ""))
# Out:
# Since PARSE-CHAT-RESPONSE is non-recursive, its admission is trivial.
# We observe that the type of PARSE-CHAT-RESPONSE is described by the
# theorem (STRINGP (PARSE-CHAT-RESPONSE JSON)).
#
# Computing the guard conjecture for PARSE-CHAT-RESPONSE....
#
# The guard conjecture for PARSE-CHAT-RESPONSE is trivial to prove.
# PARSE-CHAT-RESPONSE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN PARSE-CHAT-RESPONSE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  PARSE-CHAT-RESPONSE

# %%
(defthm stringp-of-parse-chat-response
  (stringp (parse-chat-response json)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-PARSE-CHAT-RESPONSE ...):
# A :REWRITE rule generated from STRINGP-OF-PARSE-CHAT-RESPONSE will
# be triggered only by terms containing the function symbol
# PARSE-CHAT-RESPONSE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-PARSE-CHAT-RESPONSE depends upon the :type-
# prescription rule PARSE-CHAT-RESPONSE.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-PARSE-CHAT-RESPONSE ...)
# Rules: ((:TYPE-PRESCRIPTION PARSE-CHAT-RESPONSE))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-PARSE-CHAT-RESPONSE

# %%
;; Parse completions response JSON, extract generated text
;; Input: json response string
;; Output: text string (empty on parse failure)
(defun parse-completions-response (json)
  (declare (xargs :guard (stringp json))
           (ignore json))
  (prog2$ (er hard? 'parse-completions-response "Raw Lisp definition not installed?")
          ""))
# Out:
# Since PARSE-COMPLETIONS-RESPONSE is non-recursive, its admission is
# trivial.  We observe that the type of PARSE-COMPLETIONS-RESPONSE is
# described by the theorem (STRINGP (PARSE-COMPLETIONS-RESPONSE JSON)).
#
# Computing the guard conjecture for PARSE-COMPLETIONS-RESPONSE....
#
# The guard conjecture for PARSE-COMPLETIONS-RESPONSE is trivial to prove.
# PARSE-COMPLETIONS-RESPONSE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN PARSE-COMPLETIONS-RESPONSE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  PARSE-COMPLETIONS-RESPONSE

# %%
(defthm stringp-of-parse-completions-response
  (stringp (parse-completions-response json)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-PARSE-COMPLETIONS-RESPONSE
# ...):  A :REWRITE rule generated from STRINGP-OF-PARSE-COMPLETIONS-RESPONSE
# will be triggered only by terms containing the function symbol
# PARSE-COMPLETIONS-RESPONSE, which has a non-recursive definition.
# Unless this definition is disabled, this rule is unlikely ever to be
# used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-PARSE-COMPLETIONS-RESPONSE depends upon the
# :type-prescription rule PARSE-COMPLETIONS-RESPONSE.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-PARSE-COMPLETIONS-RESPONSE ...)
# Rules: ((:TYPE-PRESCRIPTION PARSE-COMPLETIONS-RESPONSE))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-PARSE-COMPLETIONS-RESPONSE

# %%
;; Parse models response JSON, extract list of model IDs
;; Input: json response string from /v1/models (OpenAI format)
;; Output: list of model ID strings (nil on parse failure)
;; Note: Implementation in llm-client-raw.lsp uses kestrel/json-parser
(defun parse-models-response (json)
  (declare (xargs :guard (stringp json))
           (ignore json))
  (prog2$ (er hard? 'parse-models-response "Raw Lisp definition not installed?")
          nil))
# Out:
# Since PARSE-MODELS-RESPONSE is non-recursive, its admission is trivial.
# We observe that the type of PARSE-MODELS-RESPONSE is described by the
# theorem (EQUAL (PARSE-MODELS-RESPONSE JSON) NIL).
#
# Computing the guard conjecture for PARSE-MODELS-RESPONSE....
#
# The guard conjecture for PARSE-MODELS-RESPONSE is trivial to prove.
# PARSE-MODELS-RESPONSE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN PARSE-MODELS-RESPONSE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  PARSE-MODELS-RESPONSE

# %%
(defthm string-listp-of-parse-models-response
  (string-listp (parse-models-response json)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRING-LISTP-OF-PARSE-MODELS-RESPONSE
# ...):  A :REWRITE rule generated from STRING-LISTP-OF-PARSE-MODELS-RESPONSE
# will be triggered only by terms containing the function symbol
# PARSE-MODELS-RESPONSE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRING-LISTP-OF-PARSE-MODELS-RESPONSE depends upon the
# :type-prescription rule STRING-LISTP.
#
# Summary
# Form:  ( DEFTHM STRING-LISTP-OF-PARSE-MODELS-RESPONSE ...)
# Rules: ((:DEFINITION PARSE-MODELS-RESPONSE)
#         (:EXECUTABLE-COUNTERPART STRING-LISTP)
#         (:TYPE-PRESCRIPTION STRING-LISTP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  4
#  STRING-LISTP-OF-PARSE-MODELS-RESPONSE

# %%
;; Parse LM Studio v0 models response JSON, extract full model info
;; Input: json response string from /api/v0/models 
;; Output: list of model-info-p (nil on parse failure)
;; Note: Implementation in llm-client-raw.lsp uses kestrel/json-parser
(defun parse-v0-models-response (json)
  (declare (xargs :guard (stringp json))
           (ignore json))
  (prog2$ (er hard? 'parse-v0-models-response "Raw Lisp definition not installed?")
          nil))
# Out:
# Since PARSE-V0-MODELS-RESPONSE is non-recursive, its admission is trivial.
# We observe that the type of PARSE-V0-MODELS-RESPONSE is described by
# the theorem (EQUAL (PARSE-V0-MODELS-RESPONSE JSON) NIL).
#
# Computing the guard conjecture for PARSE-V0-MODELS-RESPONSE....
#
# The guard conjecture for PARSE-V0-MODELS-RESPONSE is trivial to prove.
# PARSE-V0-MODELS-RESPONSE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN PARSE-V0-MODELS-RESPONSE ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  PARSE-V0-MODELS-RESPONSE

# %%
(defthm model-info-list-p-of-parse-v0-models-response
  (model-info-list-p (parse-v0-models-response json)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM
# MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE ...):  A :REWRITE rule
# generated from MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE will be
# triggered only by terms containing the function symbol
# PARSE-V0-MODELS-RESPONSE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE depends
# upon the :compound-recognizer rule
# TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER and the :type-
# prescription rule MODEL-INFO-LIST-P.
#
# Summary
# Form:  ( DEFTHM MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE ...)
# Rules: ((:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER)
#         (:DEFINITION PARSE-V0-MODELS-RESPONSE)
#         (:EXECUTABLE-COUNTERPART MODEL-INFO-LIST-P)
#         (:TYPE-PRESCRIPTION MODEL-INFO-LIST-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  4
#  MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Unicode Normalization
# ;;
# ;; ACL2's character model only supports char-codes 0-255. LLM responses often
# ;; contain Unicode characters (smart quotes, em-dashes, etc.) with codes > 255.
# ;; This function normalizes them to ASCII equivalents.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Normalize Unicode characters in a string to ASCII/Latin-1
;; Input: any string (may contain Unicode chars > 255)
;; Output: string with all chars having char-code <= 255
;; Common mappings:
;;   - Smart quotes (U+2018-201F) -> ASCII ' or "
;;   - Dashes (U+2010-2015, U+2212) -> ASCII -
;;   - Bullets (U+2022) -> ASCII *
;;   - Arrows (U+2192) -> ASCII >
;;   - Unknown chars > 255 -> ?
(defun normalize-unicode-string (s)
  (declare (xargs :guard (stringp s))
           (ignore s))
  (prog2$ (er hard? 'normalize-unicode-string "Raw Lisp definition not installed?")
          ""))
# Out:
# Since NORMALIZE-UNICODE-STRING is non-recursive, its admission is trivial.
# We observe that the type of NORMALIZE-UNICODE-STRING is described by
# the theorem (STRINGP (NORMALIZE-UNICODE-STRING S)).
#
# Computing the guard conjecture for NORMALIZE-UNICODE-STRING....
#
# The guard conjecture for NORMALIZE-UNICODE-STRING is trivial to prove.
# NORMALIZE-UNICODE-STRING is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN NORMALIZE-UNICODE-STRING ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  NORMALIZE-UNICODE-STRING

# %%
(defthm stringp-of-normalize-unicode-string
  (stringp (normalize-unicode-string s)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-NORMALIZE-UNICODE-STRING
# ...):  A :REWRITE rule generated from STRINGP-OF-NORMALIZE-UNICODE-STRING
# will be triggered only by terms containing the function symbol
# NORMALIZE-UNICODE-STRING, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-NORMALIZE-UNICODE-STRING depends upon the
# :type-prescription rule NORMALIZE-UNICODE-STRING.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-NORMALIZE-UNICODE-STRING ...)
# Rules: ((:TYPE-PRESCRIPTION NORMALIZE-UNICODE-STRING))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-NORMALIZE-UNICODE-STRING

# %%
;; Helper: check if all characters in list have char-code <= 255
(defun acl2-safe-chars-p (chars)
  "Check if all characters in list have char-code <= 255."
  (declare (xargs :guard (character-listp chars)))
  (if (endp chars)
      t
    (and (< (char-code (car chars)) 256)
         (acl2-safe-chars-p (cdr chars)))))
# Out:
# The admission of ACL2-SAFE-CHARS-P is trivial, using the relation O<
# (which is known to be well-founded on the domain recognized by O-P)
# and the measure (ACL2-COUNT CHARS).  We observe that the type of
# ACL2-SAFE-CHARS-P is described by the theorem
# (OR (EQUAL (ACL2-SAFE-CHARS-P CHARS) T)
#     (EQUAL (ACL2-SAFE-CHARS-P CHARS) NIL)).
#
# Computing the guard conjecture for ACL2-SAFE-CHARS-P....
#
# The non-trivial part of the guard conjecture for ACL2-SAFE-CHARS-P,
# given primitive type reasoning, the :forward-chaining rules
# ATOM-LISTP-FORWARD-TO-TRUE-LISTP, CHARACTER-LISTP-FORWARD-TO-EQLABLE-LISTP
# and EQLABLE-LISTP-FORWARD-TO-ATOM-LISTP and the :type-prescription
# rules ATOM-LISTP, CHARACTER-LISTP and EQLABLE-LISTP, is
#
# Goal
# (AND (IMPLIES (AND (CHARACTER-LISTP CHARS)
#                    (NOT (ENDP CHARS)))
#               (CHARACTERP (CAR CHARS)))
#      (IMPLIES (AND (CHARACTER-LISTP CHARS)
#                    (NOT (ENDP CHARS))
#                    (< (CHAR-CODE (CAR CHARS)) 256))
#               (CHARACTER-LISTP (CDR CHARS)))).
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the guard theorem for ACL2-SAFE-CHARS-P.
# ACL2-SAFE-CHARS-P is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN ACL2-SAFE-CHARS-P ...)
# Rules: ((:DEFINITION CHARACTER-LISTP)
#         (:DEFINITION ENDP)
#         (:DEFINITION NOT)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING ATOM-LISTP-FORWARD-TO-TRUE-LISTP)
#         (:FORWARD-CHAINING CHARACTER-LISTP-FORWARD-TO-EQLABLE-LISTP)
#         (:FORWARD-CHAINING EQLABLE-LISTP-FORWARD-TO-ATOM-LISTP)
#         (:TYPE-PRESCRIPTION ATOM-LISTP)
#         (:TYPE-PRESCRIPTION CHARACTER-LISTP)
#         (:TYPE-PRESCRIPTION EQLABLE-LISTP))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  158
#  ACL2-SAFE-CHARS-P

# %%
(defthm booleanp-of-acl2-safe-chars-p
  (booleanp (acl2-safe-chars-p chars))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM BOOLEANP-OF-ACL2-SAFE-CHARS-P ...):  Our
# heuristics choose (ACL2-SAFE-CHARS-P CHARS) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-ACL2-SAFE-CHARS-P depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-ACL2-SAFE-CHARS-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION ACL2-SAFE-CHARS-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  BOOLEANP-OF-ACL2-SAFE-CHARS-P

# %%
;; Key property: normalized strings are ACL2-safe (all char-codes <= 255)
;; This is the critical invariant that allows LLM responses to be used in ACL2
(defun acl2-safe-string-p (s)
  "A string is ACL2-safe if all its characters have char-code <= 255."
  (declare (xargs :guard (stringp s)))
  (if (not (stringp s))
      nil
    (acl2-safe-chars-p (coerce s 'list))))
# Out:
# Since ACL2-SAFE-STRING-P is non-recursive, its admission is trivial.
# We observe that the type of ACL2-SAFE-STRING-P is described by the
# theorem
# (OR (EQUAL (ACL2-SAFE-STRING-P S) T) (EQUAL (ACL2-SAFE-STRING-P S) NIL)).
# We used the :type-prescription rule BOOLEANP-OF-ACL2-SAFE-CHARS-P.
#
# Computing the guard conjecture for ACL2-SAFE-STRING-P....
#
# The guard conjecture for ACL2-SAFE-STRING-P is trivial to prove, given
# the :forward-chaining rule CHARACTER-LISTP-COERCE.  ACL2-SAFE-STRING-P
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN ACL2-SAFE-STRING-P ...)
# Rules: ((:FORWARD-CHAINING CHARACTER-LISTP-COERCE)
#         (:TYPE-PRESCRIPTION BOOLEANP-OF-ACL2-SAFE-CHARS-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  ACL2-SAFE-STRING-P

# %%
(defthm booleanp-of-acl2-safe-string-p
  (booleanp (acl2-safe-string-p s))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM BOOLEANP-OF-ACL2-SAFE-STRING-P ...):
# Our heuristics choose (ACL2-SAFE-STRING-P S) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-ACL2-SAFE-STRING-P depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-ACL2-SAFE-STRING-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION ACL2-SAFE-STRING-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  BOOLEANP-OF-ACL2-SAFE-STRING-P

# %% [raw]
# ;; Note: The theorem that normalize-unicode-string produces ACL2-safe strings
# ;; cannot be proven in ACL2's logic because ACL2 cannot represent strings with
# ;; char-code > 255. The property holds by construction in raw Lisp.

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Main API
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Helper to check if HTTP status indicates success (2xx)
(defun http-success-p (status)
  (declare (xargs :guard (natp status)))
  (and (>= status 200)
       (< status 300)))
# Out:
# Since HTTP-SUCCESS-P is non-recursive, its admission is trivial.  We
# observe that the type of HTTP-SUCCESS-P is described by the theorem
# (OR (EQUAL (HTTP-SUCCESS-P STATUS) T) (EQUAL (HTTP-SUCCESS-P STATUS) NIL)).
#
# Computing the guard conjecture for HTTP-SUCCESS-P....
#
# The guard conjecture for HTTP-SUCCESS-P is trivial to prove, given
# the :compound-recognizer rule NATP-COMPOUND-RECOGNIZER.  HTTP-SUCCESS-P
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN HTTP-SUCCESS-P ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  HTTP-SUCCESS-P

# %%
(defthm booleanp-of-http-success-p
  (booleanp (http-success-p status))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM BOOLEANP-OF-HTTP-SUCCESS-P ...):  Our
# heuristics choose (HTTP-SUCCESS-P STATUS) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-HTTP-SUCCESS-P depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-HTTP-SUCCESS-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION HTTP-SUCCESS-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  BOOLEANP-OF-HTTP-SUCCESS-P

# %%
;; Call LLM chat completion API
;;
;; Parameters:
;;   model    - Model identifier string (e.g., "local-model")
;;   messages - Conversation history as chat-message-list
;;   state    - ACL2 state
;;
;; Returns: (mv error response state)
;;   error    - NIL on success, error string on failure
;;   response - Assistant's response content (stringp, empty on error)
;;   state    - Updated state
(defun llm-chat-completion (model messages state)
  (declare (xargs :guard (and (stringp model)
                              (chat-message-list-p messages))
                  :stobjs state
                  :guard-hints (("Goal" :in-theory (disable post-json)))))
  (b* ((request-json (serialize-chat-request model messages))
       
       ;; HTTP headers for JSON API (charset=utf-8 required for proper Unicode)
       (headers '(("Content-Type" . "application/json; charset=utf-8")
                  ("Accept" . "application/json")))
       
       ;; Make HTTP POST request with proper guards
       ((mv err response-body status-raw state)
        (post-json *lm-studio-endpoint*
                   request-json
                   headers
                   *llm-connect-timeout*
                   *llm-read-timeout*
                   state))
       
       ;; Coerce status to natp (it is, via theorem, but help guard verification)
       (status (mbe :logic (nfix status-raw) :exec status-raw))
       
       ;; Check for network/connection errors
       ((when err)
        (mv err "" state))
       
       ;; Check for HTTP error status
       ((unless (http-success-p status))
        (mv (concatenate 'string "HTTP error: status " 
                        (coerce (explode-nonnegative-integer status 10 nil) 'string))
            ""
            state))
       
       ;; Parse the response JSON to extract assistant content
       (content (parse-chat-response response-body)))
    
    (mv nil content state)))

# %%
;; Return type theorems for llm-chat-completion
(defthm stringp-of-llm-chat-completion-response
  (stringp (mv-nth 1 (llm-chat-completion model messages state))))
# Out:
# ACL2 Error [Translate] in ( DEFTHM STRINGP-OF-LLM-CHAT-COMPLETION-RESPONSE
# ...):  The symbol LLM-CHAT-COMPLETION (in package "ACL2") has neither
# a function nor macro definition in ACL2.  Please define it.  See :DOC
# near-misses.  Note:  this error occurred in the context
# (LLM-CHAT-COMPLETION MODEL MESSAGES STATE).
#
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-LLM-CHAT-COMPLETION-RESPONSE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Error [Failure] in ( DEFTHM STRINGP-OF-LLM-CHAT-COMPLETION-RESPONSE
# ...):  See :DOC failure.
#
# ******** FAILED ********

# %%
(defthm state-p1-of-llm-chat-completion
  (implies (state-p1 state)
           (state-p1 (mv-nth 2 (llm-chat-completion model messages state)))))
# Out:
# ACL2 Error [Translate] in ( DEFTHM STATE-P1-OF-LLM-CHAT-COMPLETION
# ...):  The symbol LLM-CHAT-COMPLETION (in package "ACL2") has neither
# a function nor macro definition in ACL2.  Please define it.  See :DOC
# near-misses.  Note:  this error occurred in the context
# (LLM-CHAT-COMPLETION MODEL MESSAGES STATE).
#
#
# Summary
# Form:  ( DEFTHM STATE-P1-OF-LLM-CHAT-COMPLETION ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Error [Failure] in ( DEFTHM STATE-P1-OF-LLM-CHAT-COMPLETION ...):
# See :DOC failure.
#
# ******** FAILED ********

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Provider-Aware Chat Completion
# ;;
# ;; Use a provider configuration to call the appropriate LLM API.
# ;; Supports local (LM Studio), OpenAI, and custom OpenAI-compatible endpoints.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Build headers for provider (adds Authorization for cloud providers)
(defun make-provider-headers (config)
  (declare (xargs :guard (llm-provider-config-p config)))
  (let* ((api-key (llm-provider-config->api-key config))
         (org-id (llm-provider-config->org-id config))
         (base-headers '(("Content-Type" . "application/json; charset=utf-8")
                        ("Accept" . "application/json"))))
    (cond
     ;; No API key needed (local)
     ((equal api-key "")
      base-headers)
     ;; Has API key - add Authorization header
     (t
      (let ((auth-headers 
             (cons (cons "Authorization" 
                        (concatenate 'string "Bearer " api-key))
                   base-headers)))
        ;; Add org header if present
        (if (equal org-id "")
            auth-headers
          (cons (cons "OpenAI-Organization" org-id)
                auth-headers)))))))

# %%
(defthm alistp-of-make-provider-headers
  (alistp (make-provider-headers config)))

# %%
;; Call LLM chat completion API with provider configuration
;;
;; Parameters:
;;   config   - LLM provider configuration
;;   messages - Conversation history as chat-message-list
;;   state    - ACL2 state
;;
;; Returns: (mv error response state)
;;   error    - NIL on success, error string on failure
;;   response - Assistant's response content (stringp, empty on error)
;;   state    - Updated state
(defun llm-chat-completion-with-provider (config messages state)
  (declare (xargs :guard (and (llm-provider-config-p config)
                              (chat-message-list-p messages))
                  :stobjs state
                  :guard-hints (("Goal" :in-theory (disable post-json)))))
  (b* (;; Get endpoint and model from config
       (endpoint (llm-provider-config->endpoint config))
       (model (llm-provider-config->model config))
       
       ;; Validate config
       ((when (equal endpoint ""))
        (mv "Provider config missing endpoint" "" state))
       ((when (equal model ""))
        (mv "Provider config missing model" "" state))
       ((when (and (provider-requires-api-key-p config)
                   (equal (llm-provider-config->api-key config) "")))
        (mv "Provider requires API key but none configured" "" state))
       
       ;; Serialize the request to JSON
       (request-json (serialize-chat-request model messages))
       
       ;; Build headers with auth if needed
       (headers (make-provider-headers config))
       
       ;; Make HTTP POST request
       ((mv err response-body status-raw state)
        (post-json endpoint
                   request-json
                   headers
                   *llm-connect-timeout*
                   *llm-read-timeout*
                   state))
       
       ;; Coerce status to natp
       (status (mbe :logic (nfix status-raw) :exec status-raw))
       
       ;; Check for network/connection errors
       ((when err)
        (mv err "" state))
       
       ;; Check for HTTP error status
       ((unless (http-success-p status))
        (mv (concatenate 'string "HTTP error: status " 
                        (coerce (explode-nonnegative-integer status 10 nil) 'string))
            ""
            state))
       
       ;; Parse the response JSON to extract assistant content
       (content (parse-chat-response response-body)))
    
    (mv nil content state)))

# %%
;; Return type theorems for llm-chat-completion-with-provider
(defthm stringp-of-llm-chat-completion-with-provider-response
  (stringp (mv-nth 1 (llm-chat-completion-with-provider config messages state))))

# %%
(defthm state-p1-of-llm-chat-completion-with-provider
  (implies (state-p1 state)
           (state-p1 (mv-nth 2 (llm-chat-completion-with-provider config messages state)))))

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Completions API (for Codex models)
# ;;
# ;; Codex models use /v1/completions endpoint with prompt instead of messages.
# ;; This function converts chat messages to a prompt and calls completions API.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(defconst *default-max-tokens* 2048)

# %%
;; Call LLM completions API with provider configuration (for Codex models)
;;
;; Parameters:
;;   config     - LLM provider configuration (endpoint will be modified to /completions)
;;   messages   - Conversation history as chat-message-list (converted to prompt)
;;   max-tokens - Maximum tokens to generate (default 2048)
;;   state      - ACL2 state
;;
;; Returns: (mv error response state)
;;   error    - NIL on success, error string on failure
;;   response - Generated text (stringp, empty on error)
;;   state    - Updated state
(defun llm-completions-with-provider (config messages max-tokens state)
  (declare (xargs :guard (and (llm-provider-config-p config)
                              (chat-message-list-p messages)
                              (natp max-tokens))
                  :stobjs state
                  :guard-hints (("Goal" :in-theory (disable post-json)))))
  (b* (;; Get model from config, use completions endpoint
       (model (llm-provider-config->model config))
       
       ;; Use the completions endpoint
       (endpoint *openai-completions-endpoint*)
       
       ;; Validate config
       ((when (equal model ""))
        (mv "Provider config missing model" "" state))
       ((when (and (provider-requires-api-key-p config)
                   (equal (llm-provider-config->api-key config) "")))
        (mv "Provider requires API key but none configured" "" state))
       
       ;; Serialize the request to JSON (converts messages to prompt)
       (request-json (serialize-completions-request model messages max-tokens))
       
       ;; Build headers with auth if needed
       (headers (make-provider-headers config))
       
       ;; Make HTTP POST request
       ((mv err response-body status-raw state)
        (post-json endpoint
                   request-json
                   headers
                   *llm-connect-timeout*
                   *llm-read-timeout*
                   state))
       
       ;; Coerce status to natp
       (status (mbe :logic (nfix status-raw) :exec status-raw))
       
       ;; Check for network/connection errors
       ((when err)
        (mv err "" state))
       
       ;; Check for HTTP error status
       ((unless (http-success-p status))
        (mv (concatenate 'string "HTTP error: status " 
                        (coerce (explode-nonnegative-integer status 10 nil) 'string)
                        " - " response-body)
            ""
            state))
       
       ;; Parse the response JSON to extract generated text
       (content (parse-completions-response response-body)))
    
    (mv nil content state)))

# %%
;; Return type theorems for llm-completions-with-provider
(defthm stringp-of-llm-completions-with-provider-response
  (stringp (mv-nth 1 (llm-completions-with-provider config messages max-tokens state))))

# %%
(defthm state-p1-of-llm-completions-with-provider
  (implies (state-p1 state)
           (state-p1 (mv-nth 2 (llm-completions-with-provider config messages max-tokens state)))))

# %%
;; List available models from LLM server
;;
;; Parameters:
;;   state - ACL2 state
;;
;; Returns: (mv error models state)
;;   error  - NIL on success, error string on failure
;;   models - List of model ID strings (string-listp)
;;   state  - Updated state
(defun llm-list-models (state)
  (declare (xargs :stobjs state))
  (b* (;; HTTP headers for JSON API
       (headers '(("Accept" . "application/json")))
       
       ;; Make HTTP GET request
       ((mv err response-body status-raw state)
        (get-json *lm-studio-models-endpoint*
                  headers
                  *llm-connect-timeout*
                  *llm-read-timeout*
                  state))
       
       ;; Coerce status to natp
       (status (mbe :logic (nfix status-raw) :exec status-raw))
       
       ;; Check for network/connection errors
       ((when err)
        (mv err nil state))
       
       ;; Check for HTTP error status
       ((unless (http-success-p status))
        (mv (concatenate 'string "HTTP error: status " 
                        (coerce (explode-nonnegative-integer status 10 nil) 'string))
            nil
            state))
       
       ;; Parse the response JSON to extract model list
       (models (parse-models-response response-body)))
    
    (mv nil models state)))

# %%
;; Return type theorems for llm-list-models
(defthm string-listp-of-llm-list-models-models
  (string-listp (mv-nth 1 (llm-list-models state))))

# %%
(defthm state-p1-of-llm-list-models
  (implies (state-p1 state)
           (state-p1 (mv-nth 2 (llm-list-models state)))))

# %%
;; List available models with full info from LM Studio v0 API
;;
;; Parameters:
;;   state - ACL2 state
;;
;; Returns: (mv error models state)
;;   error  - NIL on success, error string on failure
;;   models - List of model-info-p with full details
;;   state  - Updated state
(defun llm-list-models-full (state)
  (declare (xargs :stobjs state))
  (b* (;; HTTP headers for JSON API
       (headers '(("Accept" . "application/json")))
       
       ;; Make HTTP GET request to v0 API
       ((mv err response-body status-raw state)
        (get-json *lm-studio-v0-models-endpoint*
                  headers
                  *llm-connect-timeout*
                  *llm-read-timeout*
                  state))
       
       ;; Coerce status to natp
       (status (mbe :logic (nfix status-raw) :exec status-raw))
       
       ;; Check for network/connection errors
       ((when err)
        (mv err nil state))
       
       ;; Check for HTTP error status
       ((unless (http-success-p status))
        (mv (concatenate 'string "HTTP error: status " 
                        (coerce (explode-nonnegative-integer status 10 nil) 'string))
            nil
            state))
       
       ;; Parse the response JSON to extract full model info
       (models (parse-v0-models-response response-body)))
    
    (mv nil models state)))

# %%
;; Return type theorems for llm-list-models-full
(defthm model-info-list-p-of-llm-list-models-full-models
  (model-info-list-p (mv-nth 1 (llm-list-models-full state))))

# %%
(defthm state-p1-of-llm-list-models-full
  (implies (state-p1 state)
           (state-p1 (mv-nth 2 (llm-list-models-full state)))))

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Model Selection
# ;;
# ;; Select the best model from available models based on preferences.
# ;; Default: first loaded completions model that matches any preference string.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Check if model ID contains a preference substring (case-insensitive would be 
;; nice but we'll do exact substring for now)
(defun model-matches-pref-p (model-id pref)
  (declare (xargs :guard (and (stringp model-id) (stringp pref))))
  (search pref model-id))

# %%
;; Find first model matching any of the preferences
;; Implementation in raw Lisp uses LOOP for efficiency
(defun find-matching-model (models prefs)
  (declare (xargs :guard (and (model-info-list-p models)
                              (string-listp prefs)))
           (ignore models prefs))
  (prog2$ (er hard? 'find-matching-model "Raw Lisp definition not installed?")
          nil))

# %%
;; Select best model for completions
;;
;; Parameters:
;;   models - Full model info list from llm-list-models-full
;;   prefs  - List of preference strings to match (partial match on model ID)
;;
;; Returns: model-info-p or nil if no suitable model found
;;
;; Selection order:
;; 1. First loaded completions model matching a preference (in pref order)
;; 2. First loaded completions model (if no prefs or no match)
;; 3. NIL if no loaded completions models
(defun select-completions-model (models prefs)
  (declare (xargs :guard (and (model-info-list-p models)
                              (string-listp prefs)))
           (ignore models prefs))
  (prog2$ (er hard? 'select-completions-model "Raw Lisp definition not installed?")
          nil))

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Trust tag and raw Lisp inclusion for serialization functions
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(defttag :llm-client)
(include-raw "llm-client-raw.lsp"
             :host-readtable t)
