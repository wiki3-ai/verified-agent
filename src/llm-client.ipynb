# %% [raw]
# ; LLM Client -- HTTP client for LLM API calls
# ;
# ; Copyright (C) 2025
# ;
# ; License: See LICENSE file
# ;
# ; Author: AI Assistant with human guidance
# ;
# ; This book provides a verified LLM client using properly-guarded HTTP JSON
# ; functions. All guards are maintained for formal verification.

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(in-package "ACL2")
# Out:
#  "ACL2"

# %%
(include-book "llm-types")
(include-book "http-json" 
              :ttags ((:quicklisp) (:quicklisp.dexador) (:http-json)))
(include-book "std/strings/explode-nonnegative-integer" :dir :system)
(include-book "kestrel/json-parser/parse-json" :dir :system)
; (depends-on "llm-client-raw.lsp")
# Out:
# Summary
# Form:  ( INCLUDE-BOOK "llm-types" ...)
# Rules: NIL
# Time:  0.43 seconds (prove: 0.00, print: 0.00, other: 0.43)
#  "/workspaces/verified-agent/src/llm-types.lisp"
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP from book /home/acl2/books/quicklisp/base.
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP.DEXADOR from book /home/acl2/books/quicklisp/dexador.
#
# TTAG NOTE (for included book): Adding ttag :HTTP-JSON from book /workspaces/verified-agent/src/http-json.
#
# Summary
# Form:  ( INCLUDE-BOOK "http-json" ...)
# Rules: NIL
# Time:  0.34 seconds (prove: 0.00, print: 0.00, other: 0.34)
#  "/workspaces/verified-agent/src/http-json.lisp"
#
# Summary
# Form:  ( INCLUDE-BOOK "std/strings/explode-nonnegative-integer" ...)
# Rules: NIL
# Time:  0.04 seconds (prove: 0.00, print: 0.00, other: 0.04)
#  "/home/acl2/books/std/strings/explode-nonnegative-integer.lisp"
#
# Summary
# Form:  ( INCLUDE-BOOK "kestrel/json-parser/parse-json" ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  "/home/acl2/books/kestrel/json-parser/parse-json.lisp"

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Configuration
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(defconst *lm-studio-endpoint* 
  "http://host.docker.internal:1234/v1/chat/completions")
# Out:
# Summary
# Form:  ( DEFCONST *LM-STUDIO-ENDPOINT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LM-STUDIO-ENDPOINT*

# %%
;; OpenAI-compatible models endpoint (basic info only)
(defconst *lm-studio-models-endpoint*
  "http://host.docker.internal:1234/v1/models")
# Out:
# Summary
# Form:  ( DEFCONST *LM-STUDIO-MODELS-ENDPOINT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LM-STUDIO-MODELS-ENDPOINT*

# %%
;; LM Studio native API (full model info with type, state, context length)
(defconst *lm-studio-v0-models-endpoint*
  "http://host.docker.internal:1234/api/v0/models")
# Out:
# Summary
# Form:  ( DEFCONST *LM-STUDIO-V0-MODELS-ENDPOINT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LM-STUDIO-V0-MODELS-ENDPOINT*

# %%
(defconst *llm-connect-timeout* 30)   ; seconds
(defconst *llm-read-timeout* 120)     ; seconds (higher for slow local models)
# Out:
# Summary
# Form:  ( DEFCONST *LLM-CONNECT-TIMEOUT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LLM-CONNECT-TIMEOUT*
#
# Summary
# Form:  ( DEFCONST *LLM-READ-TIMEOUT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *LLM-READ-TIMEOUT*

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; JSON Serialization Helpers
# ;;
# ;; Logical specifications - raw Lisp provides actual implementation.
# ;; These maintain proper guards (stringp returns).
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Serialize a single chat message to JSON object string
;; Input: chat-message-p
;; Output: stringp like {"role":"user","content":"hello"}
(defun serialize-chat-message (msg)
  (declare (xargs :guard (chat-message-p msg))
           (ignore msg))
  (prog2$ (er hard? 'serialize-chat-message "Raw Lisp definition not installed?")
          "{}"))
# Out:
# Since SERIALIZE-CHAT-MESSAGE is non-recursive, its admission is trivial.
# We observe that the type of SERIALIZE-CHAT-MESSAGE is described by
# the theorem (STRINGP (SERIALIZE-CHAT-MESSAGE MSG)).
#
# Computing the guard conjecture for SERIALIZE-CHAT-MESSAGE....
#
# The guard conjecture for SERIALIZE-CHAT-MESSAGE is trivial to prove.
# SERIALIZE-CHAT-MESSAGE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SERIALIZE-CHAT-MESSAGE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  SERIALIZE-CHAT-MESSAGE

# %%
(defthm stringp-of-serialize-chat-message
  (stringp (serialize-chat-message msg)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-MESSAGE
# ...):  A :REWRITE rule generated from STRINGP-OF-SERIALIZE-CHAT-MESSAGE
# will be triggered only by terms containing the function symbol
# SERIALIZE-CHAT-MESSAGE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-SERIALIZE-CHAT-MESSAGE depends upon the :type-
# prescription rule SERIALIZE-CHAT-MESSAGE.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-MESSAGE ...)
# Rules: ((:TYPE-PRESCRIPTION SERIALIZE-CHAT-MESSAGE))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-SERIALIZE-CHAT-MESSAGE

# %%
;; Serialize a list of chat messages to JSON array string
;; Input: chat-message-list-p
;; Output: stringp like [{"role":"user","content":"hello"}]
(defun serialize-chat-messages (messages)
  (declare (xargs :guard (chat-message-list-p messages))
           (ignore messages))
  (prog2$ (er hard? 'serialize-chat-messages "Raw Lisp definition not installed?")
          "[]"))
# Out:
# Since SERIALIZE-CHAT-MESSAGES is non-recursive, its admission is trivial.
# We observe that the type of SERIALIZE-CHAT-MESSAGES is described by
# the theorem (STRINGP (SERIALIZE-CHAT-MESSAGES MESSAGES)).
#
# Computing the guard conjecture for SERIALIZE-CHAT-MESSAGES....
#
# The guard conjecture for SERIALIZE-CHAT-MESSAGES is trivial to prove.
# SERIALIZE-CHAT-MESSAGES is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SERIALIZE-CHAT-MESSAGES ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  SERIALIZE-CHAT-MESSAGES

# %%
(defthm stringp-of-serialize-chat-messages
  (stringp (serialize-chat-messages messages)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-MESSAGES
# ...):  A :REWRITE rule generated from STRINGP-OF-SERIALIZE-CHAT-MESSAGES
# will be triggered only by terms containing the function symbol
# SERIALIZE-CHAT-MESSAGES, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-SERIALIZE-CHAT-MESSAGES depends upon the
# :type-prescription rule SERIALIZE-CHAT-MESSAGES.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-MESSAGES ...)
# Rules: ((:TYPE-PRESCRIPTION SERIALIZE-CHAT-MESSAGES))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-SERIALIZE-CHAT-MESSAGES

# %%
;; Serialize full chat completion request to JSON string
;; Input: model (stringp), messages (chat-message-list-p)
;; Output: stringp like {"model":"...","messages":[...]}
(defun serialize-chat-request (model messages)
  (declare (xargs :guard (and (stringp model) (chat-message-list-p messages)))
           (ignore model messages))
  (prog2$ (er hard? 'serialize-chat-request "Raw Lisp definition not installed?")
          "{}"))
# Out:
# Since SERIALIZE-CHAT-REQUEST is non-recursive, its admission is trivial.
# We observe that the type of SERIALIZE-CHAT-REQUEST is described by
# the theorem (STRINGP (SERIALIZE-CHAT-REQUEST MODEL MESSAGES)).
#
# Computing the guard conjecture for SERIALIZE-CHAT-REQUEST....
#
# The guard conjecture for SERIALIZE-CHAT-REQUEST is trivial to prove.
# SERIALIZE-CHAT-REQUEST is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SERIALIZE-CHAT-REQUEST ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  SERIALIZE-CHAT-REQUEST

# %%
(defthm stringp-of-serialize-chat-request
  (stringp (serialize-chat-request model messages)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-REQUEST
# ...):  A :REWRITE rule generated from STRINGP-OF-SERIALIZE-CHAT-REQUEST
# will be triggered only by terms containing the function symbol
# SERIALIZE-CHAT-REQUEST, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-SERIALIZE-CHAT-REQUEST depends upon the :type-
# prescription rule SERIALIZE-CHAT-REQUEST.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-SERIALIZE-CHAT-REQUEST ...)
# Rules: ((:TYPE-PRESCRIPTION SERIALIZE-CHAT-REQUEST))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-SERIALIZE-CHAT-REQUEST

# %%
;; Parse chat completion response JSON, extract assistant message content
;; Input: json response string
;; Output: content string (empty on parse failure)
;; Note: Implementation in llm-client-raw.lsp uses kestrel/json-parser
(defun parse-chat-response (json)
  (declare (xargs :guard (stringp json))
           (ignore json))
  (prog2$ (er hard? 'parse-chat-response "Raw Lisp definition not installed?")
          ""))
# Out:
# Since PARSE-CHAT-RESPONSE is non-recursive, its admission is trivial.
# We observe that the type of PARSE-CHAT-RESPONSE is described by the
# theorem (STRINGP (PARSE-CHAT-RESPONSE JSON)).
#
# Computing the guard conjecture for PARSE-CHAT-RESPONSE....
#
# The guard conjecture for PARSE-CHAT-RESPONSE is trivial to prove.
# PARSE-CHAT-RESPONSE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN PARSE-CHAT-RESPONSE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  PARSE-CHAT-RESPONSE

# %%
(defthm stringp-of-parse-chat-response
  (stringp (parse-chat-response json)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-PARSE-CHAT-RESPONSE ...):
# A :REWRITE rule generated from STRINGP-OF-PARSE-CHAT-RESPONSE will
# be triggered only by terms containing the function symbol
# PARSE-CHAT-RESPONSE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-PARSE-CHAT-RESPONSE depends upon the :type-
# prescription rule PARSE-CHAT-RESPONSE.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-PARSE-CHAT-RESPONSE ...)
# Rules: ((:TYPE-PRESCRIPTION PARSE-CHAT-RESPONSE))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRINGP-OF-PARSE-CHAT-RESPONSE

# %%
;; Parse models response JSON, extract list of model IDs
;; Input: json response string from /v1/models (OpenAI format)
;; Output: list of model ID strings (nil on parse failure)
;; Note: Implementation in llm-client-raw.lsp uses kestrel/json-parser
(defun parse-models-response (json)
  (declare (xargs :guard (stringp json))
           (ignore json))
  (prog2$ (er hard? 'parse-models-response "Raw Lisp definition not installed?")
          nil))
# Out:
# Since PARSE-MODELS-RESPONSE is non-recursive, its admission is trivial.
# We observe that the type of PARSE-MODELS-RESPONSE is described by the
# theorem (EQUAL (PARSE-MODELS-RESPONSE JSON) NIL).
#
# Computing the guard conjecture for PARSE-MODELS-RESPONSE....
#
# The guard conjecture for PARSE-MODELS-RESPONSE is trivial to prove.
# PARSE-MODELS-RESPONSE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN PARSE-MODELS-RESPONSE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  PARSE-MODELS-RESPONSE

# %%
(defthm string-listp-of-parse-models-response
  (string-listp (parse-models-response json)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRING-LISTP-OF-PARSE-MODELS-RESPONSE
# ...):  A :REWRITE rule generated from STRING-LISTP-OF-PARSE-MODELS-RESPONSE
# will be triggered only by terms containing the function symbol
# PARSE-MODELS-RESPONSE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRING-LISTP-OF-PARSE-MODELS-RESPONSE depends upon the
# :type-prescription rule STRING-LISTP.
#
# Summary
# Form:  ( DEFTHM STRING-LISTP-OF-PARSE-MODELS-RESPONSE ...)
# Rules: ((:DEFINITION PARSE-MODELS-RESPONSE)
#         (:EXECUTABLE-COUNTERPART STRING-LISTP)
#         (:TYPE-PRESCRIPTION STRING-LISTP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  4
#  STRING-LISTP-OF-PARSE-MODELS-RESPONSE

# %%
;; Parse LM Studio v0 models response JSON, extract full model info
;; Input: json response string from /api/v0/models 
;; Output: list of model-info-p (nil on parse failure)
;; Note: Implementation in llm-client-raw.lsp uses kestrel/json-parser
(defun parse-v0-models-response (json)
  (declare (xargs :guard (stringp json))
           (ignore json))
  (prog2$ (er hard? 'parse-v0-models-response "Raw Lisp definition not installed?")
          nil))
# Out:
# Since PARSE-V0-MODELS-RESPONSE is non-recursive, its admission is trivial.
# We observe that the type of PARSE-V0-MODELS-RESPONSE is described by
# the theorem (EQUAL (PARSE-V0-MODELS-RESPONSE JSON) NIL).
#
# Computing the guard conjecture for PARSE-V0-MODELS-RESPONSE....
#
# The guard conjecture for PARSE-V0-MODELS-RESPONSE is trivial to prove.
# PARSE-V0-MODELS-RESPONSE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN PARSE-V0-MODELS-RESPONSE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  PARSE-V0-MODELS-RESPONSE

# %%
(defthm model-info-list-p-of-parse-v0-models-response
  (model-info-list-p (parse-v0-models-response json)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM
# MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE ...):  A :REWRITE rule
# generated from MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE will be
# triggered only by terms containing the function symbol
# PARSE-V0-MODELS-RESPONSE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE depends
# upon the :compound-recognizer rule
# TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER and the :type-
# prescription rule MODEL-INFO-LIST-P.
#
# Summary
# Form:  ( DEFTHM MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE ...)
# Rules: ((:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER)
#         (:DEFINITION PARSE-V0-MODELS-RESPONSE)
#         (:EXECUTABLE-COUNTERPART MODEL-INFO-LIST-P)
#         (:TYPE-PRESCRIPTION MODEL-INFO-LIST-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  4
#  MODEL-INFO-LIST-P-OF-PARSE-V0-MODELS-RESPONSE

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Main API
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Helper to check if HTTP status indicates success (2xx)
(defun http-success-p (status)
  (declare (xargs :guard (natp status)))
  (and (>= status 200)
       (< status 300)))
# Out:
# Since HTTP-SUCCESS-P is non-recursive, its admission is trivial.  We
# observe that the type of HTTP-SUCCESS-P is described by the theorem
# (OR (EQUAL (HTTP-SUCCESS-P STATUS) T) (EQUAL (HTTP-SUCCESS-P STATUS) NIL)).
#
# Computing the guard conjecture for HTTP-SUCCESS-P....
#
# The guard conjecture for HTTP-SUCCESS-P is trivial to prove, given
# the :compound-recognizer rule NATP-COMPOUND-RECOGNIZER.  HTTP-SUCCESS-P
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN HTTP-SUCCESS-P ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  HTTP-SUCCESS-P

# %%
(defthm booleanp-of-http-success-p
  (booleanp (http-success-p status))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM BOOLEANP-OF-HTTP-SUCCESS-P ...):  Our
# heuristics choose (HTTP-SUCCESS-P STATUS) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-HTTP-SUCCESS-P depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-HTTP-SUCCESS-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION HTTP-SUCCESS-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  BOOLEANP-OF-HTTP-SUCCESS-P

# %%
;; Call LLM chat completion API
;;
;; Parameters:
;;   model    - Model identifier string (e.g., "local-model")
;;   messages - Conversation history as chat-message-list
;;   state    - ACL2 state
;;
;; Returns: (mv error response state)
;;   error    - NIL on success, error string on failure
;;   response - Assistant's response content (stringp, empty on error)
;;   state    - Updated state
(defun llm-chat-completion (model messages state)
  (declare (xargs :guard (and (stringp model)
                              (chat-message-list-p messages))
                  :stobjs state
                  :guard-hints (("Goal" :in-theory (disable post-json)))))
  (b* (;; Serialize the request to JSON
       (request-json (serialize-chat-request model messages))
       
       ;; HTTP headers for JSON API
       (headers '(("Content-Type" . "application/json")
                  ("Accept" . "application/json")))
       
       ;; Make HTTP POST request with proper guards
       ((mv err response-body status-raw state)
        (post-json *lm-studio-endpoint*
                   request-json
                   headers
                   *llm-connect-timeout*
                   *llm-read-timeout*
                   state))
       
       ;; Coerce status to natp (it is, via theorem, but help guard verification)
       (status (mbe :logic (nfix status-raw) :exec status-raw))
       
       ;; Check for network/connection errors
       ((when err)
        (mv err "" state))
       
       ;; Check for HTTP error status
       ((unless (http-success-p status))
        (mv (concatenate 'string "HTTP error: status " 
                        (coerce (explode-nonnegative-integer status 10 nil) 'string))
            ""
            state))
       
       ;; Parse the response JSON to extract assistant content
       (content (parse-chat-response response-body)))
    
    (mv nil content state)))
# Out:
# Since LLM-CHAT-COMPLETION is non-recursive, its admission is trivial.
# We observe that the type of LLM-CHAT-COMPLETION is described by the
# theorem
# (AND (CONSP (LLM-CHAT-COMPLETION MODEL MESSAGES STATE))
#      (TRUE-LISTP (LLM-CHAT-COMPLETION MODEL MESSAGES STATE))).
# We used primitive type reasoning.
#
# (LLM-CHAT-COMPLETION * * STATE) => (MV * * STATE).
#
# Computing the guard conjecture for LLM-CHAT-COMPLETION....
#
# The non-trivial part of the guard conjecture for LLM-CHAT-COMPLETION,
# given the :executable-counterparts of NATP and PRINT-BASE-P, is
#
# Goal
# (IMPLIES
#  (AND (CHAT-MESSAGE-LIST-P MESSAGES)
#       (STRINGP MODEL)
#       (STATE-P STATE))
#  (LET* ((REQUEST-JSON (SERIALIZE-CHAT-REQUEST MODEL MESSAGES))
#         (HEADERS '(("Content-Type" . "application/json")
#                    ("Accept" . "application/json"))))
#   (AND
#    (ALISTP HEADERS)
#    (STRINGP REQUEST-JSON)
#    (MV-LET (ERR RESPONSE-BODY STATUS-RAW)
#            (POST-JSON "http://host.docker.internal:1234/v1/chat/completions"
#                       REQUEST-JSON HEADERS 30 120 STATE)
#     (AND
#      (EQUAL (NFIX STATUS-RAW) STATUS-RAW)
#      (LET ((STATUS (NFIX STATUS-RAW)))
#       (AND (OR ERR (NATP STATUS))
#            (OR ERR (NOT (HTTP-SUCCESS-P STATUS))
#                (STRINGP RESPONSE-BODY))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (INTEGERP STATUS))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (<= 0 STATUS))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (CHARACTER-LISTP (EXPLODE-NONNEGATIVE-INTEGER STATUS 10 NIL)))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (STRINGP (COERCE (EXPLODE-NONNEGATIVE-INTEGER STATUS 10 NIL)
#                                 'STRING)))))))))).
# Goal'
#
# Q.E.D.
#
# That completes the proof of the guard theorem for LLM-CHAT-COMPLETION.
# LLM-CHAT-COMPLETION is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-CHAT-COMPLETION ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION HTTP-SUCCESS-P)
#         (:DEFINITION NFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION SERIALIZE-CHAT-REQUEST)
#         (:DEFINITION STATE-P)
#         (:EXECUTABLE-COUNTERPART ALISTP)
#         (:EXECUTABLE-COUNTERPART CHARACTER-LISTP)
#         (:EXECUTABLE-COUNTERPART NATP)
#         (:EXECUTABLE-COUNTERPART PRINT-BASE-P)
#         (:EXECUTABLE-COUNTERPART STRINGP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE CHARACTER-LISTP-OF-EXPLODE-NONNEGATIVE-INTEGER)
#         (:REWRITE STR::COERCE-TO-STRING-REMOVAL)
#         (:TYPE-PRESCRIPTION NATP-OF-POST-JSON-STATUS)
#         (:TYPE-PRESCRIPTION STRINGP-OF-IMPLODE)
#         (:TYPE-PRESCRIPTION STRINGP-OF-POST-JSON-BODY))
# Time:  0.03 seconds (prove: 0.01, print: 0.00, other: 0.02)
# Prover steps counted:  682
#  LLM-CHAT-COMPLETION

# %%
;; Return type theorems for llm-chat-completion
(defthm stringp-of-llm-chat-completion-response
  (stringp (mv-nth 1 (llm-chat-completion model messages state))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-LLM-CHAT-COMPLETION-RESPONSE
# ...):  A :REWRITE rule generated from STRINGP-OF-LLM-CHAT-COMPLETION-RESPONSE
# will be triggered only by terms containing the function symbol
# LLM-CHAT-COMPLETION, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Splitter note (see :DOC splitter) for Goal (12 subgoals).
#   if-intro: ((:DEFINITION LLM-CHAT-COMPLETION)
#              (:DEFINITION NATP)
#              (:DEFINITION POST-JSON))
#
# Subgoal 12
# Subgoal 12'
# Subgoal 11
# Subgoal 11'
# Subgoal 10
# Subgoal 10'
# Subgoal 9
# Subgoal 9'
# Subgoal 8
# Subgoal 8'
# Subgoal 7
# Subgoal 7'
# Subgoal 6
# Subgoal 6'
# Subgoal 5
# Subgoal 5'
# Subgoal 4
# Subgoal 4'
# Subgoal 3
# Subgoal 3'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-LLM-CHAT-COMPLETION-RESPONSE ...)
# Rules: ((:DEFINITION LLM-CHAT-COMPLETION)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION PARSE-CHAT-RESPONSE)
#         (:DEFINITION POST-JSON)
#         (:DEFINITION SERIALIZE-CHAT-REQUEST)
#         (:DEFINITION STRING-APPEND)
#         (:EXECUTABLE-COUNTERPART COERCE)
#         (:REWRITE APPEND-OF-CONS)
#         (:REWRITE STR::COERCE-TO-LIST-REMOVAL)
#         (:REWRITE STR::COERCE-TO-STRING-REMOVAL))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION LLM-CHAT-COMPLETION)
#              (:DEFINITION NATP)
#              (:DEFINITION POST-JSON))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  3232
#  STRINGP-OF-LLM-CHAT-COMPLETION-RESPONSE

# %%
(defthm state-p1-of-llm-chat-completion
  (implies (state-p1 state)
           (state-p1 (mv-nth 2 (llm-chat-completion model messages state)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STATE-P1-OF-LLM-CHAT-COMPLETION
# ...):  A :REWRITE rule generated from STATE-P1-OF-LLM-CHAT-COMPLETION
# will be triggered only by terms containing the function symbol
# LLM-CHAT-COMPLETION, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Splitter note (see :DOC splitter) for Goal (12 subgoals).
#   if-intro: ((:DEFINITION LLM-CHAT-COMPLETION)
#              (:DEFINITION NATP)
#              (:DEFINITION POST-JSON))
#
# Subgoal 12
# Subgoal 12'
# Subgoal 11
# Subgoal 11'
# Subgoal 10
# Subgoal 10'
# Subgoal 9
# Subgoal 9'
# Subgoal 8
# Subgoal 8'
# Subgoal 7
# Subgoal 7'
# Subgoal 6
# Subgoal 6'
# Subgoal 6''
# Subgoal 5
# Subgoal 5'
# Subgoal 5''
# Subgoal 4
# Subgoal 4'
# Subgoal 3
# Subgoal 3'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# The storage of STATE-P1-OF-LLM-CHAT-COMPLETION depends upon the :type-
# prescription rule STATE-P1.
#
# Summary
# Form:  ( DEFTHM STATE-P1-OF-LLM-CHAT-COMPLETION ...)
# Rules: ((:CONGRUENCE STR::CHARLISTEQV-IMPLIES-CHARLISTEQV-APPEND-2)
#         (:DEFINITION HTTP-SUCCESS-P)
#         (:DEFINITION LLM-CHAT-COMPLETION)
#         (:DEFINITION MV-NTH)
#         (:DEFINITION NATP)
#         (:DEFINITION NFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION PARSE-CHAT-RESPONSE)
#         (:DEFINITION POST-JSON)
#         (:DEFINITION SERIALIZE-CHAT-REQUEST)
#         (:DEFINITION STRING-APPEND)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART BINARY-APPEND)
#         (:EXECUTABLE-COUNTERPART COERCE)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART EXPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART EXPLODE-NONNEGATIVE-INTEGER)
#         (:EXECUTABLE-COUNTERPART HTTP-SUCCESS-P)
#         (:EXECUTABLE-COUNTERPART IMPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART NFIX)
#         (:EXECUTABLE-COUNTERPART TRUE-LISTP)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:REWRITE APPEND-OF-CONS)
#         (:REWRITE APPEND-WHEN-NOT-CONSP)
#         (:REWRITE STR::COERCE-TO-LIST-REMOVAL)
#         (:REWRITE STR::COERCE-TO-STRING-REMOVAL)
#         (:REWRITE STR::EXPLODE-OF-IMPLODE)
#         (:REWRITE STR::MAKE-CHARACTER-LIST-IS-IDENTITY-UNDER-CHARLISTEQV)
#         (:REWRITE MV-NTH-OF-CONS)
#         (:REWRITE STATE-P1-READ-ACL2-ORACLE)
#         (:TYPE-PRESCRIPTION EXPLODE-NONNEGATIVE-INTEGER)
#         (:TYPE-PRESCRIPTION STATE-P1)
#         (:TYPE-PRESCRIPTION TRUE-LISTP-OF-EXPLODE-NONNEGATIVE-INTEGER-TYPE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION LLM-CHAT-COMPLETION)
#              (:DEFINITION NATP)
#              (:DEFINITION POST-JSON))
# Warnings:  Non-rec
# Time:  0.05 seconds (prove: 0.04, print: 0.00, other: 0.00)
# Prover steps counted:  7904
#  STATE-P1-OF-LLM-CHAT-COMPLETION

# %%
;; List available models from LLM server
;;
;; Parameters:
;;   state - ACL2 state
;;
;; Returns: (mv error models state)
;;   error  - NIL on success, error string on failure
;;   models - List of model ID strings (string-listp)
;;   state  - Updated state
(defun llm-list-models (state)
  (declare (xargs :stobjs state))
  (b* (;; HTTP headers for JSON API
       (headers '(("Accept" . "application/json")))
       
       ;; Make HTTP GET request
       ((mv err response-body status-raw state)
        (get-json *lm-studio-models-endpoint*
                  headers
                  *llm-connect-timeout*
                  *llm-read-timeout*
                  state))
       
       ;; Coerce status to natp
       (status (mbe :logic (nfix status-raw) :exec status-raw))
       
       ;; Check for network/connection errors
       ((when err)
        (mv err nil state))
       
       ;; Check for HTTP error status
       ((unless (http-success-p status))
        (mv (concatenate 'string "HTTP error: status " 
                        (coerce (explode-nonnegative-integer status 10 nil) 'string))
            nil
            state))
       
       ;; Parse the response JSON to extract model list
       (models (parse-models-response response-body)))
    
    (mv nil models state)))
# Out:
# Since LLM-LIST-MODELS is non-recursive, its admission is trivial.
# We observe that the type of LLM-LIST-MODELS is described by the theorem
# (AND (CONSP (LLM-LIST-MODELS STATE)) (TRUE-LISTP (LLM-LIST-MODELS STATE))).
# We used primitive type reasoning and the :type-prescription rule
# PARSE-MODELS-RESPONSE.
#
# (LLM-LIST-MODELS STATE) => (MV * * STATE).
#
# Computing the guard conjecture for LLM-LIST-MODELS....
#
# The non-trivial part of the guard conjecture for LLM-LIST-MODELS, given
# the :executable-counterparts of NATP and PRINT-BASE-P, is
#
# Goal
# (IMPLIES
#  (STATE-P STATE)
#  (LET ((HEADERS '(("Accept" . "application/json"))))
#   (AND
#    (ALISTP HEADERS)
#    (MV-LET (ERR RESPONSE-BODY STATUS-RAW)
#            (GET-JSON "http://host.docker.internal:1234/v1/models"
#                      HEADERS 30 120 STATE)
#     (AND
#      (EQUAL (NFIX STATUS-RAW) STATUS-RAW)
#      (LET ((STATUS (NFIX STATUS-RAW)))
#       (AND (OR ERR (NATP STATUS))
#            (OR ERR (NOT (HTTP-SUCCESS-P STATUS))
#                (STRINGP RESPONSE-BODY))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (INTEGERP STATUS))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (<= 0 STATUS))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (CHARACTER-LISTP (EXPLODE-NONNEGATIVE-INTEGER STATUS 10 NIL)))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (STRINGP (COERCE (EXPLODE-NONNEGATIVE-INTEGER STATUS 10 NIL)
#                                 'STRING)))))))))).
# Goal'
#
# Splitter note (see :DOC splitter) for Goal' (12 subgoals).
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION NATP))
#
# Subgoal 12
# Subgoal 11
# Subgoal 10
# Subgoal 9
# Subgoal 8
# Subgoal 7
# Subgoal 6
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the guard theorem for LLM-LIST-MODELS.
# LLM-LIST-MODELS is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-LIST-MODELS ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION GET-JSON)
#         (:DEFINITION HTTP-SUCCESS-P)
#         (:DEFINITION MV-NTH)
#         (:DEFINITION NATP)
#         (:DEFINITION NFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION STATE-P)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART ALISTP)
#         (:EXECUTABLE-COUNTERPART CHARACTER-LISTP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART EXPLODE-NONNEGATIVE-INTEGER)
#         (:EXECUTABLE-COUNTERPART HTTP-SUCCESS-P)
#         (:EXECUTABLE-COUNTERPART IMPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART NATP)
#         (:EXECUTABLE-COUNTERPART NFIX)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART PRINT-BASE-P)
#         (:EXECUTABLE-COUNTERPART STRINGP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE CHARACTER-LISTP-OF-EXPLODE-NONNEGATIVE-INTEGER)
#         (:REWRITE STR::COERCE-TO-STRING-REMOVAL)
#         (:TYPE-PRESCRIPTION PARSE-MODELS-RESPONSE)
#         (:TYPE-PRESCRIPTION STRINGP-OF-IMPLODE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION NATP))
# Time:  0.04 seconds (prove: 0.03, print: 0.00, other: 0.01)
# Prover steps counted:  4324
#  LLM-LIST-MODELS

# %%
;; Return type theorems for llm-list-models
(defthm string-listp-of-llm-list-models-models
  (string-listp (mv-nth 1 (llm-list-models state))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STRING-LISTP-OF-LLM-LIST-MODELS-MODELS
# ...):  A :REWRITE rule generated from STRING-LISTP-OF-LLM-LIST-MODELS-MODELS
# will be triggered only by terms containing the function symbol
# LLM-LIST-MODELS, which has a non-recursive definition.  Unless this
# definition is disabled, this rule is unlikely ever to be used.
#
#
# Splitter note (see :DOC splitter) for Goal (12 subgoals).
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION LLM-LIST-MODELS)
#              (:DEFINITION NATP))
#
# Subgoal 12
# Subgoal 12'
# Subgoal 11
# Subgoal 11'
# Subgoal 10
# Subgoal 10'
# Subgoal 9
# Subgoal 9'
# Subgoal 8
# Subgoal 8'
# Subgoal 7
# Subgoal 7'
# Subgoal 6
# Subgoal 6'
# Subgoal 6''
# Subgoal 5
# Subgoal 5'
# Subgoal 5''
# Subgoal 4
# Subgoal 4'
# Subgoal 3
# Subgoal 3'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# The storage of STRING-LISTP-OF-LLM-LIST-MODELS-MODELS depends upon
# the :type-prescription rule STRING-LISTP.
#
# Summary
# Form:  ( DEFTHM STRING-LISTP-OF-LLM-LIST-MODELS-MODELS ...)
# Rules: ((:CONGRUENCE STR::CHARLISTEQV-IMPLIES-CHARLISTEQV-APPEND-2)
#         (:DEFINITION GET-JSON)
#         (:DEFINITION HTTP-SUCCESS-P)
#         (:DEFINITION LLM-LIST-MODELS)
#         (:DEFINITION MV-NTH)
#         (:DEFINITION NATP)
#         (:DEFINITION NFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION STRING-APPEND)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART BINARY-APPEND)
#         (:EXECUTABLE-COUNTERPART COERCE)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART EXPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART EXPLODE-NONNEGATIVE-INTEGER)
#         (:EXECUTABLE-COUNTERPART HTTP-SUCCESS-P)
#         (:EXECUTABLE-COUNTERPART IMPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART NFIX)
#         (:EXECUTABLE-COUNTERPART STRING-LISTP)
#         (:EXECUTABLE-COUNTERPART TRUE-LISTP)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:REWRITE APPEND-OF-CONS)
#         (:REWRITE APPEND-WHEN-NOT-CONSP)
#         (:REWRITE STR::COERCE-TO-LIST-REMOVAL)
#         (:REWRITE STR::COERCE-TO-STRING-REMOVAL)
#         (:REWRITE STR::EXPLODE-OF-IMPLODE)
#         (:REWRITE STR::MAKE-CHARACTER-LIST-IS-IDENTITY-UNDER-CHARLISTEQV)
#         (:REWRITE MV-NTH-OF-CONS)
#         (:TYPE-PRESCRIPTION EXPLODE-NONNEGATIVE-INTEGER)
#         (:TYPE-PRESCRIPTION STRING-LISTP)
#         (:TYPE-PRESCRIPTION TRUE-LISTP-OF-EXPLODE-NONNEGATIVE-INTEGER-TYPE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION LLM-LIST-MODELS)
#              (:DEFINITION NATP))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  7209
#  STRING-LISTP-OF-LLM-LIST-MODELS-MODELS

# %%
(defthm state-p1-of-llm-list-models
  (implies (state-p1 state)
           (state-p1 (mv-nth 2 (llm-list-models state)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STATE-P1-OF-LLM-LIST-MODELS ...):
# A :REWRITE rule generated from STATE-P1-OF-LLM-LIST-MODELS will be
# triggered only by terms containing the function symbol LLM-LIST-MODELS,
# which has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Splitter note (see :DOC splitter) for Goal (12 subgoals).
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION LLM-LIST-MODELS)
#              (:DEFINITION NATP))
#
# Subgoal 12
# Subgoal 12'
# Subgoal 11
# Subgoal 11'
# Subgoal 10
# Subgoal 10'
# Subgoal 9
# Subgoal 9'
# Subgoal 8
# Subgoal 8'
# Subgoal 7
# Subgoal 7'
# Subgoal 6
# Subgoal 6'
# Subgoal 6''
# Subgoal 5
# Subgoal 5'
# Subgoal 5''
# Subgoal 4
# Subgoal 4'
# Subgoal 3
# Subgoal 3'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# The storage of STATE-P1-OF-LLM-LIST-MODELS depends upon the :type-
# prescription rule STATE-P1.
#
# Summary
# Form:  ( DEFTHM STATE-P1-OF-LLM-LIST-MODELS ...)
# Rules: ((:CONGRUENCE STR::CHARLISTEQV-IMPLIES-CHARLISTEQV-APPEND-2)
#         (:DEFINITION GET-JSON)
#         (:DEFINITION HTTP-SUCCESS-P)
#         (:DEFINITION LLM-LIST-MODELS)
#         (:DEFINITION MV-NTH)
#         (:DEFINITION NATP)
#         (:DEFINITION NFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION STRING-APPEND)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART BINARY-APPEND)
#         (:EXECUTABLE-COUNTERPART COERCE)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART EXPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART EXPLODE-NONNEGATIVE-INTEGER)
#         (:EXECUTABLE-COUNTERPART HTTP-SUCCESS-P)
#         (:EXECUTABLE-COUNTERPART IMPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART NFIX)
#         (:EXECUTABLE-COUNTERPART TRUE-LISTP)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:REWRITE APPEND-OF-CONS)
#         (:REWRITE APPEND-WHEN-NOT-CONSP)
#         (:REWRITE STR::COERCE-TO-LIST-REMOVAL)
#         (:REWRITE STR::COERCE-TO-STRING-REMOVAL)
#         (:REWRITE STR::EXPLODE-OF-IMPLODE)
#         (:REWRITE STR::MAKE-CHARACTER-LIST-IS-IDENTITY-UNDER-CHARLISTEQV)
#         (:REWRITE MV-NTH-OF-CONS)
#         (:REWRITE STATE-P1-READ-ACL2-ORACLE)
#         (:TYPE-PRESCRIPTION EXPLODE-NONNEGATIVE-INTEGER)
#         (:TYPE-PRESCRIPTION STATE-P1)
#         (:TYPE-PRESCRIPTION TRUE-LISTP-OF-EXPLODE-NONNEGATIVE-INTEGER-TYPE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION LLM-LIST-MODELS)
#              (:DEFINITION NATP))
# Warnings:  Non-rec
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Prover steps counted:  7866
#  STATE-P1-OF-LLM-LIST-MODELS

# %%
;; List available models with full info from LM Studio v0 API
;;
;; Parameters:
;;   state - ACL2 state
;;
;; Returns: (mv error models state)
;;   error  - NIL on success, error string on failure
;;   models - List of model-info-p with full details
;;   state  - Updated state
(defun llm-list-models-full (state)
  (declare (xargs :stobjs state))
  (b* (;; HTTP headers for JSON API
       (headers '(("Accept" . "application/json")))
       
       ;; Make HTTP GET request to v0 API
       ((mv err response-body status-raw state)
        (get-json *lm-studio-v0-models-endpoint*
                  headers
                  *llm-connect-timeout*
                  *llm-read-timeout*
                  state))
       
       ;; Coerce status to natp
       (status (mbe :logic (nfix status-raw) :exec status-raw))
       
       ;; Check for network/connection errors
       ((when err)
        (mv err nil state))
       
       ;; Check for HTTP error status
       ((unless (http-success-p status))
        (mv (concatenate 'string "HTTP error: status " 
                        (coerce (explode-nonnegative-integer status 10 nil) 'string))
            nil
            state))
       
       ;; Parse the response JSON to extract full model info
       (models (parse-v0-models-response response-body)))
    
    (mv nil models state)))
# Out:
# Since LLM-LIST-MODELS-FULL is non-recursive, its admission is trivial.
# We observe that the type of LLM-LIST-MODELS-FULL is described by the
# theorem
# (AND (CONSP (LLM-LIST-MODELS-FULL STATE))
#      (TRUE-LISTP (LLM-LIST-MODELS-FULL STATE))).
# We used primitive type reasoning and the :type-prescription rule
# PARSE-V0-MODELS-RESPONSE.
#
# (LLM-LIST-MODELS-FULL STATE) => (MV * * STATE).
#
# Computing the guard conjecture for LLM-LIST-MODELS-FULL....
#
# The non-trivial part of the guard conjecture for LLM-LIST-MODELS-FULL,
# given the :executable-counterparts of NATP and PRINT-BASE-P, is
#
# Goal
# (IMPLIES
#  (STATE-P STATE)
#  (LET ((HEADERS '(("Accept" . "application/json"))))
#   (AND
#    (ALISTP HEADERS)
#    (MV-LET (ERR RESPONSE-BODY STATUS-RAW)
#            (GET-JSON "http://host.docker.internal:1234/api/v0/models"
#                      HEADERS 30 120 STATE)
#     (AND
#      (EQUAL (NFIX STATUS-RAW) STATUS-RAW)
#      (LET ((STATUS (NFIX STATUS-RAW)))
#       (AND (OR ERR (NATP STATUS))
#            (OR ERR (NOT (HTTP-SUCCESS-P STATUS))
#                (STRINGP RESPONSE-BODY))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (INTEGERP STATUS))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (<= 0 STATUS))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (CHARACTER-LISTP (EXPLODE-NONNEGATIVE-INTEGER STATUS 10 NIL)))
#            (OR ERR (HTTP-SUCCESS-P STATUS)
#                (STRINGP (COERCE (EXPLODE-NONNEGATIVE-INTEGER STATUS 10 NIL)
#                                 'STRING)))))))))).
# Goal'
#
# Splitter note (see :DOC splitter) for Goal' (12 subgoals).
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION NATP))
#
# Subgoal 12
# Subgoal 11
# Subgoal 10
# Subgoal 9
# Subgoal 8
# Subgoal 7
# Subgoal 6
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the guard theorem for LLM-LIST-MODELS-FULL.
# LLM-LIST-MODELS-FULL is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-LIST-MODELS-FULL ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION GET-JSON)
#         (:DEFINITION HTTP-SUCCESS-P)
#         (:DEFINITION MV-NTH)
#         (:DEFINITION NATP)
#         (:DEFINITION NFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION STATE-P)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART ALISTP)
#         (:EXECUTABLE-COUNTERPART CHARACTER-LISTP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART EXPLODE-NONNEGATIVE-INTEGER)
#         (:EXECUTABLE-COUNTERPART HTTP-SUCCESS-P)
#         (:EXECUTABLE-COUNTERPART IMPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART NATP)
#         (:EXECUTABLE-COUNTERPART NFIX)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART PRINT-BASE-P)
#         (:EXECUTABLE-COUNTERPART STRINGP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE CHARACTER-LISTP-OF-EXPLODE-NONNEGATIVE-INTEGER)
#         (:REWRITE STR::COERCE-TO-STRING-REMOVAL)
#         (:TYPE-PRESCRIPTION PARSE-V0-MODELS-RESPONSE)
#         (:TYPE-PRESCRIPTION STRINGP-OF-IMPLODE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION NATP))
# Time:  0.04 seconds (prove: 0.04, print: 0.00, other: 0.01)
# Prover steps counted:  4324
#  LLM-LIST-MODELS-FULL

# %%
;; Return type theorems for llm-list-models-full
(defthm model-info-list-p-of-llm-list-models-full-models
  (model-info-list-p (mv-nth 1 (llm-list-models-full state))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM
# MODEL-INFO-LIST-P-OF-LLM-LIST-MODELS-FULL-MODELS ...):  A :REWRITE
# rule generated from MODEL-INFO-LIST-P-OF-LLM-LIST-MODELS-FULL-MODELS
# will be triggered only by terms containing the function symbol
# LLM-LIST-MODELS-FULL, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Splitter note (see :DOC splitter) for Goal (12 subgoals).
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION LLM-LIST-MODELS-FULL)
#              (:DEFINITION NATP))
#
# Subgoal 12
# Subgoal 12'
# Subgoal 11
# Subgoal 11'
# Subgoal 10
# Subgoal 10'
# Subgoal 9
# Subgoal 9'
# Subgoal 8
# Subgoal 8'
# Subgoal 7
# Subgoal 7'
# Subgoal 6
# Subgoal 6'
# Subgoal 6''
# Subgoal 5
# Subgoal 5'
# Subgoal 5''
# Subgoal 4
# Subgoal 4'
# Subgoal 3
# Subgoal 3'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# The storage of MODEL-INFO-LIST-P-OF-LLM-LIST-MODELS-FULL-MODELS depends
# upon the :compound-recognizer rule
# TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER and the :type-
# prescription rule MODEL-INFO-LIST-P.
#
# Summary
# Form:  ( DEFTHM MODEL-INFO-LIST-P-OF-LLM-LIST-MODELS-FULL-MODELS ...)
# Rules: ((:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER)
#         (:CONGRUENCE STR::CHARLISTEQV-IMPLIES-CHARLISTEQV-APPEND-2)
#         (:DEFINITION GET-JSON)
#         (:DEFINITION HTTP-SUCCESS-P)
#         (:DEFINITION LLM-LIST-MODELS-FULL)
#         (:DEFINITION MV-NTH)
#         (:DEFINITION NATP)
#         (:DEFINITION NFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION STRING-APPEND)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART BINARY-APPEND)
#         (:EXECUTABLE-COUNTERPART COERCE)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART EXPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART EXPLODE-NONNEGATIVE-INTEGER)
#         (:EXECUTABLE-COUNTERPART HTTP-SUCCESS-P)
#         (:EXECUTABLE-COUNTERPART IMPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART MODEL-INFO-LIST-P)
#         (:EXECUTABLE-COUNTERPART NFIX)
#         (:EXECUTABLE-COUNTERPART TRUE-LISTP)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:REWRITE APPEND-OF-CONS)
#         (:REWRITE APPEND-WHEN-NOT-CONSP)
#         (:REWRITE STR::COERCE-TO-LIST-REMOVAL)
#         (:REWRITE STR::COERCE-TO-STRING-REMOVAL)
#         (:REWRITE STR::EXPLODE-OF-IMPLODE)
#         (:REWRITE STR::MAKE-CHARACTER-LIST-IS-IDENTITY-UNDER-CHARLISTEQV)
#         (:REWRITE MV-NTH-OF-CONS)
#         (:TYPE-PRESCRIPTION EXPLODE-NONNEGATIVE-INTEGER)
#         (:TYPE-PRESCRIPTION MODEL-INFO-LIST-P)
#         (:TYPE-PRESCRIPTION TRUE-LISTP-OF-EXPLODE-NONNEGATIVE-INTEGER-TYPE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION LLM-LIST-MODELS-FULL)
#              (:DEFINITION NATP))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  7173
#  MODEL-INFO-LIST-P-OF-LLM-LIST-MODELS-FULL-MODELS

# %%
(defthm state-p1-of-llm-list-models-full
  (implies (state-p1 state)
           (state-p1 (mv-nth 2 (llm-list-models-full state)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STATE-P1-OF-LLM-LIST-MODELS-FULL
# ...):  A :REWRITE rule generated from STATE-P1-OF-LLM-LIST-MODELS-FULL
# will be triggered only by terms containing the function symbol
# LLM-LIST-MODELS-FULL, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Splitter note (see :DOC splitter) for Goal (12 subgoals).
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION LLM-LIST-MODELS-FULL)
#              (:DEFINITION NATP))
#
# Subgoal 12
# Subgoal 12'
# Subgoal 11
# Subgoal 11'
# Subgoal 10
# Subgoal 10'
# Subgoal 9
# Subgoal 9'
# Subgoal 8
# Subgoal 8'
# Subgoal 7
# Subgoal 7'
# Subgoal 6
# Subgoal 6'
# Subgoal 6''
# Subgoal 5
# Subgoal 5'
# Subgoal 5''
# Subgoal 4
# Subgoal 4'
# Subgoal 3
# Subgoal 3'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# The storage of STATE-P1-OF-LLM-LIST-MODELS-FULL depends upon the :type-
# prescription rule STATE-P1.
#
# Summary
# Form:  ( DEFTHM STATE-P1-OF-LLM-LIST-MODELS-FULL ...)
# Rules: ((:CONGRUENCE STR::CHARLISTEQV-IMPLIES-CHARLISTEQV-APPEND-2)
#         (:DEFINITION GET-JSON)
#         (:DEFINITION HTTP-SUCCESS-P)
#         (:DEFINITION LLM-LIST-MODELS-FULL)
#         (:DEFINITION MV-NTH)
#         (:DEFINITION NATP)
#         (:DEFINITION NFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION STRING-APPEND)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART BINARY-APPEND)
#         (:EXECUTABLE-COUNTERPART COERCE)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART EXPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART EXPLODE-NONNEGATIVE-INTEGER)
#         (:EXECUTABLE-COUNTERPART HTTP-SUCCESS-P)
#         (:EXECUTABLE-COUNTERPART IMPLODE$INLINE)
#         (:EXECUTABLE-COUNTERPART NFIX)
#         (:EXECUTABLE-COUNTERPART TRUE-LISTP)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:REWRITE APPEND-OF-CONS)
#         (:REWRITE APPEND-WHEN-NOT-CONSP)
#         (:REWRITE STR::COERCE-TO-LIST-REMOVAL)
#         (:REWRITE STR::COERCE-TO-STRING-REMOVAL)
#         (:REWRITE STR::EXPLODE-OF-IMPLODE)
#         (:REWRITE STR::MAKE-CHARACTER-LIST-IS-IDENTITY-UNDER-CHARLISTEQV)
#         (:REWRITE MV-NTH-OF-CONS)
#         (:REWRITE STATE-P1-READ-ACL2-ORACLE)
#         (:TYPE-PRESCRIPTION EXPLODE-NONNEGATIVE-INTEGER)
#         (:TYPE-PRESCRIPTION STATE-P1)
#         (:TYPE-PRESCRIPTION TRUE-LISTP-OF-EXPLODE-NONNEGATIVE-INTEGER-TYPE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION GET-JSON)
#              (:DEFINITION LLM-LIST-MODELS-FULL)
#              (:DEFINITION NATP))
# Warnings:  Non-rec
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Prover steps counted:  7866
#  STATE-P1-OF-LLM-LIST-MODELS-FULL

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Model Selection
# ;;
# ;; Select the best model from available models based on preferences.
# ;; Default: first loaded completions model that matches any preference string.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Check if model ID contains a preference substring (case-insensitive would be 
;; nice but we'll do exact substring for now)
(defun model-matches-pref-p (model-id pref)
  (declare (xargs :guard (and (stringp model-id) (stringp pref))))
  (search pref model-id))
# Out:
# Since MODEL-MATCHES-PREF-P is non-recursive, its admission is trivial.
# We observe that the type of MODEL-MATCHES-PREF-P is described by the
# theorem
# (OR (INTEGERP (MODEL-MATCHES-PREF-P MODEL-ID PREF))
#     (EQUAL (MODEL-MATCHES-PREF-P MODEL-ID PREF)
#            NIL)).
# We used the :type-prescription rule SEARCH-FN.
#
# Computing the guard conjecture for MODEL-MATCHES-PREF-P....
#
# The non-trivial part of the guard conjecture for MODEL-MATCHES-PREF-P
# is
#
# Goal
# (IMPLIES (AND (STRINGP PREF) (STRINGP MODEL-ID))
#          (SEARCH-FN-GUARD PREF MODEL-ID NIL 'EQUAL
#                           0 0 NIL NIL NIL NIL)).
# Goal'
#
# Splitter note (see :DOC splitter) for Goal' (2 subgoals).
#   if-intro: ((:DEFINITION SEARCH-FN-GUARD))
#
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the guard theorem for MODEL-MATCHES-PREF-P.
# MODEL-MATCHES-PREF-P is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MODEL-MATCHES-PREF-P ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION LENGTH)
#         (:DEFINITION NOT)
#         (:DEFINITION SEARCH-FN-GUARD)
#         (:EXECUTABLE-COUNTERPART MEMBER-EQUAL)
#         (:EXECUTABLE-COUNTERPART NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE STR::COERCE-TO-LIST-REMOVAL)
#         (:TYPE-PRESCRIPTION LEN)
#         (:TYPE-PRESCRIPTION SEARCH-FN))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION SEARCH-FN-GUARD))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  361
#  MODEL-MATCHES-PREF-P

# %%
;; Find first model matching any of the preferences
;; Implementation in raw Lisp uses LOOP for efficiency
(defun find-matching-model (models prefs)
  (declare (xargs :guard (and (model-info-list-p models)
                              (string-listp prefs)))
           (ignore models prefs))
  (prog2$ (er hard? 'find-matching-model "Raw Lisp definition not installed?")
          nil))
# Out:
# Since FIND-MATCHING-MODEL is non-recursive, its admission is trivial.
# We observe that the type of FIND-MATCHING-MODEL is described by the
# theorem (EQUAL (FIND-MATCHING-MODEL MODELS PREFS) NIL).
#
# Computing the guard conjecture for FIND-MATCHING-MODEL....
#
# The guard conjecture for FIND-MATCHING-MODEL is trivial to prove.
# FIND-MATCHING-MODEL is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN FIND-MATCHING-MODEL ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  FIND-MATCHING-MODEL

# %%
;; Select best model for completions
;;
;; Parameters:
;;   models - Full model info list from llm-list-models-full
;;   prefs  - List of preference strings to match (partial match on model ID)
;;
;; Returns: model-info-p or nil if no suitable model found
;;
;; Selection order:
;; 1. First loaded completions model matching a preference (in pref order)
;; 2. First loaded completions model (if no prefs or no match)
;; 3. NIL if no loaded completions models
(defun select-completions-model (models prefs)
  (declare (xargs :guard (and (model-info-list-p models)
                              (string-listp prefs)))
           (ignore models prefs))
  (prog2$ (er hard? 'select-completions-model "Raw Lisp definition not installed?")
          nil))
# Out:
# Since SELECT-COMPLETIONS-MODEL is non-recursive, its admission is trivial.
# We observe that the type of SELECT-COMPLETIONS-MODEL is described by
# the theorem (EQUAL (SELECT-COMPLETIONS-MODEL MODELS PREFS) NIL).
#
# Computing the guard conjecture for SELECT-COMPLETIONS-MODEL....
#
# The guard conjecture for SELECT-COMPLETIONS-MODEL is trivial to prove.
# SELECT-COMPLETIONS-MODEL is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SELECT-COMPLETIONS-MODEL ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  SELECT-COMPLETIONS-MODEL

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Trust tag and raw Lisp inclusion for serialization functions
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(defttag :llm-client)
(include-raw "llm-client-raw.lsp"
             :host-readtable t)
# Out:
# TTAG NOTE: Adding ttag :LLM-CLIENT from the top level loop.
#  :LLM-CLIENT
#
#
# ACL2 !>>(PROGN!
#          (SET-RAW-MODE T)
#          (DEFUN RAW-COMPILE (NAME ERROR-ON-FAIL ON-FAIL STATE)
#           (COND
#            ((NOT (MEMBER :CLTL2 *FEATURES*))
#             (COMPILE-FILE (EXTEND-PATHNAME (CBD) NAME STATE)))
#            (T
#             (HANDLER-CASE
#              (COMPILE-FILE (EXTEND-PATHNAME (CBD) NAME STATE))
#              (ERROR
#               (CONDITION)
#               (IF ERROR-ON-FAIL
#                (LET ((CONDITION-STR (FORMAT NIL "~a" CONDITION)))
#                 (ER
#                  HARD 'INCLUDE-RAW
#                  "Compilation of ~x0 failed with the following message:~%~@1~%"
#                  NAME CONDITION-STR))
#                (EVAL
#                 (CONS
#                   'LET
#                   (CONS (CONS (CONS 'CONDITION
#                                     (CONS (CONS 'QUOTE (CONS CONDITION 'NIL))
#                                           'NIL))
#                               'NIL)
#                         (CONS '(DECLARE (IGNORABLE CONDITION))
#                               (CONS ON-FAIL 'NIL))))))))
#             NIL)))
#          (DEFUN RAW-LOAD-UNCOMPILED (NAME ERROR-ON-FAIL ON-FAIL STATE)
#           (COND
#            ((NOT (MEMBER :CLTL2 *FEATURES*))
#             (LOAD (EXTEND-PATHNAME (CBD) NAME STATE)))
#            (T
#             (HANDLER-CASE
#              (LOAD (EXTEND-PATHNAME (CBD) NAME STATE))
#              (ERROR
#               (CONDITION)
#               (IF ERROR-ON-FAIL
#                (LET ((CONDITION-STR (FORMAT NIL "~a" CONDITION)))
#                  (ER HARD 'INCLUDE-RAW
#                      "Load of ~x0 failed with the following message:~%~@1~%"
#                      NAME CONDITION-STR))
#                (EVAL
#                 (CONS
#                   'LET
#                   (CONS (CONS (CONS 'CONDITION
#                                     (CONS (CONS 'QUOTE (CONS CONDITION 'NIL))
#                                           'NIL))
#                               'NIL)
#                         (CONS '(DECLARE (IGNORABLE CONDITION))
#                               (CONS ON-FAIL 'NIL))))))))
#             NIL)))
#          (DEFUN RAW-LOAD (NAME ERROR-ON-FAIL ON-FAIL STATE)
#           (LET* ((FNAME (EXTEND-PATHNAME (CBD) NAME STATE))
#                  (COMPILED-FNAME (COMPILE-FILE-PATHNAME FNAME))
#                  (SRC-DATE (OUR-IGNORE-ERRORS (FILE-WRITE-DATE FNAME)))
#                  (COMPILED-DATE
#                       (OUR-IGNORE-ERRORS (FILE-WRITE-DATE COMPILED-FNAME))))
#            (COND
#             ((AND SRC-DATE COMPILED-DATE
#                   (< COMPILED-DATE SRC-DATE))
#              (FORMAT
#               T
#               "Include-raw Warning: source file is newer than compiled file, loading uncompiled ~a~%"
#               FNAME)
#              (RAW-LOAD-UNCOMPILED NAME ERROR-ON-FAIL ON-FAIL STATE))
#             ((NOT (MEMBER :CLTL2 *FEATURES*))
#              (COND
#               ((PROBE-FILE COMPILED-FNAME)
#                (LOAD-COMPILED COMPILED-FNAME))
#               (T
#                (FORMAT
#                 T
#                 "Include-raw Warning: compiled file does not exist; loading uncompiled ~a~%"
#                 FNAME)
#                (RAW-LOAD-UNCOMPILED NAME ERROR-ON-FAIL ON-FAIL STATE))))
#             (T
#              (HANDLER-CASE
#               (LOAD-COMPILED COMPILED-FNAME)
#               (ERROR
#                (CONDITION)
#                (PROGN
#                 (FORMAT
#                  T
#                  "Include-raw Warning: compiled file failed to load; loading uncompiled ~a~%Details: ~a~%"
#                  FNAME CONDITION)
#                 (RAW-LOAD-UNCOMPILED NAME ERROR-ON-FAIL ON-FAIL STATE))))))
#            NIL)))
#
# Summary
# Form:  ( PROGN! (SET-RAW-MODE T) ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# NIL
#
#
# ACL2 !>>(MAKE-EVENT
#           (MV-LET
#               (ERP VAL STATE)
#               (PROGN! (SET-RAW-MODE T)
#                       (LET ((*READTABLE* (IF T *HOST-READTABLE*
#                                            *ACL2-READTABLE*)))
#                         (IF (OR (NOT (F-GET-GLOBAL 'CERTIFY-BOOK-INFO STATE))
#                                 NIL)
#                             (MV NIL NIL STATE)
#                           (RAW-COMPILE "llm-client-raw.lsp" T 'NIL
#                                        STATE))))
#             (DECLARE (IGNORE ERP VAL))
#             (VALUE '(VALUE-TRIPLE :INVISIBLE))))
#
# Summary
# Form:  ( PROGN! (SET-RAW-MODE T) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Summary
# Form:  ( MAKE-EVENT (MV-LET ...))
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# :INVISIBLE
#
#
# ACL2 !>>(PROGN!
#          (SET-RAW-MODE T)
#          (LET ((*READTABLE* (IF T *HOST-READTABLE*
#                               *ACL2-READTABLE*)))
#            (WHEN (NULL *HCOMP-FN-MACRO-RESTORE-HT*)
#                  (EXTEND-WITH-RAW-CODE '(RAW-LOAD "llm-client-raw.lsp" T 'NIL
#                                                   STATE)
#                                        STATE)))
#          (VALUE-TRIPLE "llm-client-raw.lsp"))
#
# Summary
# Form:  ( PROGN! (SET-RAW-MODE T) ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# NIL
#
# Summary
# Form:  ( PROGN (PROGN! ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
#  NIL
