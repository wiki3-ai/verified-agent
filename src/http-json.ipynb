# %% [raw]
# ; HTTP JSON Client -- Properly-guarded JSON POST for ACL2
# ;
# ; Copyright (C) 2025
# ;
# ; License: See LICENSE file
# ;
# ; Author: AI Assistant with human guidance
# ;
# ; This book provides a properly-guarded post-json function that accepts
# ; stringp JSON body (unlike kestrel/htclient/post-light which requires alistp).
# ; This follows the oracle model for network I/O in formal verification.

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(in-package "ACL2")
# Out:
#  "ACL2"

# %%
(include-book "std/util/define" :dir :system)
(include-book "quicklisp/dexador" :dir :system)
; (depends-on "http-json-raw.lsp")
# Out:
# Summary
# Form:  ( INCLUDE-BOOK "std/util/define" ...)
# Rules: NIL
# Time:  0.10 seconds (prove: 0.00, print: 0.00, other: 0.10)
#  "/home/acl2/books/std/util/define.lisp"
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP from book /home/acl2/books/quicklisp/base.
#
# ACL2 Warning [Ttags] in ( INCLUDE-BOOK "quicklisp/dexador" ...):  The
# ttag note just printed to the terminal indicates a modification to
# ACL2.  To avoid this warning, supply an explicit :TTAGS argument when
# including the book "/home/acl2/books/quicklisp/dexador".
#
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP.DEXADOR from book /home/acl2/books/quicklisp/dexador.
#
# ACL2 Warning [Ttags] in ( INCLUDE-BOOK "quicklisp/dexador" ...):  The
# ttag note just printed to the terminal indicates a modification to
# ACL2.  To avoid this warning, supply an explicit :TTAGS argument when
# including the book "/home/acl2/books/quicklisp/dexador".
#
#
# Summary
# Form:  ( INCLUDE-BOOK "quicklisp/dexador" ...)
# Rules: NIL
# Warnings:  Ttags
# Time:  0.37 seconds (prove: 0.00, print: 0.00, other: 0.37)
#  "/home/acl2/books/quicklisp/dexador.lisp"

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Helper: state preservation theorem for oracle reads
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(local
 (defthm state-p1-of-read-acl2-oracle
   (implies (state-p1 state)
            (state-p1 (mv-nth 2 (read-acl2-oracle state))))
   :hints (("Goal" :in-theory (enable read-acl2-oracle)))))
# Out:
# ACL2 Warning [Subsume] in ( DEFTHM STATE-P1-OF-READ-ACL2-ORACLE ...):
# A newly proposed :REWRITE rule generated from STATE-P1-OF-READ-ACL2-ORACLE
# probably subsumes the previously added :REWRITE rule
# STATE-P1-READ-ACL2-ORACLE, in the sense that the new rule will now
# probably be applied whenever the old rule would have been.
#
#
# ACL2 Warning [Subsume] in ( DEFTHM STATE-P1-OF-READ-ACL2-ORACLE ...):
# The previously added rule STATE-P1-READ-ACL2-ORACLE subsumes a newly
# proposed :REWRITE rule generated from STATE-P1-OF-READ-ACL2-ORACLE,
# in the sense that the old rule rewrites a more general target.  Because
# the new rule will be tried first, it may nonetheless find application.
#
#
# Q.E.D.
#
# The storage of STATE-P1-OF-READ-ACL2-ORACLE depends upon the :type-
# prescription rule STATE-P1.
#
# Summary
# Form:  ( DEFTHM STATE-P1-OF-READ-ACL2-ORACLE ...)
# Rules: ((:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:TYPE-PRESCRIPTION STATE-P1))
# Warnings:  Subsume
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  12
#  STATE-P1-OF-READ-ACL2-ORACLE

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; post-json: HTTP POST with JSON string body
# ;;
# ;; This is the logical specification. The raw Lisp implementation in
# ;; http-json-raw.lsp replaces this with actual Dexador calls.
# ;;
# ;; Parameters:
# ;;   url           - Target URL (stringp)
# ;;   json-body     - JSON request body as string (stringp)
# ;;   headers       - HTTP headers as alist (alistp)
# ;;   connect-timeout - Connection timeout in seconds (natp)
# ;;   read-timeout  - Read timeout in seconds (natp)
# ;;   state         - ACL2 state
# ;;
# ;; Returns: (mv error body status state)
# ;;   error  - NIL on success, error string on failure
# ;;   body   - Response body as string
# ;;   status - HTTP status code (0 on error)
# ;;   state  - Updated state
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(defun post-json (url json-body headers connect-timeout read-timeout state)
  (declare (xargs :guard (and (stringp url)
                              (stringp json-body)
                              (alistp headers)
                              (natp connect-timeout)
                              (natp read-timeout))
                  :stobjs state)
           (ignore url json-body headers connect-timeout read-timeout))
  ;; Logical definition reads from oracle (will be replaced by raw Lisp)
  (prog2$ 
   (er hard? 'post-json "Raw Lisp definition not installed?")
   (mv-let (err1 val1 state)
     (read-acl2-oracle state)
     (declare (ignore err1))
     (mv-let (err2 val2 state)
       (read-acl2-oracle state)
       (declare (ignore err2))
       (mv-let (err3 val3 state)
         (read-acl2-oracle state)
         (declare (ignore err3))
         ;; Return: error (or nil), body string, status code
         (mv (if (stringp val1) val1 nil)
             (if (stringp val2) val2 "")
             (if (natp val3) val3 0)
             state))))))
# Out:
# Since POST-JSON is non-recursive, its admission is trivial.  We observe
# that the type of POST-JSON is described by the theorem
# (AND (CONSP (POST-JSON URL JSON-BODY HEADERS
#                        CONNECT-TIMEOUT READ-TIMEOUT STATE))
#      (TRUE-LISTP (POST-JSON URL JSON-BODY HEADERS
#                             CONNECT-TIMEOUT READ-TIMEOUT STATE))).
# We used primitive type reasoning.
#
# (POST-JSON * * * * * STATE) => (MV * * * STATE).
#
# Computing the guard conjecture for POST-JSON....
#
# The non-trivial part of the guard conjecture for POST-JSON, given the
# :forward-chaining rule STATE-P-IMPLIES-AND-FORWARD-TO-STATE-P1 and
# the :type-prescription rule STATE-P, is
#
# Goal
# (IMPLIES (AND (NATP READ-TIMEOUT)
#               (NATP CONNECT-TIMEOUT)
#               (ALISTP HEADERS)
#               (STRINGP JSON-BODY)
#               (STRINGP URL)
#               (STATE-P STATE))
#          (LET* ((MV (READ-ACL2-ORACLE STATE))
#                 (STATE (MV-NTH 2 MV)))
#            (AND (STATE-P1 STATE)
#                 (LET* ((MV (READ-ACL2-ORACLE STATE))
#                        (STATE (MV-NTH 2 MV)))
#                   (STATE-P1 STATE))))).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for POST-JSON.  POST-JSON
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN POST-JSON ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION STATE-P)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING STATE-P-IMPLIES-AND-FORWARD-TO-STATE-P1)
#         (:TYPE-PRESCRIPTION STATE-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  102
#  POST-JSON

# %%
;; Return type theorems
(defthm stringp-or-null-of-post-json-error
  (or (null (mv-nth 0 (post-json url json-body headers ct rt state)))
      (stringp (mv-nth 0 (post-json url json-body headers ct rt state))))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM STRINGP-OR-NULL-OF-POST-JSON-ERROR ...):
# Our heuristics choose
# (MV-NTH 0 (POST-JSON URL JSON-BODY HEADERS CT RT STATE)) as the :TYPED-
# TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OR-NULL-OF-POST-JSON-ERROR
# ...):  A :REWRITE rule generated from STRINGP-OR-NULL-OF-POST-JSON-ERROR
# will be triggered only by terms containing the function symbols NULL
# and POST-JSON, which have non-recursive definitions.  Unless these
# definitions are disabled, this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM STRINGP-OR-NULL-OF-POST-JSON-ERROR ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION NULL)
#         (:DEFINITION POST-JSON)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  619
#  STRINGP-OR-NULL-OF-POST-JSON-ERROR

# %%
(defthm stringp-of-post-json-body
  (stringp (mv-nth 1 (post-json url json-body headers ct rt state)))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM STRINGP-OF-POST-JSON-BODY ...):  Our heuristics
# choose (MV-NTH 1 (POST-JSON URL JSON-BODY HEADERS CT RT STATE)) as
# the :TYPED-TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-POST-JSON-BODY ...):
# A :REWRITE rule generated from STRINGP-OF-POST-JSON-BODY will be triggered
# only by terms containing the function symbol POST-JSON, which has a
# non-recursive definition.  Unless this definition is disabled, this
# rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-POST-JSON-BODY ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION POST-JSON))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  192
#  STRINGP-OF-POST-JSON-BODY

# %%
(defthm natp-of-post-json-status
  (natp (mv-nth 2 (post-json url json-body headers ct rt state)))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM NATP-OF-POST-JSON-STATUS ...):  Our heuristics
# choose (MV-NTH 2 (POST-JSON URL JSON-BODY HEADERS CT RT STATE)) as
# the :TYPED-TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM NATP-OF-POST-JSON-STATUS ...):
# A :REWRITE rule generated from NATP-OF-POST-JSON-STATUS will be triggered
# only by terms containing the function symbols NATP and POST-JSON, which
# have non-recursive definitions.  Unless these definitions are disabled,
# this rule is unlikely ever to be used.
#
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of NATP-OF-POST-JSON-STATUS depends upon the :compound-
# recognizer rule NATP-COMPOUND-RECOGNIZER and the :type-prescription
# rule NATP.
#
# Summary
# Form:  ( DEFTHM NATP-OF-POST-JSON-STATUS ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POST-JSON)
#         (:TYPE-PRESCRIPTION NATP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  470
#  NATP-OF-POST-JSON-STATUS

# %%
(defthm state-p1-of-post-json
  (implies (state-p1 state)
           (state-p1 (mv-nth 3 (post-json url json-body headers ct rt state)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STATE-P1-OF-POST-JSON ...):  A :REWRITE
# rule generated from STATE-P1-OF-POST-JSON will be triggered only by
# terms containing the function symbol POST-JSON, which has a non-recursive
# definition.  Unless this definition is disabled, this rule is unlikely
# ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of STATE-P1-OF-POST-JSON depends upon the :type-prescription
# rule STATE-P1.
#
# Summary
# Form:  ( DEFTHM STATE-P1-OF-POST-JSON ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POST-JSON)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:TYPE-PRESCRIPTION STATE-P1))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  250
#  STATE-P1-OF-POST-JSON

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; post-json-with-headers: HTTP POST returning response headers
# ;;
# ;; Like post-json but also returns response headers as alist.
# ;; Needed for MCP protocol which returns session ID in headers.
# ;;
# ;; Parameters:
# ;;   url           - Target URL (stringp)
# ;;   json-body     - JSON request body as string (stringp)
# ;;   headers       - HTTP headers as alist (alistp)
# ;;   connect-timeout - Connection timeout in seconds (natp)
# ;;   read-timeout  - Read timeout in seconds (natp)
# ;;   state         - ACL2 state
# ;;
# ;; Returns: (mv error body status response-headers state)
# ;;   error   - NIL on success, error string on failure
# ;;   body    - Response body as string
# ;;   status  - HTTP status code (0 on error)
# ;;   response-headers - Response headers as alist
# ;;   state   - Updated state
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(defun post-json-with-headers (url json-body headers connect-timeout read-timeout state)
  (declare (xargs :guard (and (stringp url)
                              (stringp json-body)
                              (alistp headers)
                              (natp connect-timeout)
                              (natp read-timeout))
                  :stobjs state)
           (ignore url json-body headers connect-timeout read-timeout))
  ;; Logical definition reads from oracle (will be replaced by raw Lisp)
  (prog2$ 
   (er hard? 'post-json-with-headers "Raw Lisp definition not installed?")
   (mv-let (err1 val1 state)
     (read-acl2-oracle state)
     (declare (ignore err1))
     (mv-let (err2 val2 state)
       (read-acl2-oracle state)
       (declare (ignore err2))
       (mv-let (err3 val3 state)
         (read-acl2-oracle state)
         (declare (ignore err3))
         (mv-let (err4 val4 state)
           (read-acl2-oracle state)
           (declare (ignore err4))
           ;; Return: error (or nil), body string, status code, headers alist
           (mv (if (stringp val1) val1 nil)
               (if (stringp val2) val2 "")
               (if (natp val3) val3 0)
               (if (alistp val4) val4 nil)
               state)))))))
# Out:
# Since POST-JSON-WITH-HEADERS is non-recursive, its admission is trivial.
# We observe that the type of POST-JSON-WITH-HEADERS is described by
# the theorem
# (AND
#    (CONSP (POST-JSON-WITH-HEADERS URL JSON-BODY HEADERS
#                                   CONNECT-TIMEOUT READ-TIMEOUT STATE))
#    (TRUE-LISTP (POST-JSON-WITH-HEADERS URL JSON-BODY HEADERS
#                                        CONNECT-TIMEOUT READ-TIMEOUT STATE))).
# We used primitive type reasoning.
#
# (POST-JSON-WITH-HEADERS * * * * * STATE) => (MV * * * * STATE).
#
# Computing the guard conjecture for POST-JSON-WITH-HEADERS....
#
# The non-trivial part of the guard conjecture for POST-JSON-WITH-HEADERS,
# given the :forward-chaining rule STATE-P-IMPLIES-AND-FORWARD-TO-STATE-P1
# and the :type-prescription rule STATE-P, is
#
# Goal
# (IMPLIES (AND (NATP READ-TIMEOUT)
#               (NATP CONNECT-TIMEOUT)
#               (ALISTP HEADERS)
#               (STRINGP JSON-BODY)
#               (STRINGP URL)
#               (STATE-P STATE))
#          (LET* ((MV (READ-ACL2-ORACLE STATE))
#                 (STATE (MV-NTH 2 MV)))
#            (AND (STATE-P1 STATE)
#                 (LET* ((MV (READ-ACL2-ORACLE STATE))
#                        (STATE (MV-NTH 2 MV)))
#                   (AND (STATE-P1 STATE)
#                        (LET* ((MV (READ-ACL2-ORACLE STATE))
#                               (STATE (MV-NTH 2 MV)))
#                          (STATE-P1 STATE))))))).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for POST-JSON-WITH-HEADERS.
# POST-JSON-WITH-HEADERS is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN POST-JSON-WITH-HEADERS ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION STATE-P)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING STATE-P-IMPLIES-AND-FORWARD-TO-STATE-P1)
#         (:TYPE-PRESCRIPTION STATE-P))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  113
#  POST-JSON-WITH-HEADERS

# %%
;; Return type theorems for post-json-with-headers
(defthm stringp-or-null-of-post-json-with-headers-error
  (or (null (mv-nth 0 (post-json-with-headers url json-body headers ct rt state)))
      (stringp (mv-nth 0 (post-json-with-headers url json-body headers ct rt state))))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM STRINGP-OR-NULL-OF-POST-JSON-WITH-HEADERS-ERROR
# ...):  Our heuristics choose
# (MV-NTH 0 (POST-JSON-WITH-HEADERS URL JSON-BODY HEADERS CT RT STATE))
# as the :TYPED-TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM
# STRINGP-OR-NULL-OF-POST-JSON-WITH-HEADERS-ERROR ...):  A :REWRITE rule
# generated from STRINGP-OR-NULL-OF-POST-JSON-WITH-HEADERS-ERROR will
# be triggered only by terms containing the function symbols NULL and
# POST-JSON-WITH-HEADERS, which have non-recursive definitions.  Unless
# these definitions are disabled, this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM STRINGP-OR-NULL-OF-POST-JSON-WITH-HEADERS-ERROR ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION NULL)
#         (:DEFINITION POST-JSON-WITH-HEADERS)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  1390
#  STRINGP-OR-NULL-OF-POST-JSON-WITH-HEADERS-ERROR

# %%
(defthm stringp-of-post-json-with-headers-body
  (stringp (mv-nth 1 (post-json-with-headers url json-body headers ct rt state)))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM STRINGP-OF-POST-JSON-WITH-HEADERS-BODY
# ...):  Our heuristics choose
# (MV-NTH 1 (POST-JSON-WITH-HEADERS URL JSON-BODY HEADERS CT RT STATE))
# as the :TYPED-TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-POST-JSON-WITH-HEADERS-BODY
# ...):  A :REWRITE rule generated from STRINGP-OF-POST-JSON-WITH-HEADERS-BODY
# will be triggered only by terms containing the function symbol
# POST-JSON-WITH-HEADERS, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-POST-JSON-WITH-HEADERS-BODY ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION POST-JSON-WITH-HEADERS))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  449
#  STRINGP-OF-POST-JSON-WITH-HEADERS-BODY

# %%
(defthm natp-of-post-json-with-headers-status
  (natp (mv-nth 2 (post-json-with-headers url json-body headers ct rt state)))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM NATP-OF-POST-JSON-WITH-HEADERS-STATUS
# ...):  Our heuristics choose
# (MV-NTH 2 (POST-JSON-WITH-HEADERS URL JSON-BODY HEADERS CT RT STATE))
# as the :TYPED-TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM NATP-OF-POST-JSON-WITH-HEADERS-STATUS
# ...):  A :REWRITE rule generated from NATP-OF-POST-JSON-WITH-HEADERS-STATUS
# will be triggered only by terms containing the function symbols NATP
# and POST-JSON-WITH-HEADERS, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of NATP-OF-POST-JSON-WITH-HEADERS-STATUS depends upon the
# :compound-recognizer rule NATP-COMPOUND-RECOGNIZER and the :type-prescription
# rule NATP.
#
# Summary
# Form:  ( DEFTHM NATP-OF-POST-JSON-WITH-HEADERS-STATUS ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POST-JSON-WITH-HEADERS)
#         (:TYPE-PRESCRIPTION NATP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  984
#  NATP-OF-POST-JSON-WITH-HEADERS-STATUS

# %%
(defthm alistp-of-post-json-with-headers-response-headers
  (alistp (mv-nth 3 (post-json-with-headers url json-body headers ct rt state)))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM
# ALISTP-OF-POST-JSON-WITH-HEADERS-RESPONSE-HEADERS ...):  Our heuristics
# choose
# (ALISTP (MV-NTH 3
#                 (POST-JSON-WITH-HEADERS URL JSON-BODY HEADERS CT RT STATE)))
# as the :TYPED-TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM
# ALISTP-OF-POST-JSON-WITH-HEADERS-RESPONSE-HEADERS ...):  A :REWRITE
# rule generated from ALISTP-OF-POST-JSON-WITH-HEADERS-RESPONSE-HEADERS
# will be triggered only by terms containing the function symbol
# POST-JSON-WITH-HEADERS, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of ALISTP-OF-POST-JSON-WITH-HEADERS-RESPONSE-HEADERS depends
# upon the :type-prescription rule ALISTP.
#
# Summary
# Form:  ( DEFTHM ALISTP-OF-POST-JSON-WITH-HEADERS-RESPONSE-HEADERS ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION POST-JSON-WITH-HEADERS)
#         (:EXECUTABLE-COUNTERPART ALISTP)
#         (:TYPE-PRESCRIPTION ALISTP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  481
#  ALISTP-OF-POST-JSON-WITH-HEADERS-RESPONSE-HEADERS

# %%
(defthm state-p1-of-post-json-with-headers
  (implies (state-p1 state)
           (state-p1 (mv-nth 4 (post-json-with-headers url json-body headers ct rt state)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STATE-P1-OF-POST-JSON-WITH-HEADERS
# ...):  A :REWRITE rule generated from STATE-P1-OF-POST-JSON-WITH-HEADERS
# will be triggered only by terms containing the function symbol
# POST-JSON-WITH-HEADERS, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of STATE-P1-OF-POST-JSON-WITH-HEADERS depends upon the
# :type-prescription rule STATE-P1.
#
# Summary
# Form:  ( DEFTHM STATE-P1-OF-POST-JSON-WITH-HEADERS ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POST-JSON-WITH-HEADERS)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:TYPE-PRESCRIPTION STATE-P1))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  510
#  STATE-P1-OF-POST-JSON-WITH-HEADERS

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; get-json: HTTP GET for JSON endpoints
# ;;
# ;; Parameters:
# ;;   url           - Target URL (stringp)
# ;;   headers       - HTTP headers as alist (alistp)
# ;;   connect-timeout - Connection timeout in seconds (natp)
# ;;   read-timeout  - Read timeout in seconds (natp)
# ;;   state         - ACL2 state
# ;;
# ;; Returns: (mv error body status state)
# ;;   error  - NIL on success, error string on failure
# ;;   body   - Response body as string
# ;;   status - HTTP status code (0 on error)
# ;;   state  - Updated state
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(defun get-json (url headers connect-timeout read-timeout state)
  (declare (xargs :guard (and (stringp url)
                              (alistp headers)
                              (natp connect-timeout)
                              (natp read-timeout))
                  :stobjs state)
           (ignore url headers connect-timeout read-timeout))
  ;; Logical definition reads from oracle (will be replaced by raw Lisp)
  (prog2$ 
   (er hard? 'get-json "Raw Lisp definition not installed?")
   (mv-let (err1 val1 state)
     (read-acl2-oracle state)
     (declare (ignore err1))
     (mv-let (err2 val2 state)
       (read-acl2-oracle state)
       (declare (ignore err2))
       (mv-let (err3 val3 state)
         (read-acl2-oracle state)
         (declare (ignore err3))
         ;; Return: error (or nil), body string, status code
         (mv (if (stringp val1) val1 nil)
             (if (stringp val2) val2 "")
             (if (natp val3) val3 0)
             state))))))
# Out:
# Since GET-JSON is non-recursive, its admission is trivial.  We observe
# that the type of GET-JSON is described by the theorem
# (AND (CONSP (GET-JSON URL HEADERS
#                       CONNECT-TIMEOUT READ-TIMEOUT STATE))
#      (TRUE-LISTP (GET-JSON URL HEADERS
#                            CONNECT-TIMEOUT READ-TIMEOUT STATE))).
# We used primitive type reasoning.
#
# (GET-JSON * * * * STATE) => (MV * * * STATE).
#
# Computing the guard conjecture for GET-JSON....
#
# The non-trivial part of the guard conjecture for GET-JSON, given the
# :forward-chaining rule STATE-P-IMPLIES-AND-FORWARD-TO-STATE-P1 and
# the :type-prescription rule STATE-P, is
#
# Goal
# (IMPLIES (AND (NATP READ-TIMEOUT)
#               (NATP CONNECT-TIMEOUT)
#               (ALISTP HEADERS)
#               (STRINGP URL)
#               (STATE-P STATE))
#          (LET* ((MV (READ-ACL2-ORACLE STATE))
#                 (STATE (MV-NTH 2 MV)))
#            (AND (STATE-P1 STATE)
#                 (LET* ((MV (READ-ACL2-ORACLE STATE))
#                        (STATE (MV-NTH 2 MV)))
#                   (STATE-P1 STATE))))).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for GET-JSON.  GET-JSON
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN GET-JSON ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION STATE-P)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING STATE-P-IMPLIES-AND-FORWARD-TO-STATE-P1)
#         (:TYPE-PRESCRIPTION STATE-P))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  92
#  GET-JSON

# %%
;; Return type theorems for get-json
(defthm stringp-of-get-json-body
  (stringp (mv-nth 1 (get-json url headers ct rt state)))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM STRINGP-OF-GET-JSON-BODY ...):  Our heuristics
# choose (MV-NTH 1 (GET-JSON URL HEADERS CT RT STATE)) as the :TYPED-
# TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-GET-JSON-BODY ...):
# A :REWRITE rule generated from STRINGP-OF-GET-JSON-BODY will be triggered
# only by terms containing the function symbol GET-JSON, which has a
# non-recursive definition.  Unless this definition is disabled, this
# rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-GET-JSON-BODY ...)
# Rules: ((:DEFINITION GET-JSON)
#         (:DEFINITION NATP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  190
#  STRINGP-OF-GET-JSON-BODY

# %%
(defthm natp-of-get-json-status
  (natp (mv-nth 2 (get-json url headers ct rt state)))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM NATP-OF-GET-JSON-STATUS ...):  Our heuristics
# choose (MV-NTH 2 (GET-JSON URL HEADERS CT RT STATE)) as the :TYPED-
# TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM NATP-OF-GET-JSON-STATUS ...):  A
# :REWRITE rule generated from NATP-OF-GET-JSON-STATUS will be triggered
# only by terms containing the function symbols NATP and GET-JSON, which
# have non-recursive definitions.  Unless these definitions are disabled,
# this rule is unlikely ever to be used.
#
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of NATP-OF-GET-JSON-STATUS depends upon the :compound-
# recognizer rule NATP-COMPOUND-RECOGNIZER and the :type-prescription
# rule NATP.
#
# Summary
# Form:  ( DEFTHM NATP-OF-GET-JSON-STATUS ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION GET-JSON)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:TYPE-PRESCRIPTION NATP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  460
#  NATP-OF-GET-JSON-STATUS

# %%
(defthm state-p1-of-get-json
  (implies (state-p1 state)
           (state-p1 (mv-nth 3 (get-json url headers ct rt state)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM STATE-P1-OF-GET-JSON ...):  A :REWRITE
# rule generated from STATE-P1-OF-GET-JSON will be triggered only by
# terms containing the function symbol GET-JSON, which has a non-recursive
# definition.  Unless this definition is disabled, this rule is unlikely
# ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of STATE-P1-OF-GET-JSON depends upon the :type-prescription
# rule STATE-P1.
#
# Summary
# Form:  ( DEFTHM STATE-P1-OF-GET-JSON ...)
# Rules: ((:DEFINITION GET-JSON)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:TYPE-PRESCRIPTION STATE-P1))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  247
#  STATE-P1-OF-GET-JSON

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Trust tag and raw Lisp inclusion
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(defttag :http-json)
(include-raw "http-json-raw.lsp"
             :host-readtable t)
# Out:
# TTAG NOTE: Adding ttag :HTTP-JSON from the top level loop.
#  :HTTP-JSON
#
#
# ACL2 !>>(PROGN!
#          (SET-RAW-MODE T)
#          (DEFUN RAW-COMPILE (NAME ERROR-ON-FAIL ON-FAIL STATE)
#           (COND
#            ((NOT (MEMBER :CLTL2 *FEATURES*))
#             (COMPILE-FILE (EXTEND-PATHNAME (CBD) NAME STATE)))
#            (T
#             (HANDLER-CASE
#              (COMPILE-FILE (EXTEND-PATHNAME (CBD) NAME STATE))
#              (ERROR
#               (CONDITION)
#               (IF ERROR-ON-FAIL
#                (LET ((CONDITION-STR (FORMAT NIL "~a" CONDITION)))
#                 (ER
#                  HARD 'INCLUDE-RAW
#                  "Compilation of ~x0 failed with the following message:~%~@1~%"
#                  NAME CONDITION-STR))
#                (EVAL
#                 (CONS
#                   'LET
#                   (CONS (CONS (CONS 'CONDITION
#                                     (CONS (CONS 'QUOTE (CONS CONDITION 'NIL))
#                                           'NIL))
#                               'NIL)
#                         (CONS '(DECLARE (IGNORABLE CONDITION))
#                               (CONS ON-FAIL 'NIL))))))))
#             NIL)))
#          (DEFUN RAW-LOAD-UNCOMPILED (NAME ERROR-ON-FAIL ON-FAIL STATE)
#           (COND
#            ((NOT (MEMBER :CLTL2 *FEATURES*))
#             (LOAD (EXTEND-PATHNAME (CBD) NAME STATE)))
#            (T
#             (HANDLER-CASE
#              (LOAD (EXTEND-PATHNAME (CBD) NAME STATE))
#              (ERROR
#               (CONDITION)
#               (IF ERROR-ON-FAIL
#                (LET ((CONDITION-STR (FORMAT NIL "~a" CONDITION)))
#                  (ER HARD 'INCLUDE-RAW
#                      "Load of ~x0 failed with the following message:~%~@1~%"
#                      NAME CONDITION-STR))
#                (EVAL
#                 (CONS
#                   'LET
#                   (CONS (CONS (CONS 'CONDITION
#                                     (CONS (CONS 'QUOTE (CONS CONDITION 'NIL))
#                                           'NIL))
#                               'NIL)
#                         (CONS '(DECLARE (IGNORABLE CONDITION))
#                               (CONS ON-FAIL 'NIL))))))))
#             NIL)))
#          (DEFUN RAW-LOAD (NAME ERROR-ON-FAIL ON-FAIL STATE)
#           (LET* ((FNAME (EXTEND-PATHNAME (CBD) NAME STATE))
#                  (COMPILED-FNAME (COMPILE-FILE-PATHNAME FNAME))
#                  (SRC-DATE (OUR-IGNORE-ERRORS (FILE-WRITE-DATE FNAME)))
#                  (COMPILED-DATE
#                       (OUR-IGNORE-ERRORS (FILE-WRITE-DATE COMPILED-FNAME))))
#            (COND
#             ((AND SRC-DATE COMPILED-DATE
#                   (< COMPILED-DATE SRC-DATE))
#              (FORMAT
#               T
#               "Include-raw Warning: source file is newer than compiled file, loading uncompiled ~a~%"
#               FNAME)
#              (RAW-LOAD-UNCOMPILED NAME ERROR-ON-FAIL ON-FAIL STATE))
#             ((NOT (MEMBER :CLTL2 *FEATURES*))
#              (COND
#               ((PROBE-FILE COMPILED-FNAME)
#                (LOAD-COMPILED COMPILED-FNAME))
#               (T
#                (FORMAT
#                 T
#                 "Include-raw Warning: compiled file does not exist; loading uncompiled ~a~%"
#                 FNAME)
#                (RAW-LOAD-UNCOMPILED NAME ERROR-ON-FAIL ON-FAIL STATE))))
#             (T
#              (HANDLER-CASE
#               (LOAD-COMPILED COMPILED-FNAME)
#               (ERROR
#                (CONDITION)
#                (PROGN
#                 (FORMAT
#                  T
#                  "Include-raw Warning: compiled file failed to load; loading uncompiled ~a~%Details: ~a~%"
#                  FNAME CONDITION)
#                 (RAW-LOAD-UNCOMPILED NAME ERROR-ON-FAIL ON-FAIL STATE))))))
#            NIL)))
#
# Summary
# Form:  ( PROGN! (SET-RAW-MODE T) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# NIL
#
#
# ACL2 !>>(MAKE-EVENT
#           (MV-LET
#               (ERP VAL STATE)
#               (PROGN! (SET-RAW-MODE T)
#                       (LET ((*READTABLE* (IF T *HOST-READTABLE*
#                                            *ACL2-READTABLE*)))
#                         (IF (OR (NOT (F-GET-GLOBAL 'CERTIFY-BOOK-INFO STATE))
#                                 NIL)
#                             (MV NIL NIL STATE)
#                           (RAW-COMPILE "http-json-raw.lsp" T 'NIL
#                                        STATE))))
#             (DECLARE (IGNORE ERP VAL))
#             (VALUE '(VALUE-TRIPLE :INVISIBLE))))
#
# Summary
# Form:  ( PROGN! (SET-RAW-MODE T) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Summary
# Form:  ( MAKE-EVENT (MV-LET ...))
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# :INVISIBLE
#
#
# ACL2 !>>(PROGN!
#           (SET-RAW-MODE T)
#           (LET ((*READTABLE* (IF T *HOST-READTABLE*
#                                *ACL2-READTABLE*)))
#             (WHEN (NULL *HCOMP-FN-MACRO-RESTORE-HT*)
#                   (EXTEND-WITH-RAW-CODE '(RAW-LOAD "http-json-raw.lsp" T 'NIL
#                                                    STATE)
#                                         STATE)))
#           (VALUE-TRIPLE "http-json-raw.lsp"))
#
# Summary
# Form:  ( PROGN! (SET-RAW-MODE T) ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# NIL
#
# Summary
# Form:  ( PROGN (PROGN! ...) ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  NIL
