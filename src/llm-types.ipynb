# %% [raw]
# ; LLM Types -- FTY type definitions for LLM chat messages
# ;
# ; Copyright (C) 2025
# ;
# ; License: See LICENSE file
# ;
# ; Author: AI Assistant with human guidance

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(in-package "ACL2")
# Out:
#  "ACL2"

# %%
(include-book "centaur/fty/top" :dir :system)
(include-book "std/util/define" :dir :system)
# Out:
# Summary
# Form:  ( INCLUDE-BOOK "centaur/fty/top" ...)
# Rules: NIL
# Time:  0.38 seconds (prove: 0.00, print: 0.00, other: 0.38)
#  "/home/acl2/books/centaur/fty/top.lisp"
#
# The event ( INCLUDE-BOOK "std/util/define" ...) is redundant.  See
# :DOC redundant-events.
#
# Summary
# Form:  ( INCLUDE-BOOK "std/util/define" ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  :REDUNDANT

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Chat Role
# ;;
# ;; Represents the role of a message in a chat conversation.
# ;; OpenAI-compatible roles for LLM APIs.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(fty::deftagsum chat-role
  (:system ())      ; System prompt / instructions
  (:user ())        ; User input
  (:assistant ())   ; Model response
  (:tool ()))       ; Tool result (for future MCP integration)
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN CHAT-ROLE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CONSP-WHEN-CHAT-ROLE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHAT-ROLE-KIND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN CHAT-ROLE-KIND$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CHAT-ROLE-KIND-POSSIBILITIES ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE RULESET-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-ROLE-KIND-POSSIBILITIES ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHAT-ROLE-CASE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHAT-ROLE-KIND-EQ ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHAT-ROLE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN CHAT-ROLE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 5
# Subgoal 4
# Subgoal 4'
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM CHAT-ROLE-P-OF-CHAT-ROLE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-ROLE-P-OF-CHAT-ROLE-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CHAT-ROLE-FIX-WHEN-CHAT-ROLE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS CHAT-ROLE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM CHAT-ROLE-KIND$INLINE-OF-CHAT-ROLE-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM CONSP-OF-CHAT-ROLE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TAG-WHEN-CHAT-ROLE-P-FORWARD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM TAG-OF-CHAT-ROLE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE RULESET-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN CHAT-ROLE-SYSTEM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-CHAT-ROLE-SYSTEM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-CHAT-ROLE-SYSTEM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-ROLE-FIX-WHEN-SYSTEM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-CHAT-ROLE-SYSTEM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO PATBIND-CHAT-ROLE-SYSTEM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-CHAT-ROLE-SYSTEM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-CHAT-ROLE-SYSTEM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-CHAT-ROLE-SYSTEM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-ROLE-FIX-WHEN-SYSTEM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN CHAT-ROLE-USER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-CHAT-ROLE-USER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-CHAT-ROLE-USER ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-ROLE-FIX-WHEN-USER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-CHAT-ROLE-USER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO PATBIND-CHAT-ROLE-USER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-CHAT-ROLE-USER ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-CHAT-ROLE-USER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-CHAT-ROLE-USER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-ROLE-FIX-WHEN-USER ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN CHAT-ROLE-ASSISTANT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-CHAT-ROLE-ASSISTANT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-CHAT-ROLE-ASSISTANT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-ROLE-FIX-WHEN-ASSISTANT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-CHAT-ROLE-ASSISTANT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO PATBIND-CHAT-ROLE-ASSISTANT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-CHAT-ROLE-ASSISTANT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-CHAT-ROLE-ASSISTANT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-CHAT-ROLE-ASSISTANT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-ROLE-FIX-WHEN-ASSISTANT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN CHAT-ROLE-TOOL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-CHAT-ROLE-TOOL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-CHAT-ROLE-TOOL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-ROLE-FIX-WHEN-TOOL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-CHAT-ROLE-TOOL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO PATBIND-CHAT-ROLE-TOOL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-CHAT-ROLE-TOOL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-CHAT-ROLE-TOOL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-CHAT-ROLE-TOOL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-ROLE-FIX-WHEN-TOOL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM CHAT-ROLE-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC CHAT-ROLE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC CHAT-ROLE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.08 seconds (prove: 0.01, print: 0.00, other: 0.07)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.08 seconds (prove: 0.01, print: 0.00, other: 0.07)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFTAGSUM-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.08 seconds (prove: 0.01, print: 0.00, other: 0.07)
# Prover steps counted:  3174
#  T

# %%
;; Helper functions for creating roles
(defmacro role-system () '(chat-role-system))
(defmacro role-user () '(chat-role-user))
(defmacro role-assistant () '(chat-role-assistant))
(defmacro role-tool () '(chat-role-tool))
# Out:
# Summary
# Form:  ( DEFMACRO ROLE-SYSTEM ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  ROLE-SYSTEM
#
# Summary
# Form:  ( DEFMACRO ROLE-USER ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  ROLE-USER
#
# Summary
# Form:  ( DEFMACRO ROLE-ASSISTANT ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  ROLE-ASSISTANT
#
# Summary
# Form:  ( DEFMACRO ROLE-TOOL ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  ROLE-TOOL

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Chat Message
# ;;
# ;; A single message in a conversation with role and content.
# ;; Future extension: add tool-calls and tool-call-id for MCP.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(fty::defprod chat-message
  ((role chat-role-p "The role of the message sender")
   (content stringp "The text content of the message" :default ""))
  :layout :list)
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TMP-DEFTYPES-STRINGP-OF-STR-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFUN CHAT-MESSAGE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONSP-WHEN-CHAT-MESSAGE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHAT-MESSAGE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN CHAT-MESSAGE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM CHAT-MESSAGE-P-OF-CHAT-MESSAGE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-MESSAGE-P-OF-CHAT-MESSAGE-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CHAT-MESSAGE-FIX-WHEN-CHAT-MESSAGE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS CHAT-MESSAGE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHAT-MESSAGE->ROLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN CHAT-MESSAGE->ROLE$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CHAT-ROLE-P-OF-CHAT-MESSAGE->ROLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-ROLE-P-OF-CHAT-MESSAGE->ROLE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-MESSAGE->ROLE$INLINE-OF-CHAT-MESSAGE-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV CHAT-MESSAGE->ROLE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHAT-MESSAGE->CONTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN CHAT-MESSAGE->CONTENT$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-CHAT-MESSAGE->CONTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-CHAT-MESSAGE->CONTENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-MESSAGE->CONTENT$INLINE-OF-CHAT-MESSAGE-FIX-X
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV CHAT-MESSAGE->CONTENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN CHAT-MESSAGE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-MESSAGE-P-OF-CHAT-MESSAGE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-MESSAGE-P-OF-CHAT-MESSAGE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM CHAT-MESSAGE->ROLE-OF-CHAT-MESSAGE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM CHAT-MESSAGE->CONTENT-OF-CHAT-MESSAGE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-MESSAGE-OF-FIELDS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-MESSAGE-FIX-WHEN-CHAT-MESSAGE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 4
# Subgoal 4'
# Subgoal 4''
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM EQUAL-OF-CHAT-MESSAGE ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Goal'
# Form:  ( DEFTHM CHAT-MESSAGE-OF-CHAT-ROLE-FIX-ROLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CHAT-MESSAGE-OF-STR-FIX-CONTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFMACRO PATBIND-CHAT-MESSAGE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-CHAT-MESSAGE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-CHAT-MESSAGE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-CHAT-MESSAGE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-MESSAGE->ROLE-OF-CHAT-MESSAGE ...) ...)
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CHAT-MESSAGE-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC CHAT-MESSAGE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC CHAT-MESSAGE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.08 seconds (prove: 0.01, print: 0.00, other: 0.07)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.09 seconds (prove: 0.01, print: 0.00, other: 0.08)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFPROD-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.09 seconds (prove: 0.01, print: 0.00, other: 0.08)
# Prover steps counted:  2716
#  T

# %%
;; Convenient constructors
(define make-system-message ((content stringp))
  :returns (msg chat-message-p)
  (make-chat-message :role (role-system) :content content))
# Out:
# Since MAKE-SYSTEM-MESSAGE is non-recursive, its admission is trivial.
# We observe that the type of MAKE-SYSTEM-MESSAGE is described by the
# theorem
# (AND (CONSP (MAKE-SYSTEM-MESSAGE CONTENT))
#      (TRUE-LISTP (MAKE-SYSTEM-MESSAGE CONTENT))).
# We used the :type-prescription rule CHAT-MESSAGE.
#
# Computing the guard conjecture for MAKE-SYSTEM-MESSAGE....
#
# The guard conjecture for MAKE-SYSTEM-MESSAGE is trivial to prove, given
# the :executable-counterparts of CHAT-ROLE-P and CHAT-ROLE-SYSTEM.
# MAKE-SYSTEM-MESSAGE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MAKE-SYSTEM-MESSAGE ...)
# Rules: ((:EXECUTABLE-COUNTERPART CHAT-ROLE-P)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-SYSTEM)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM CHAT-MESSAGE-P-OF-MAKE-SYSTEM-MESSAGE
#           (B* ((MSG (MAKE-SYSTEM-MESSAGE CONTENT)))
#             (CHAT-MESSAGE-P MSG))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'MAKE-SYSTEM-MESSAGE
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM CHAT-MESSAGE-P-OF-MAKE-SYSTEM-MESSAGE
# ...):  A :REWRITE rule generated from CHAT-MESSAGE-P-OF-MAKE-SYSTEM-MESSAGE
# will be triggered only by terms containing the function symbol
# MAKE-SYSTEM-MESSAGE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of CHAT-MESSAGE-P-OF-MAKE-SYSTEM-MESSAGE depends upon the
# :compound-recognizer rule CONSP-WHEN-CHAT-MESSAGE-P and the :type-
# prescription rule CHAT-MESSAGE-P.
#
# Summary
# Form:  ( DEFTHM CHAT-MESSAGE-P-OF-MAKE-SYSTEM-MESSAGE ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-CHAT-MESSAGE-P)
#         (:DEFINITION MAKE-SYSTEM-MESSAGE)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-SYSTEM)
#         (:REWRITE CHAT-MESSAGE-P-OF-CHAT-MESSAGE)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  12
# CHAT-MESSAGE-P-OF-MAKE-SYSTEM-MESSAGE
#
# Summary
# Form:  ( PROGN (DEFTHM CHAT-MESSAGE-P-OF-MAKE-SYSTEM-MESSAGE ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  12
#  MAKE-SYSTEM-MESSAGE

# %%
(define make-user-message ((content stringp))
  :returns (msg chat-message-p)
  (make-chat-message :role (role-user) :content content))
# Out:
# Since MAKE-USER-MESSAGE is non-recursive, its admission is trivial.
# We observe that the type of MAKE-USER-MESSAGE is described by the theorem
# (AND (CONSP (MAKE-USER-MESSAGE CONTENT))
#      (TRUE-LISTP (MAKE-USER-MESSAGE CONTENT))).
# We used the :type-prescription rule CHAT-MESSAGE.
#
# Computing the guard conjecture for MAKE-USER-MESSAGE....
#
# The guard conjecture for MAKE-USER-MESSAGE is trivial to prove, given
# the :executable-counterparts of CHAT-ROLE-P and CHAT-ROLE-USER.
# MAKE-USER-MESSAGE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MAKE-USER-MESSAGE ...)
# Rules: ((:EXECUTABLE-COUNTERPART CHAT-ROLE-P)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-USER)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM CHAT-MESSAGE-P-OF-MAKE-USER-MESSAGE
#           (B* ((MSG (MAKE-USER-MESSAGE CONTENT)))
#             (CHAT-MESSAGE-P MSG))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'MAKE-USER-MESSAGE
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM CHAT-MESSAGE-P-OF-MAKE-USER-MESSAGE
# ...):  A :REWRITE rule generated from CHAT-MESSAGE-P-OF-MAKE-USER-MESSAGE
# will be triggered only by terms containing the function symbol
# MAKE-USER-MESSAGE, which has a non-recursive definition.  Unless this
# definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of CHAT-MESSAGE-P-OF-MAKE-USER-MESSAGE depends upon the
# :compound-recognizer rule CONSP-WHEN-CHAT-MESSAGE-P and the :type-
# prescription rule CHAT-MESSAGE-P.
#
# Summary
# Form:  ( DEFTHM CHAT-MESSAGE-P-OF-MAKE-USER-MESSAGE ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-CHAT-MESSAGE-P)
#         (:DEFINITION MAKE-USER-MESSAGE)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-USER)
#         (:REWRITE CHAT-MESSAGE-P-OF-CHAT-MESSAGE)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  12
# CHAT-MESSAGE-P-OF-MAKE-USER-MESSAGE
#
# Summary
# Form:  ( PROGN (DEFTHM CHAT-MESSAGE-P-OF-MAKE-USER-MESSAGE ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  12
#  MAKE-USER-MESSAGE

# %%
(define make-assistant-message ((content stringp))
  :returns (msg chat-message-p)
  (make-chat-message :role (role-assistant) :content content))
# Out:
# Since MAKE-ASSISTANT-MESSAGE is non-recursive, its admission is trivial.
# We observe that the type of MAKE-ASSISTANT-MESSAGE is described by
# the theorem
# (AND (CONSP (MAKE-ASSISTANT-MESSAGE CONTENT))
#      (TRUE-LISTP (MAKE-ASSISTANT-MESSAGE CONTENT))).
# We used the :type-prescription rule CHAT-MESSAGE.
#
# Computing the guard conjecture for MAKE-ASSISTANT-MESSAGE....
#
# The guard conjecture for MAKE-ASSISTANT-MESSAGE is trivial to prove,
# given the :executable-counterparts of CHAT-ROLE-ASSISTANT and CHAT-ROLE-P.
# MAKE-ASSISTANT-MESSAGE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MAKE-ASSISTANT-MESSAGE ...)
# Rules: ((:EXECUTABLE-COUNTERPART CHAT-ROLE-ASSISTANT)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-P)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM CHAT-MESSAGE-P-OF-MAKE-ASSISTANT-MESSAGE
#           (B* ((MSG (MAKE-ASSISTANT-MESSAGE CONTENT)))
#             (CHAT-MESSAGE-P MSG))
#           :HINTS
#           ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'MAKE-ASSISTANT-MESSAGE
#                                                  ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM CHAT-MESSAGE-P-OF-MAKE-ASSISTANT-MESSAGE
# ...):  A :REWRITE rule generated from
# CHAT-MESSAGE-P-OF-MAKE-ASSISTANT-MESSAGE will be triggered only by
# terms containing the function symbol MAKE-ASSISTANT-MESSAGE, which
# has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of CHAT-MESSAGE-P-OF-MAKE-ASSISTANT-MESSAGE depends upon
# the :compound-recognizer rule CONSP-WHEN-CHAT-MESSAGE-P and the :type-
# prescription rule CHAT-MESSAGE-P.
#
# Summary
# Form:  ( DEFTHM CHAT-MESSAGE-P-OF-MAKE-ASSISTANT-MESSAGE ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-CHAT-MESSAGE-P)
#         (:DEFINITION MAKE-ASSISTANT-MESSAGE)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-ASSISTANT)
#         (:REWRITE CHAT-MESSAGE-P-OF-CHAT-MESSAGE)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  12
# CHAT-MESSAGE-P-OF-MAKE-ASSISTANT-MESSAGE
#
# Summary
# Form:  ( PROGN (DEFTHM CHAT-MESSAGE-P-OF-MAKE-ASSISTANT-MESSAGE ...)
# ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  12
#  MAKE-ASSISTANT-MESSAGE

# %%
(define make-tool-message ((content stringp))
  :returns (msg chat-message-p)
  (make-chat-message :role (role-tool) :content content))
# Out:
# Since MAKE-TOOL-MESSAGE is non-recursive, its admission is trivial.
# We observe that the type of MAKE-TOOL-MESSAGE is described by the theorem
# (AND (CONSP (MAKE-TOOL-MESSAGE CONTENT))
#      (TRUE-LISTP (MAKE-TOOL-MESSAGE CONTENT))).
# We used the :type-prescription rule CHAT-MESSAGE.
#
# Computing the guard conjecture for MAKE-TOOL-MESSAGE....
#
# The guard conjecture for MAKE-TOOL-MESSAGE is trivial to prove, given
# the :executable-counterparts of CHAT-ROLE-P and CHAT-ROLE-TOOL.
# MAKE-TOOL-MESSAGE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MAKE-TOOL-MESSAGE ...)
# Rules: ((:EXECUTABLE-COUNTERPART CHAT-ROLE-P)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-TOOL)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM CHAT-MESSAGE-P-OF-MAKE-TOOL-MESSAGE
#           (B* ((MSG (MAKE-TOOL-MESSAGE CONTENT)))
#             (CHAT-MESSAGE-P MSG))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'MAKE-TOOL-MESSAGE
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM CHAT-MESSAGE-P-OF-MAKE-TOOL-MESSAGE
# ...):  A :REWRITE rule generated from CHAT-MESSAGE-P-OF-MAKE-TOOL-MESSAGE
# will be triggered only by terms containing the function symbol
# MAKE-TOOL-MESSAGE, which has a non-recursive definition.  Unless this
# definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of CHAT-MESSAGE-P-OF-MAKE-TOOL-MESSAGE depends upon the
# :compound-recognizer rule CONSP-WHEN-CHAT-MESSAGE-P and the :type-
# prescription rule CHAT-MESSAGE-P.
#
# Summary
# Form:  ( DEFTHM CHAT-MESSAGE-P-OF-MAKE-TOOL-MESSAGE ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-CHAT-MESSAGE-P)
#         (:DEFINITION MAKE-TOOL-MESSAGE)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-TOOL)
#         (:REWRITE CHAT-MESSAGE-P-OF-CHAT-MESSAGE)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  12
# CHAT-MESSAGE-P-OF-MAKE-TOOL-MESSAGE
#
# Summary
# Form:  ( PROGN (DEFTHM CHAT-MESSAGE-P-OF-MAKE-TOOL-MESSAGE ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  12
#  MAKE-TOOL-MESSAGE

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Chat Message List
# ;;
# ;; A list of messages representing a conversation history.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(fty::deflist chat-message-list
  :elt-type chat-message-p
  :true-listp t)
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN CHAT-MESSAGE-LIST-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Deflist: attempting to show, using your current theory, that
# (CHAT-MESSAGE-P X) is always Boolean valued.
#
# Deflist: introducing CHAT-MESSAGE-LIST-P and proving deflist theorems.
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHAT-MESSAGE-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN CHAT-MESSAGE-LIST-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM CHAT-MESSAGE-LIST-P-OF-CHAT-MESSAGE-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM CHAT-MESSAGE-LIST-P-OF-CHAT-MESSAGE-LIST-FIX
# ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM CHAT-MESSAGE-LIST-FIX-WHEN-CHAT-MESSAGE-LIST-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS CHAT-MESSAGE-LIST-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Form:  ( DEFTHM CAR-OF-CHAT-MESSAGE-LIST-FIX-X-UNDER-CHAT-MESSAGE-EQUIV
# ...)
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
# Form:  ( DEFTHM CDR-OF-CHAT-MESSAGE-LIST-FIX-X-UNDER-CHAT-MESSAGE-LIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-CHAT-MESSAGE-FIX-X-UNDER-CHAT-MESSAGE-LIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-CHAT-MESSAGE-LIST-FIX-Y-UNDER-CHAT-MESSAGE-LIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM CONSP-OF-CHAT-MESSAGE-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CHAT-MESSAGE-LIST-FIX-UNDER-IFF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CHAT-MESSAGE-LIST-FIX-OF-CONS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM LEN-OF-CHAT-MESSAGE-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM CHAT-MESSAGE-LIST-FIX-OF-APPEND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM CHAT-MESSAGE-LIST-FIX-OF-REPEAT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/4
# Subgoal *1/4'
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM LIST-EQUIV-REFINES-CHAT-MESSAGE-LIST-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/3
# Subgoal *1/3.9
# Subgoal *1/3.9'
# Subgoal *1/3.9''
# Subgoal *1/3.9'''
# Subgoal *1/3.8
# Subgoal *1/3.7
# Subgoal *1/3.6
# Subgoal *1/3.5
# Subgoal *1/3.4
# Subgoal *1/3.3
# Subgoal *1/3.3'
# Subgoal *1/3.3''
# Subgoal *1/3.3'''
# Subgoal *1/3.2
# Subgoal *1/3.2'
# Subgoal *1/3.2''
# Subgoal *1/3.2'''
# Subgoal *1/3.1
# Subgoal *1/3.1'
# Subgoal *1/3.1''
# Subgoal *1/3.1'''
# Subgoal *1/2
# Subgoal *1/2.3
# Subgoal *1/2.3'
# Subgoal *1/2.2
# Subgoal *1/2.2'
# Subgoal *1/2.2''
# Subgoal *1/2.2'''
# Subgoal *1/2.1
# Subgoal *1/2.1'
# Subgoal *1/1
# Form:  ( DEFTHM NTH-OF-CHAT-MESSAGE-LIST-FIX ...)
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM
# CHAT-MESSAGE-LIST-EQUIV-IMPLIES-CHAT-MESSAGE-LIST-EQUIV-APPEND-1 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM
# CHAT-MESSAGE-LIST-EQUIV-IMPLIES-CHAT-MESSAGE-LIST-EQUIV-APPEND-2 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM
# CHAT-MESSAGE-LIST-EQUIV-IMPLIES-CHAT-MESSAGE-LIST-EQUIV-NTHCDR-2 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (DEFCONG-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM
# CHAT-MESSAGE-LIST-EQUIV-IMPLIES-CHAT-MESSAGE-LIST-EQUIV-TAKE-2 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (DEFCONG-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.06 seconds (prove: 0.05, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC CHAT-MESSAGE-LIST ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC CHAT-MESSAGE-LIST ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.10 seconds (prove: 0.05, print: 0.00, other: 0.05)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.10 seconds (prove: 0.05, print: 0.00, other: 0.06)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFLIST-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.10 seconds (prove: 0.05, print: 0.00, other: 0.06)
# Prover steps counted:  9089
#  T

# %%
;; Utility: Check if conversation has a system message
(define has-system-message-p ((messages chat-message-list-p))
  :returns (has booleanp)
  (if (endp messages)
      nil
    (let ((role (chat-message->role (car messages))))
      (or (chat-role-case role :system t :otherwise nil)
          (has-system-message-p (cdr messages))))))
# Out:
# The admission of HAS-SYSTEM-MESSAGE-P is trivial, using the relation
# O< (which is known to be well-founded on the domain recognized by O-P)
# and the measure (ACL2-COUNT MESSAGES).  We observe that the type of
# HAS-SYSTEM-MESSAGE-P is described by the theorem
# (OR (EQUAL (HAS-SYSTEM-MESSAGE-P MESSAGES)
#            T)
#     (EQUAL (HAS-SYSTEM-MESSAGE-P MESSAGES)
#            NIL)).
# We used primitive type reasoning.
#
# Computing the guard conjecture for HAS-SYSTEM-MESSAGE-P....
#
# The non-trivial part of the guard conjecture for HAS-SYSTEM-MESSAGE-P,
# given the :executable-counterpart of EQLABLEP, is
#
# Goal
# (IMPLIES (CHAT-MESSAGE-LIST-P MESSAGES)
#          (AND (OR (CONSP MESSAGES) (EQ MESSAGES NIL))
#               (OR (ENDP MESSAGES)
#                   (CONSP MESSAGES)
#                   (EQUAL MESSAGES NIL))
#               (OR (ENDP MESSAGES)
#                   (CHAT-MESSAGE-P (CAR MESSAGES)))
#               (OR (ENDP MESSAGES)
#                   (LET ((ROLE (CHAT-MESSAGE->ROLE (CAR MESSAGES))))
#                     (AND (CHAT-ROLE-P ROLE)
#                          (LET ((ROLE.KIND (CHAT-ROLE-KIND ROLE)))
#                            T)
#                          (OR (NOT (LET ((ROLE.KIND (CHAT-ROLE-KIND ROLE)))
#                                     (AND (EQL ROLE.KIND :SYSTEM) T)))
#                              (CHAT-ROLE-P ROLE))
#                          (OR (NOT (LET ((ROLE.KIND (CHAT-ROLE-KIND ROLE)))
#                                     (AND (EQL ROLE.KIND :SYSTEM) T)))
#                              (LET ((ROLE.KIND (CHAT-ROLE-KIND ROLE)))
#                                T))
#                          (OR (LET ((ROLE.KIND (CHAT-ROLE-KIND ROLE)))
#                                (AND (EQL ROLE.KIND :SYSTEM) T))
#                              (CONSP MESSAGES)
#                              (EQUAL MESSAGES NIL))
#                          (OR (LET ((ROLE.KIND (CHAT-ROLE-KIND ROLE)))
#                                (AND (EQL ROLE.KIND :SYSTEM) T))
#                              (CHAT-MESSAGE-LIST-P (CDR MESSAGES)))))))).
# Goal'
#
# Q.E.D.
#
# That completes the proof of the guard theorem for HAS-SYSTEM-MESSAGE-P.
# HAS-SYSTEM-MESSAGE-P is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN HAS-SYSTEM-MESSAGE-P ...)
# Rules: ((:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-CHAT-MESSAGE-LIST-P-COMPOUND-RECOGNIZER)
#         (:DEFINITION DOUBLE-REWRITE)
#         (:DEFINITION ENDP)
#         (:DEFINITION EQ)
#         (:DEFINITION EQL)
#         (:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART EQLABLEP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE CHAT-MESSAGE-LIST-P-OF-CDR-WHEN-CHAT-MESSAGE-LIST-P)
#         (:REWRITE CHAT-MESSAGE-P-OF-CAR-WHEN-CHAT-MESSAGE-LIST-P)
#         (:REWRITE CHAT-ROLE-P-OF-CHAT-MESSAGE->ROLE))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  350
#
#
# ACL2 !>>(DEFTHM BOOLEANP-OF-HAS-SYSTEM-MESSAGE-P
#           (B* ((HAS (HAS-SYSTEM-MESSAGE-P MESSAGES)))
#             (BOOLEANP HAS))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'HAS-SYSTEM-MESSAGE-P
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# *1 (the initial Goal, a key checkpoint) is pushed for proof by induction.
#
# We have been told to use induction.  One induction scheme is suggested
# by the induction hint.
#
# We will induct according to a scheme suggested by
# (HAS-SYSTEM-MESSAGE-P MESSAGES).
#
# This suggestion was produced using the :induction rule HAS-SYSTEM-MESSAGE-P.
# If we let (:P MESSAGES) denote *1 above then the induction scheme we'll
# use is
# (AND
#  (IMPLIES
#   (AND
#    (NOT (ENDP MESSAGES))
#    (NOT
#       (LET ((ROLE.KIND (CHAT-ROLE-KIND (CHAT-MESSAGE->ROLE (CAR MESSAGES)))))
#         (AND (EQL ROLE.KIND :SYSTEM) T)))
#    (:P (CDR MESSAGES)))
#   (:P MESSAGES))
#  (IMPLIES
#   (AND
#       (NOT (ENDP MESSAGES))
#       (LET ((ROLE.KIND (CHAT-ROLE-KIND (CHAT-MESSAGE->ROLE (CAR MESSAGES)))))
#         (AND (EQL ROLE.KIND :SYSTEM) T))
#       (NOT (EQL (CHAT-ROLE-KIND (CHAT-MESSAGE->ROLE (CAR MESSAGES)))
#                 :SYSTEM)))
#   (:P MESSAGES))
#  (IMPLIES
#   (AND
#       (NOT (ENDP MESSAGES))
#       (LET ((ROLE.KIND (CHAT-ROLE-KIND (CHAT-MESSAGE->ROLE (CAR MESSAGES)))))
#         (AND (EQL ROLE.KIND :SYSTEM) T))
#       (EQL (CHAT-ROLE-KIND (CHAT-MESSAGE->ROLE (CAR MESSAGES)))
#            :SYSTEM))
#   (:P MESSAGES))
#  (IMPLIES (ENDP MESSAGES)
#           (:P MESSAGES))).
# This induction is justified by the same argument used to admit
# HAS-SYSTEM-MESSAGE-P.  When applied to the goal at hand the above induction
# scheme produces four nontautological subgoals.
# Subgoal *1/4
# Subgoal *1/3
# Subgoal *1/2
# Subgoal *1/1
#
# *1 is COMPLETED!
# Thus key checkpoint Goal is COMPLETED!
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-HAS-SYSTEM-MESSAGE-P depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER and the :type-prescription
# rule HAS-SYSTEM-MESSAGE-P.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-HAS-SYSTEM-MESSAGE-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:INDUCTION HAS-SYSTEM-MESSAGE-P)
#         (:TYPE-PRESCRIPTION HAS-SYSTEM-MESSAGE-P))
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# BOOLEANP-OF-HAS-SYSTEM-MESSAGE-P
#
# Summary
# Form:  ( PROGN (DEFTHM BOOLEANP-OF-HAS-SYSTEM-MESSAGE-P ...) ...)
# Rules: NIL
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
#  HAS-SYSTEM-MESSAGE-P

# %%
;; Utility: Get the last assistant message content (if any)
(define last-assistant-content ((messages chat-message-list-p))
  :returns (content stringp)
  (if (endp messages)
      ""
    (let* ((msg (car (last messages)))
           (role (chat-message->role msg)))
      (if (chat-role-case role :assistant t :otherwise nil)
          (chat-message->content msg)
        ""))))
# Out:
# Since LAST-ASSISTANT-CONTENT is non-recursive, its admission is trivial.
# We observe that the type of LAST-ASSISTANT-CONTENT is described by
# the theorem (STRINGP (LAST-ASSISTANT-CONTENT MESSAGES)).  We used the
# :type-prescription rule CHAT-MESSAGE->CONTENT$INLINE.
#
# Computing the guard conjecture for LAST-ASSISTANT-CONTENT....
#
# The non-trivial part of the guard conjecture for LAST-ASSISTANT-CONTENT,
# given the :executable-counterpart of EQLABLEP, is
#
# Goal
# (IMPLIES
#      (CHAT-MESSAGE-LIST-P MESSAGES)
#      (AND (OR (CONSP MESSAGES) (EQ MESSAGES NIL))
#           (OR (ENDP MESSAGES) (LISTP MESSAGES))
#           (OR (ENDP MESSAGES)
#               (CONSP (LAST MESSAGES))
#               (EQUAL (LAST MESSAGES) NIL))
#           (OR (ENDP MESSAGES)
#               (LET ((MSG (CAR (LAST MESSAGES))))
#                 (AND (CHAT-MESSAGE-P MSG)
#                      (LET ((ROLE (CHAT-MESSAGE->ROLE MSG)))
#                        (AND (CHAT-ROLE-P ROLE)
#                             (LET ((ROLE.KIND (CHAT-ROLE-KIND ROLE)))
#                               T)
#                             (OR (NOT (LET ((ROLE.KIND (CHAT-ROLE-KIND ROLE)))
#                                        (AND (EQL ROLE.KIND :ASSISTANT) T)))
#                                 (CHAT-MESSAGE-P MSG))))))))).
# Goal'
# Goal''
#
# ([ A key checkpoint:
#
# Goal''
# (IMPLIES (AND (CHAT-MESSAGE-LIST-P MESSAGES)
#               (CONSP MESSAGES))
#          (CHAT-MESSAGE-P (CAR (LAST MESSAGES))))
#
# *1 (Goal'') is pushed for proof by induction.
#
# ])
#
# Perhaps we can prove *1 by induction.  One induction scheme is suggested
# by this conjecture.
#
# We will induct according to a scheme suggested by (LAST MESSAGES).
#
# This suggestion was produced using the :induction rule LAST.  If we
# let (:P MESSAGES) denote *1 above then the induction scheme we'll use
# is
# (AND (IMPLIES (AND (NOT (ATOM (CDR MESSAGES)))
#                    (:P (CDR MESSAGES)))
#               (:P MESSAGES))
#      (IMPLIES (ATOM (CDR MESSAGES))
#               (:P MESSAGES))).
# This induction is justified by the same argument used to admit LAST.
# When applied to the goal at hand the above induction scheme produces
# three nontautological subgoals.
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
#
# *1 is COMPLETED!
# Thus key checkpoint Goal'' is COMPLETED!
#
# Q.E.D.
#
# That completes the proof of the guard theorem for LAST-ASSISTANT-CONTENT.
# LAST-ASSISTANT-CONTENT is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LAST-ASSISTANT-CONTENT ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-CHAT-MESSAGE-P)
#         (:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-CHAT-MESSAGE-LIST-P-COMPOUND-RECOGNIZER)
#         (:DEFINITION ATOM)
#         (:DEFINITION DOUBLE-REWRITE)
#         (:DEFINITION ENDP)
#         (:DEFINITION EQ)
#         (:DEFINITION EQL)
#         (:DEFINITION LAST)
#         (:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART EQLABLEP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION LAST)
#         (:REWRITE CHAT-MESSAGE-LIST-P-OF-CDR-WHEN-CHAT-MESSAGE-LIST-P)
#         (:REWRITE CHAT-MESSAGE-P-OF-CAR-WHEN-CHAT-MESSAGE-LIST-P)
#         (:REWRITE CHAT-ROLE-P-OF-CHAT-MESSAGE->ROLE)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE->CONTENT$INLINE)
#         (:TYPE-PRESCRIPTION CHAT-MESSAGE-P)
#         (:TYPE-PRESCRIPTION LAST))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  658
#
#
# ACL2 !>>(DEFTHM STRINGP-OF-LAST-ASSISTANT-CONTENT
#           (B* ((CONTENT (LAST-ASSISTANT-CONTENT MESSAGES)))
#             (STRINGP CONTENT))
#           :HINTS
#           ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'LAST-ASSISTANT-CONTENT
#                                                  ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-LAST-ASSISTANT-CONTENT
# ...):  A :REWRITE rule generated from STRINGP-OF-LAST-ASSISTANT-CONTENT
# will be triggered only by terms containing the function symbol
# LAST-ASSISTANT-CONTENT, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-LAST-ASSISTANT-CONTENT depends upon the :type-
# prescription rule LAST-ASSISTANT-CONTENT.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-LAST-ASSISTANT-CONTENT ...)
# Rules: ((:TYPE-PRESCRIPTION LAST-ASSISTANT-CONTENT))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# STRINGP-OF-LAST-ASSISTANT-CONTENT
#
# Summary
# Form:  ( PROGN (DEFTHM STRINGP-OF-LAST-ASSISTANT-CONTENT ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  LAST-ASSISTANT-CONTENT

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Role to String Conversion (for JSON serialization)
# ;;
# ;; These are pure ACL2 functions - the raw Lisp code will use them.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(define chat-role-to-string ((role chat-role-p))
  :returns (s stringp)
  (chat-role-case role
    :system "system"
    :user "user"
    :assistant "assistant"
    :tool "tool"))
# Out:
# Since CHAT-ROLE-TO-STRING is non-recursive, its admission is trivial.
# We observe that the type of CHAT-ROLE-TO-STRING is described by the
# theorem (STRINGP (CHAT-ROLE-TO-STRING ROLE)).
#
# Computing the guard conjecture for CHAT-ROLE-TO-STRING....
#
# The guard conjecture for CHAT-ROLE-TO-STRING is trivial to prove, given
# the :compound-recognizer rule CONSP-WHEN-CHAT-ROLE-P and the :executable-
# counterpart of EQLABLEP.  CHAT-ROLE-TO-STRING is compliant with Common
# Lisp.
#
# Summary
# Form:  ( DEFUN CHAT-ROLE-TO-STRING ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-CHAT-ROLE-P)
#         (:EXECUTABLE-COUNTERPART EQLABLEP))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#
#
# ACL2 !>>(DEFTHM STRINGP-OF-CHAT-ROLE-TO-STRING
#           (B* ((S (CHAT-ROLE-TO-STRING ROLE)))
#             (STRINGP S))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'CHAT-ROLE-TO-STRING
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-CHAT-ROLE-TO-STRING ...):
# A :REWRITE rule generated from STRINGP-OF-CHAT-ROLE-TO-STRING will
# be triggered only by terms containing the function symbol
# CHAT-ROLE-TO-STRING, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-CHAT-ROLE-TO-STRING depends upon the :type-
# prescription rule CHAT-ROLE-TO-STRING.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-CHAT-ROLE-TO-STRING ...)
# Rules: ((:TYPE-PRESCRIPTION CHAT-ROLE-TO-STRING))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# STRINGP-OF-CHAT-ROLE-TO-STRING
#
# Summary
# Form:  ( PROGN (DEFTHM STRINGP-OF-CHAT-ROLE-TO-STRING ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  CHAT-ROLE-TO-STRING

# %%
(define string-to-chat-role ((s stringp))
  :returns (role chat-role-p)
  (cond ((equal s "system") (role-system))
        ((equal s "user") (role-user))
        ((equal s "assistant") (role-assistant))
        ((equal s "tool") (role-tool))
        ;; Default to user for unknown roles
        (t (role-user))))
# Out:
# Since STRING-TO-CHAT-ROLE is non-recursive, its admission is trivial.
# We observe that the type of STRING-TO-CHAT-ROLE is described by the
# theorem
# (AND (CONSP (STRING-TO-CHAT-ROLE S)) (TRUE-LISTP (STRING-TO-CHAT-ROLE S))).
# We used the :type-prescription rules CHAT-ROLE-ASSISTANT, CHAT-ROLE-SYSTEM,
# CHAT-ROLE-TOOL and CHAT-ROLE-USER.
#
# Computing the guard conjecture for STRING-TO-CHAT-ROLE....
#
# The guard conjecture for STRING-TO-CHAT-ROLE is trivial to prove.
# STRING-TO-CHAT-ROLE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN STRING-TO-CHAT-ROLE ...)
# Rules: ((:TYPE-PRESCRIPTION CHAT-ROLE-ASSISTANT)
#         (:TYPE-PRESCRIPTION CHAT-ROLE-SYSTEM)
#         (:TYPE-PRESCRIPTION CHAT-ROLE-TOOL)
#         (:TYPE-PRESCRIPTION CHAT-ROLE-USER))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM CHAT-ROLE-P-OF-STRING-TO-CHAT-ROLE
#           (B* ((ROLE (STRING-TO-CHAT-ROLE S)))
#             (CHAT-ROLE-P ROLE))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'STRING-TO-CHAT-ROLE
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM CHAT-ROLE-P-OF-STRING-TO-CHAT-ROLE
# ...):  A :REWRITE rule generated from CHAT-ROLE-P-OF-STRING-TO-CHAT-ROLE
# will be triggered only by terms containing the function symbol
# STRING-TO-CHAT-ROLE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
# Goal'
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of CHAT-ROLE-P-OF-STRING-TO-CHAT-ROLE depends upon the
# :compound-recognizer rule CONSP-WHEN-CHAT-ROLE-P and the :type-prescription
# rule CHAT-ROLE-P.
#
# Summary
# Form:  ( DEFTHM CHAT-ROLE-P-OF-STRING-TO-CHAT-ROLE ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-CHAT-ROLE-P)
#         (:DEFINITION STRING-TO-CHAT-ROLE)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-ASSISTANT)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-P)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-SYSTEM)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-TOOL)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-USER)
#         (:TYPE-PRESCRIPTION CHAT-ROLE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  128
# CHAT-ROLE-P-OF-STRING-TO-CHAT-ROLE
#
# Summary
# Form:  ( PROGN (DEFTHM CHAT-ROLE-P-OF-STRING-TO-CHAT-ROLE ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  128
#  STRING-TO-CHAT-ROLE

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Basic Theorems
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(defthm chat-role-to-string-returns-valid-string
  (implies (chat-role-p role)
           (member-equal (chat-role-to-string role)
                        '("system" "user" "assistant" "tool")))
  :hints (("Goal" :in-theory (enable chat-role-to-string))))
# Out:
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM CHAT-ROLE-TO-STRING-RETURNS-VALID-STRING ...)
# Rules: ((:DEFINITION CHAT-ROLE-TO-STRING)
#         (:DEFINITION MEMBER-EQUAL)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  319
#  CHAT-ROLE-TO-STRING-RETURNS-VALID-STRING

# %%
(defthm string-to-chat-role-roundtrip
  (implies (and (stringp s)
                (member-equal s '("system" "user" "assistant" "tool")))
           (equal (chat-role-to-string (string-to-chat-role s)) s))
  :hints (("Goal" :in-theory (enable chat-role-to-string string-to-chat-role))))
# Out:
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM STRING-TO-CHAT-ROLE-ROUNDTRIP ...)
# Rules: ((:DEFINITION CHAT-ROLE-TO-STRING)
#         (:DEFINITION MEMBER-EQUAL)
#         (:DEFINITION STRING-TO-CHAT-ROLE)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-ASSISTANT)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-KIND$INLINE)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-SYSTEM)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-TOOL)
#         (:EXECUTABLE-COUNTERPART CHAT-ROLE-USER)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART STRINGP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  342
#  STRING-TO-CHAT-ROLE-ROUNDTRIP

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Model Type
# ;;
# ;; Type of model: llm (chat/completion), vlm (vision), embeddings
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(fty::deftagsum model-type
  (:llm ())         ; Language model for chat/completion
  (:vlm ())         ; Vision-language model
  (:embeddings ())) ; Embedding model
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-TYPE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CONSP-WHEN-MODEL-TYPE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-TYPE-KIND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN MODEL-TYPE-KIND$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MODEL-TYPE-KIND-POSSIBILITIES ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE RULESET-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-TYPE-KIND-POSSIBILITIES ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-TYPE-CASE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-TYPE-KIND-EQ ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-TYPE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-TYPE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 4
# Subgoal 3
# Subgoal 3'
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM MODEL-TYPE-P-OF-MODEL-TYPE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-TYPE-P-OF-MODEL-TYPE-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MODEL-TYPE-FIX-WHEN-MODEL-TYPE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS MODEL-TYPE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM MODEL-TYPE-KIND$INLINE-OF-MODEL-TYPE-FIX-X ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM CONSP-OF-MODEL-TYPE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TAG-WHEN-MODEL-TYPE-P-FORWARD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM TAG-OF-MODEL-TYPE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE RULESET-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-TYPE-LLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-MODEL-TYPE-LLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-MODEL-TYPE-LLM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-TYPE-FIX-WHEN-LLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-MODEL-TYPE-LLM ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFMACRO PATBIND-MODEL-TYPE-LLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-MODEL-TYPE-LLM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-MODEL-TYPE-LLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-MODEL-TYPE-LLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-TYPE-FIX-WHEN-LLM ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-TYPE-VLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-MODEL-TYPE-VLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-MODEL-TYPE-VLM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-TYPE-FIX-WHEN-VLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-MODEL-TYPE-VLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO PATBIND-MODEL-TYPE-VLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-MODEL-TYPE-VLM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-MODEL-TYPE-VLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-MODEL-TYPE-VLM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-TYPE-FIX-WHEN-VLM ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-TYPE-EMBEDDINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-MODEL-TYPE-EMBEDDINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-MODEL-TYPE-EMBEDDINGS ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-TYPE-FIX-WHEN-EMBEDDINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-MODEL-TYPE-EMBEDDINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO PATBIND-MODEL-TYPE-EMBEDDINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-MODEL-TYPE-EMBEDDINGS ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-MODEL-TYPE-EMBEDDINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-MODEL-TYPE-EMBEDDINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-TYPE-FIX-WHEN-EMBEDDINGS ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM MODEL-TYPE-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MODEL-TYPE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MODEL-TYPE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.09 seconds (prove: 0.01, print: 0.00, other: 0.08)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.10 seconds (prove: 0.01, print: 0.00, other: 0.09)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFTAGSUM-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.10 seconds (prove: 0.01, print: 0.00, other: 0.09)
# Prover steps counted:  2406
#  T

# %%
(define model-type-to-string ((mt model-type-p))
  :returns (s stringp)
  (model-type-case mt
    :llm "llm"
    :vlm "vlm"
    :embeddings "embeddings"))
# Out:
# Since MODEL-TYPE-TO-STRING is non-recursive, its admission is trivial.
# We observe that the type of MODEL-TYPE-TO-STRING is described by the
# theorem (STRINGP (MODEL-TYPE-TO-STRING MT)).
#
# Computing the guard conjecture for MODEL-TYPE-TO-STRING....
#
# The guard conjecture for MODEL-TYPE-TO-STRING is trivial to prove,
# given the :compound-recognizer rule CONSP-WHEN-MODEL-TYPE-P and the
# :executable-counterpart of EQLABLEP.  MODEL-TYPE-TO-STRING is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN MODEL-TYPE-TO-STRING ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-MODEL-TYPE-P)
#         (:EXECUTABLE-COUNTERPART EQLABLEP))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM STRINGP-OF-MODEL-TYPE-TO-STRING
#           (B* ((S (MODEL-TYPE-TO-STRING MT)))
#             (STRINGP S))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'MODEL-TYPE-TO-STRING
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-MODEL-TYPE-TO-STRING
# ...):  A :REWRITE rule generated from STRINGP-OF-MODEL-TYPE-TO-STRING
# will be triggered only by terms containing the function symbol
# MODEL-TYPE-TO-STRING, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-MODEL-TYPE-TO-STRING depends upon the :type-
# prescription rule MODEL-TYPE-TO-STRING.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-MODEL-TYPE-TO-STRING ...)
# Rules: ((:TYPE-PRESCRIPTION MODEL-TYPE-TO-STRING))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# STRINGP-OF-MODEL-TYPE-TO-STRING
#
# Summary
# Form:  ( PROGN (DEFTHM STRINGP-OF-MODEL-TYPE-TO-STRING ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MODEL-TYPE-TO-STRING

# %%
(define string-to-model-type ((s stringp))
  :returns (mt model-type-p)
  (cond ((equal s "llm") (model-type-llm))
        ((equal s "vlm") (model-type-vlm))
        ((equal s "embeddings") (model-type-embeddings))
        ;; Default to llm for unknown
        (t (model-type-llm))))
# Out:
# Since STRING-TO-MODEL-TYPE is non-recursive, its admission is trivial.
# We observe that the type of STRING-TO-MODEL-TYPE is described by the
# theorem
# (AND (CONSP (STRING-TO-MODEL-TYPE S)) (TRUE-LISTP (STRING-TO-MODEL-TYPE S))).
# We used the :type-prescription rules MODEL-TYPE-EMBEDDINGS, MODEL-TYPE-LLM
# and MODEL-TYPE-VLM.
#
# Computing the guard conjecture for STRING-TO-MODEL-TYPE....
#
# The guard conjecture for STRING-TO-MODEL-TYPE is trivial to prove.
# STRING-TO-MODEL-TYPE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN STRING-TO-MODEL-TYPE ...)
# Rules: ((:TYPE-PRESCRIPTION MODEL-TYPE-EMBEDDINGS)
#         (:TYPE-PRESCRIPTION MODEL-TYPE-LLM)
#         (:TYPE-PRESCRIPTION MODEL-TYPE-VLM))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM MODEL-TYPE-P-OF-STRING-TO-MODEL-TYPE
#           (B* ((MT (STRING-TO-MODEL-TYPE S)))
#             (MODEL-TYPE-P MT))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'STRING-TO-MODEL-TYPE
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM MODEL-TYPE-P-OF-STRING-TO-MODEL-TYPE
# ...):  A :REWRITE rule generated from MODEL-TYPE-P-OF-STRING-TO-MODEL-TYPE
# will be triggered only by terms containing the function symbol
# STRING-TO-MODEL-TYPE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
# Goal'
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of MODEL-TYPE-P-OF-STRING-TO-MODEL-TYPE depends upon the
# :compound-recognizer rule CONSP-WHEN-MODEL-TYPE-P and the :type-prescription
# rule MODEL-TYPE-P.
#
# Summary
# Form:  ( DEFTHM MODEL-TYPE-P-OF-STRING-TO-MODEL-TYPE ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-MODEL-TYPE-P)
#         (:DEFINITION STRING-TO-MODEL-TYPE)
#         (:EXECUTABLE-COUNTERPART MODEL-TYPE-EMBEDDINGS)
#         (:EXECUTABLE-COUNTERPART MODEL-TYPE-LLM)
#         (:EXECUTABLE-COUNTERPART MODEL-TYPE-P)
#         (:EXECUTABLE-COUNTERPART MODEL-TYPE-VLM)
#         (:TYPE-PRESCRIPTION MODEL-TYPE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  100
# MODEL-TYPE-P-OF-STRING-TO-MODEL-TYPE
#
# Summary
# Form:  ( PROGN (DEFTHM MODEL-TYPE-P-OF-STRING-TO-MODEL-TYPE ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  100
#  STRING-TO-MODEL-TYPE

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Model State
# ;;
# ;; Whether a model is loaded into memory or not
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(fty::deftagsum model-state
  (:loaded ())
  (:not-loaded ()))
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-STATE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CONSP-WHEN-MODEL-STATE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-STATE-KIND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN MODEL-STATE-KIND$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MODEL-STATE-KIND-POSSIBILITIES ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE RULESET-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-STATE-KIND-POSSIBILITIES ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-STATE-CASE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-STATE-KIND-EQ ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-STATE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-STATE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 3
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Form:  ( DEFTHM MODEL-STATE-P-OF-MODEL-STATE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-STATE-P-OF-MODEL-STATE-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MODEL-STATE-FIX-WHEN-MODEL-STATE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS MODEL-STATE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM MODEL-STATE-KIND$INLINE-OF-MODEL-STATE-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM CONSP-OF-MODEL-STATE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TAG-WHEN-MODEL-STATE-P-FORWARD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM TAG-OF-MODEL-STATE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE RULESET-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-STATE-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-MODEL-STATE-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-MODEL-STATE-LOADED ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-STATE-FIX-WHEN-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-MODEL-STATE-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO PATBIND-MODEL-STATE-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-MODEL-STATE-LOADED ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-MODEL-STATE-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-MODEL-STATE-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-STATE-FIX-WHEN-LOADED ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-STATE-NOT-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-MODEL-STATE-NOT-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-MODEL-STATE-NOT-LOADED ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-STATE-FIX-WHEN-NOT-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-MODEL-STATE-NOT-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO PATBIND-MODEL-STATE-NOT-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-MODEL-STATE-NOT-LOADED ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-MODEL-STATE-NOT-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-MODEL-STATE-NOT-LOADED ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-STATE-FIX-WHEN-NOT-LOADED ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM MODEL-STATE-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MODEL-STATE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MODEL-STATE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.08 seconds (prove: 0.01, print: 0.00, other: 0.07)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.09 seconds (prove: 0.01, print: 0.00, other: 0.08)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFTAGSUM-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.09 seconds (prove: 0.01, print: 0.00, other: 0.08)
# Prover steps counted:  1697
#  T

# %%
(define model-state-to-string ((ms model-state-p))
  :returns (s stringp)
  (model-state-case ms
    :loaded "loaded"
    :not-loaded "not-loaded"))
# Out:
# Since MODEL-STATE-TO-STRING is non-recursive, its admission is trivial.
# We observe that the type of MODEL-STATE-TO-STRING is described by the
# theorem (STRINGP (MODEL-STATE-TO-STRING MS)).
#
# Computing the guard conjecture for MODEL-STATE-TO-STRING....
#
# The guard conjecture for MODEL-STATE-TO-STRING is trivial to prove,
# given the :compound-recognizer rule CONSP-WHEN-MODEL-STATE-P and the
# :executable-counterpart of EQLABLEP.  MODEL-STATE-TO-STRING is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN MODEL-STATE-TO-STRING ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-MODEL-STATE-P)
#         (:EXECUTABLE-COUNTERPART EQLABLEP))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM STRINGP-OF-MODEL-STATE-TO-STRING
#          (B* ((S (MODEL-STATE-TO-STRING MS)))
#            (STRINGP S))
#          :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'MODEL-STATE-TO-STRING
#                                                        ID WORLD))
#          :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-MODEL-STATE-TO-STRING
# ...):  A :REWRITE rule generated from STRINGP-OF-MODEL-STATE-TO-STRING
# will be triggered only by terms containing the function symbol
# MODEL-STATE-TO-STRING, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-MODEL-STATE-TO-STRING depends upon the :type-
# prescription rule MODEL-STATE-TO-STRING.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-MODEL-STATE-TO-STRING ...)
# Rules: ((:TYPE-PRESCRIPTION MODEL-STATE-TO-STRING))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# STRINGP-OF-MODEL-STATE-TO-STRING
#
# Summary
# Form:  ( PROGN (DEFTHM STRINGP-OF-MODEL-STATE-TO-STRING ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MODEL-STATE-TO-STRING

# %%
(define string-to-model-state ((s stringp))
  :returns (ms model-state-p)
  (if (equal s "loaded")
      (model-state-loaded)
    (model-state-not-loaded)))
# Out:
# Since STRING-TO-MODEL-STATE is non-recursive, its admission is trivial.
# We observe that the type of STRING-TO-MODEL-STATE is described by the
# theorem
# (AND (CONSP (STRING-TO-MODEL-STATE S))
#      (TRUE-LISTP (STRING-TO-MODEL-STATE S))).
# We used the :type-prescription rules MODEL-STATE-LOADED and
# MODEL-STATE-NOT-LOADED.
#
# Computing the guard conjecture for STRING-TO-MODEL-STATE....
#
# The guard conjecture for STRING-TO-MODEL-STATE is trivial to prove.
# STRING-TO-MODEL-STATE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN STRING-TO-MODEL-STATE ...)
# Rules: ((:TYPE-PRESCRIPTION MODEL-STATE-LOADED)
#         (:TYPE-PRESCRIPTION MODEL-STATE-NOT-LOADED))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM MODEL-STATE-P-OF-STRING-TO-MODEL-STATE
#          (B* ((MS (STRING-TO-MODEL-STATE S)))
#            (MODEL-STATE-P MS))
#          :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'STRING-TO-MODEL-STATE
#                                                        ID WORLD))
#          :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM MODEL-STATE-P-OF-STRING-TO-MODEL-STATE
# ...):  A :REWRITE rule generated from MODEL-STATE-P-OF-STRING-TO-MODEL-STATE
# will be triggered only by terms containing the function symbol
# STRING-TO-MODEL-STATE, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
# Goal'
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of MODEL-STATE-P-OF-STRING-TO-MODEL-STATE depends upon
# the :compound-recognizer rule CONSP-WHEN-MODEL-STATE-P and the :type-
# prescription rule MODEL-STATE-P.
#
# Summary
# Form:  ( DEFTHM MODEL-STATE-P-OF-STRING-TO-MODEL-STATE ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-MODEL-STATE-P)
#         (:DEFINITION STRING-TO-MODEL-STATE)
#         (:EXECUTABLE-COUNTERPART MODEL-STATE-LOADED)
#         (:EXECUTABLE-COUNTERPART MODEL-STATE-NOT-LOADED)
#         (:EXECUTABLE-COUNTERPART MODEL-STATE-P)
#         (:TYPE-PRESCRIPTION MODEL-STATE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  49
# MODEL-STATE-P-OF-STRING-TO-MODEL-STATE
#
# Summary
# Form:  ( PROGN (DEFTHM MODEL-STATE-P-OF-STRING-TO-MODEL-STATE ...)
# ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  49
#  STRING-TO-MODEL-STATE

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Model Info
# ;;
# ;; Full information about a model from LM Studio /api/v0/models
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(fty::defprod model-info
  ((id stringp "Model identifier" :default "")
   (type model-type-p "Type: llm, vlm, or embeddings")
   (load-state model-state-p "Whether model is loaded")
   (publisher stringp "Model publisher" :default "")
   (arch stringp "Model architecture" :default "")
   (quantization stringp "Quantization level" :default "")
   (max-context-length natp "Maximum context length" :default 0)
   (loaded-context-length natp "Loaded context length (0 if not loaded)" :default 0))
  :layout :list)
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TMP-DEFTYPES-STRINGP-OF-STR-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TMP-DEFTYPES-NATP-OF-NFIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM TMP-DEFTYPES-NFIX-WHEN-NATP ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFUN MODEL-INFO-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONSP-WHEN-MODEL-INFO-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-INFO-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MODEL-INFO-P-OF-MODEL-INFO-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-INFO-P-OF-MODEL-INFO-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MODEL-INFO-FIX-WHEN-MODEL-INFO-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS MODEL-INFO-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO->ID ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MODEL-INFO->ID$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-MODEL-INFO->ID ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-MODEL-INFO->ID ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO->ID$INLINE-OF-MODEL-INFO-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV MODEL-INFO->ID ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO->TYPE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MODEL-INFO->TYPE$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MODEL-TYPE-P-OF-MODEL-INFO->TYPE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-TYPE-P-OF-MODEL-INFO->TYPE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO->TYPE$INLINE-OF-MODEL-INFO-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV MODEL-INFO->TYPE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO->LOAD-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MODEL-INFO->LOAD-STATE$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MODEL-STATE-P-OF-MODEL-INFO->LOAD-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-STATE-P-OF-MODEL-INFO->LOAD-STATE ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO->LOAD-STATE$INLINE-OF-MODEL-INFO-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV MODEL-INFO->LOAD-STATE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO->PUBLISHER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MODEL-INFO->PUBLISHER$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-MODEL-INFO->PUBLISHER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-MODEL-INFO->PUBLISHER ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO->PUBLISHER$INLINE-OF-MODEL-INFO-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV MODEL-INFO->PUBLISHER ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO->ARCH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MODEL-INFO->ARCH$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-MODEL-INFO->ARCH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-MODEL-INFO->ARCH ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO->ARCH$INLINE-OF-MODEL-INFO-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV MODEL-INFO->ARCH ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO->QUANTIZATION ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MODEL-INFO->QUANTIZATION$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-MODEL-INFO->QUANTIZATION ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-MODEL-INFO->QUANTIZATION ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO->QUANTIZATION$INLINE-OF-MODEL-INFO-FIX-X
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV MODEL-INFO->QUANTIZATION ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO->MAX-CONTEXT-LENGTH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MODEL-INFO->MAX-CONTEXT-LENGTH$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM NATP-OF-MODEL-INFO->MAX-CONTEXT-LENGTH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM NATP-OF-MODEL-INFO->MAX-CONTEXT-LENGTH ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO->MAX-CONTEXT-LENGTH$INLINE-OF-MODEL-INFO-FIX-X
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV MODEL-INFO->MAX-CONTEXT-LENGTH ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO->LOADED-CONTEXT-LENGTH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MODEL-INFO->LOADED-CONTEXT-LENGTH$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM NATP-OF-MODEL-INFO->LOADED-CONTEXT-LENGTH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM NATP-OF-MODEL-INFO->LOADED-CONTEXT-LENGTH ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO->LOADED-CONTEXT-LENGTH$INLINE-OF-MODEL-INFO-FIX-X
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV MODEL-INFO->LOADED-CONTEXT-LENGTH
# ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM MODEL-INFO-P-OF-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-INFO-P-OF-MODEL-INFO ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MODEL-INFO->ID-OF-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MODEL-INFO->TYPE-OF-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MODEL-INFO->LOAD-STATE-OF-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MODEL-INFO->PUBLISHER-OF-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MODEL-INFO->ARCH-OF-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MODEL-INFO->QUANTIZATION-OF-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MODEL-INFO->MAX-CONTEXT-LENGTH-OF-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MODEL-INFO->LOADED-CONTEXT-LENGTH-OF-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO-OF-FIELDS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO-FIX-WHEN-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 10
# Subgoal 10'
# Subgoal 10''
# Subgoal 10'''
# Subgoal 9
# Subgoal 8
# Subgoal 7
# Subgoal 6
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM EQUAL-OF-MODEL-INFO ...)
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO-OF-STR-FIX-ID ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'
# Form:  ( DEFTHM MODEL-INFO-OF-MODEL-TYPE-FIX-TYPE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM MODEL-INFO-OF-MODEL-STATE-FIX-LOAD-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM MODEL-INFO-OF-STR-FIX-PUBLISHER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'
# Form:  ( DEFTHM MODEL-INFO-OF-STR-FIX-ARCH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'
# Form:  ( DEFTHM MODEL-INFO-OF-STR-FIX-QUANTIZATION ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'
# Form:  ( DEFTHM MODEL-INFO-OF-NFIX-MAX-CONTEXT-LENGTH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM MODEL-INFO-OF-NFIX-LOADED-CONTEXT-LENGTH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFMACRO PATBIND-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-MODEL-INFO ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-MODEL-INFO ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-INFO->ID-OF-MODEL-INFO ...) ...)
# Time:  0.03 seconds (prove: 0.02, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MODEL-INFO-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MODEL-INFO ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MODEL-INFO ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.13 seconds (prove: 0.03, print: 0.00, other: 0.09)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.13 seconds (prove: 0.03, print: 0.00, other: 0.10)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFPROD-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.13 seconds (prove: 0.03, print: 0.00, other: 0.10)
# Prover steps counted:  20385
#  T

# %%
;; Predicate helpers
(define model-loaded-p ((m model-info-p))
  :returns (loaded booleanp)
  (let ((st (model-info->load-state m)))
    (model-state-case st
      :loaded t
      :not-loaded nil)))
# Out:
# Since MODEL-LOADED-P is non-recursive, its admission is trivial.  We
# observe that the type of MODEL-LOADED-P is described by the theorem
# (OR (EQUAL (MODEL-LOADED-P M) T) (EQUAL (MODEL-LOADED-P M) NIL)).
# We used primitive type reasoning.
#
# Computing the guard conjecture for MODEL-LOADED-P....
#
# The non-trivial part of the guard conjecture for MODEL-LOADED-P, given
# the :executable-counterpart of EQLABLEP, is
#
# Goal
# (IMPLIES (MODEL-INFO-P M)
#          (AND (MODEL-INFO-P M)
#               (LET ((ST (MODEL-INFO->LOAD-STATE M)))
#                 (AND (MODEL-STATE-P ST)
#                      (LET ((ST.KIND (MODEL-STATE-KIND ST)))
#                        T))))).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for MODEL-LOADED-P.
# MODEL-LOADED-P is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MODEL-LOADED-P ...)
# Rules: ((:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART EQLABLEP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE MODEL-STATE-P-OF-MODEL-INFO->LOAD-STATE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  28
#
#
# ACL2 !>>(DEFTHM BOOLEANP-OF-MODEL-LOADED-P
#           (B* ((LOADED (MODEL-LOADED-P M)))
#             (BOOLEANP LOADED))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'MODEL-LOADED-P
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM BOOLEANP-OF-MODEL-LOADED-P ...):
# A :REWRITE rule generated from BOOLEANP-OF-MODEL-LOADED-P will be triggered
# only by terms containing the function symbol MODEL-LOADED-P, which
# has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-MODEL-LOADED-P depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER and the :type-prescription
# rule MODEL-LOADED-P.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-MODEL-LOADED-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION MODEL-LOADED-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# BOOLEANP-OF-MODEL-LOADED-P
#
# Summary
# Form:  ( PROGN (DEFTHM BOOLEANP-OF-MODEL-LOADED-P ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MODEL-LOADED-P

# %%
(define model-is-llm-p ((m model-info-p))
  :returns (is-llm booleanp)
  (let ((tp (model-info->type m)))
    (model-type-case tp
      :llm t
      :otherwise nil)))
# Out:
# Since MODEL-IS-LLM-P is non-recursive, its admission is trivial.  We
# observe that the type of MODEL-IS-LLM-P is described by the theorem
# (OR (EQUAL (MODEL-IS-LLM-P M) T) (EQUAL (MODEL-IS-LLM-P M) NIL)).
# We used primitive type reasoning.
#
# Computing the guard conjecture for MODEL-IS-LLM-P....
#
# The non-trivial part of the guard conjecture for MODEL-IS-LLM-P, given
# the :executable-counterpart of EQLABLEP, is
#
# Goal
# (IMPLIES (MODEL-INFO-P M)
#          (AND (MODEL-INFO-P M)
#               (LET ((TP (MODEL-INFO->TYPE M)))
#                 (AND (MODEL-TYPE-P TP)
#                      (LET ((TP.KIND (MODEL-TYPE-KIND TP)))
#                        T))))).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for MODEL-IS-LLM-P.
# MODEL-IS-LLM-P is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MODEL-IS-LLM-P ...)
# Rules: ((:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART EQLABLEP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE MODEL-TYPE-P-OF-MODEL-INFO->TYPE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  28
#
#
# ACL2 !>>(DEFTHM BOOLEANP-OF-MODEL-IS-LLM-P
#           (B* ((IS-LLM (MODEL-IS-LLM-P M)))
#             (BOOLEANP IS-LLM))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'MODEL-IS-LLM-P
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM BOOLEANP-OF-MODEL-IS-LLM-P ...):
# A :REWRITE rule generated from BOOLEANP-OF-MODEL-IS-LLM-P will be triggered
# only by terms containing the function symbol MODEL-IS-LLM-P, which
# has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-MODEL-IS-LLM-P depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER and the :type-prescription
# rule MODEL-IS-LLM-P.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-MODEL-IS-LLM-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION MODEL-IS-LLM-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# BOOLEANP-OF-MODEL-IS-LLM-P
#
# Summary
# Form:  ( PROGN (DEFTHM BOOLEANP-OF-MODEL-IS-LLM-P ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MODEL-IS-LLM-P

# %%
(define model-is-completions-p ((m model-info-p))
  :returns (is-completions booleanp)
  "True for models that can do chat/text completions (llm or vlm)"
  (let ((tp (model-info->type m)))
    (model-type-case tp
      :llm t
      :vlm t
      :embeddings nil)))
# Out:
# Since MODEL-IS-COMPLETIONS-P is non-recursive, its admission is trivial.
# We observe that the type of MODEL-IS-COMPLETIONS-P is described by
# the theorem
# (OR (EQUAL (MODEL-IS-COMPLETIONS-P M) T)
#     (EQUAL (MODEL-IS-COMPLETIONS-P M) NIL)).
# We used primitive type reasoning.
#
# Computing the guard conjecture for MODEL-IS-COMPLETIONS-P....
#
# The non-trivial part of the guard conjecture for MODEL-IS-COMPLETIONS-P,
# given the :executable-counterpart of EQLABLEP, is
#
# Goal
# (IMPLIES (MODEL-INFO-P M)
#          (AND (MODEL-INFO-P M)
#               (LET ((TP (MODEL-INFO->TYPE M)))
#                 (AND (MODEL-TYPE-P TP)
#                      (LET ((TP.KIND (MODEL-TYPE-KIND TP)))
#                        T))))).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for MODEL-IS-COMPLETIONS-P.
# MODEL-IS-COMPLETIONS-P is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MODEL-IS-COMPLETIONS-P ...)
# Rules: ((:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART EQLABLEP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE MODEL-TYPE-P-OF-MODEL-INFO->TYPE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  28
#
#
# ACL2 !>>(DEFTHM BOOLEANP-OF-MODEL-IS-COMPLETIONS-P
#           (B* ((IS-COMPLETIONS (MODEL-IS-COMPLETIONS-P M)))
#             (BOOLEANP IS-COMPLETIONS))
#           :HINTS
#           ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'MODEL-IS-COMPLETIONS-P
#                                                  ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM BOOLEANP-OF-MODEL-IS-COMPLETIONS-P
# ...):  A :REWRITE rule generated from BOOLEANP-OF-MODEL-IS-COMPLETIONS-P
# will be triggered only by terms containing the function symbol
# MODEL-IS-COMPLETIONS-P, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-MODEL-IS-COMPLETIONS-P depends upon the
# :compound-recognizer rule BOOLEANP-COMPOUND-RECOGNIZER and the :type-
# prescription rule MODEL-IS-COMPLETIONS-P.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-MODEL-IS-COMPLETIONS-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION MODEL-IS-COMPLETIONS-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# BOOLEANP-OF-MODEL-IS-COMPLETIONS-P
#
# Summary
# Form:  ( PROGN (DEFTHM BOOLEANP-OF-MODEL-IS-COMPLETIONS-P ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MODEL-IS-COMPLETIONS-P

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; Model Info List
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(fty::deflist model-info-list
  :elt-type model-info-p
  :true-listp t)
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-INFO-LIST-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Deflist: attempting to show, using your current theory, that (MODEL-INFO-P X)
# is always Boolean valued.
#
# Deflist: introducing MODEL-INFO-LIST-P and proving deflist theorems.
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MODEL-INFO-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MODEL-INFO-LIST-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM MODEL-INFO-LIST-P-OF-MODEL-INFO-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MODEL-INFO-LIST-P-OF-MODEL-INFO-LIST-FIX ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM MODEL-INFO-LIST-FIX-WHEN-MODEL-INFO-LIST-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS MODEL-INFO-LIST-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Form:  ( DEFTHM CAR-OF-MODEL-INFO-LIST-FIX-X-UNDER-MODEL-INFO-EQUIV
# ...)
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
# Form:  ( DEFTHM CDR-OF-MODEL-INFO-LIST-FIX-X-UNDER-MODEL-INFO-LIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-MODEL-INFO-FIX-X-UNDER-MODEL-INFO-LIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-MODEL-INFO-LIST-FIX-Y-UNDER-MODEL-INFO-LIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM CONSP-OF-MODEL-INFO-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MODEL-INFO-LIST-FIX-UNDER-IFF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MODEL-INFO-LIST-FIX-OF-CONS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM LEN-OF-MODEL-INFO-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM MODEL-INFO-LIST-FIX-OF-APPEND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM MODEL-INFO-LIST-FIX-OF-REPEAT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/4
# Subgoal *1/4'
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM LIST-EQUIV-REFINES-MODEL-INFO-LIST-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/3
# Subgoal *1/3.9
# Subgoal *1/3.9'
# Subgoal *1/3.9''
# Subgoal *1/3.9'''
# Subgoal *1/3.8
# Subgoal *1/3.7
# Subgoal *1/3.6
# Subgoal *1/3.5
# Subgoal *1/3.4
# Subgoal *1/3.3
# Subgoal *1/3.3'
# Subgoal *1/3.3''
# Subgoal *1/3.3'''
# Subgoal *1/3.2
# Subgoal *1/3.2'
# Subgoal *1/3.2''
# Subgoal *1/3.2'''
# Subgoal *1/3.1
# Subgoal *1/3.1'
# Subgoal *1/3.1''
# Subgoal *1/3.1'''
# Subgoal *1/2
# Subgoal *1/2.3
# Subgoal *1/2.3'
# Subgoal *1/2.2
# Subgoal *1/2.2'
# Subgoal *1/2.2''
# Subgoal *1/2.2'''
# Subgoal *1/2.1
# Subgoal *1/2.1'
# Subgoal *1/1
# Form:  ( DEFTHM NTH-OF-MODEL-INFO-LIST-FIX ...)
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM MODEL-INFO-LIST-EQUIV-IMPLIES-MODEL-INFO-LIST-EQUIV-APPEND-1
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM MODEL-INFO-LIST-EQUIV-IMPLIES-MODEL-INFO-LIST-EQUIV-APPEND-2
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM MODEL-INFO-LIST-EQUIV-IMPLIES-MODEL-INFO-LIST-EQUIV-NTHCDR-2
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (DEFCONG-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM MODEL-INFO-LIST-EQUIV-IMPLIES-MODEL-INFO-LIST-EQUIV-TAKE-2
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (DEFCONG-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.06 seconds (prove: 0.05, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MODEL-INFO-LIST ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MODEL-INFO-LIST ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.11 seconds (prove: 0.05, print: 0.00, other: 0.06)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.12 seconds (prove: 0.05, print: 0.00, other: 0.07)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFLIST-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.12 seconds (prove: 0.05, print: 0.00, other: 0.07)
# Prover steps counted:  9025
#  T

# %%
;; Filter helpers - use simpler approach without return type proofs
;; (ACL2 has trouble with recursive filter return types on FTY lists)
(defun filter-loaded-models (models)
  (declare (xargs :guard (model-info-list-p models)))
  (cond ((endp models) nil)
        ((model-loaded-p (model-info-fix (car models)))
         (cons (model-info-fix (car models)) 
               (filter-loaded-models (cdr models))))
        (t (filter-loaded-models (cdr models)))))
# Out:
# The admission of FILTER-LOADED-MODELS is trivial, using the relation
# O< (which is known to be well-founded on the domain recognized by O-P)
# and the measure (ACL2-COUNT MODELS).  We observe that the type of
# FILTER-LOADED-MODELS is described by the theorem
# (TRUE-LISTP (FILTER-LOADED-MODELS MODELS)).  We used primitive type
# reasoning.
#
# Computing the guard conjecture for FILTER-LOADED-MODELS....
#
# The non-trivial part of the guard conjecture for FILTER-LOADED-MODELS,
# given the :compound-recognizer rule
# TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER and primitive
# type reasoning, is
#
# Goal
# (AND (IMPLIES (AND (MODEL-INFO-LIST-P MODELS)
#                    (NOT (ENDP MODELS)))
#               (MODEL-INFO-P (CAR MODELS)))
#      (IMPLIES (AND (MODEL-INFO-LIST-P MODELS)
#                    (NOT (ENDP MODELS)))
#               (MODEL-INFO-P (MODEL-INFO-FIX (CAR MODELS))))
#      (IMPLIES (AND (MODEL-INFO-LIST-P MODELS)
#                    (NOT (ENDP MODELS)))
#               (MODEL-INFO-LIST-P (CDR MODELS)))).
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the guard theorem for FILTER-LOADED-MODELS.
# FILTER-LOADED-MODELS is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN FILTER-LOADED-MODELS ...)
# Rules: ((:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER)
#         (:DEFINITION DOUBLE-REWRITE)
#         (:DEFINITION ENDP)
#         (:DEFINITION NOT)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE MODEL-INFO-LIST-P-OF-CDR-WHEN-MODEL-INFO-LIST-P)
#         (:REWRITE MODEL-INFO-P-OF-CAR-WHEN-MODEL-INFO-LIST-P)
#         (:REWRITE MODEL-INFO-P-OF-MODEL-INFO-FIX))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  132
#  FILTER-LOADED-MODELS

# %%
(defun filter-completions-models (models)
  (declare (xargs :guard (model-info-list-p models)))
  (cond ((endp models) nil)
        ((model-is-completions-p (model-info-fix (car models)))
         (cons (model-info-fix (car models)) 
               (filter-completions-models (cdr models))))
        (t (filter-completions-models (cdr models)))))
# Out:
# The admission of FILTER-COMPLETIONS-MODELS is trivial, using the relation
# O< (which is known to be well-founded on the domain recognized by O-P)
# and the measure (ACL2-COUNT MODELS).  We observe that the type of
# FILTER-COMPLETIONS-MODELS is described by the theorem
# (TRUE-LISTP (FILTER-COMPLETIONS-MODELS MODELS)).  We used primitive
# type reasoning.
#
# Computing the guard conjecture for FILTER-COMPLETIONS-MODELS....
#
# The non-trivial part of the guard conjecture for FILTER-COMPLETIONS-MODELS,
# given the :compound-recognizer rule
# TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER and primitive
# type reasoning, is
#
# Goal
# (AND (IMPLIES (AND (MODEL-INFO-LIST-P MODELS)
#                    (NOT (ENDP MODELS)))
#               (MODEL-INFO-P (CAR MODELS)))
#      (IMPLIES (AND (MODEL-INFO-LIST-P MODELS)
#                    (NOT (ENDP MODELS)))
#               (MODEL-INFO-P (MODEL-INFO-FIX (CAR MODELS))))
#      (IMPLIES (AND (MODEL-INFO-LIST-P MODELS)
#                    (NOT (ENDP MODELS)))
#               (MODEL-INFO-LIST-P (CDR MODELS)))).
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the guard theorem for FILTER-COMPLETIONS-MODELS.
# FILTER-COMPLETIONS-MODELS is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN FILTER-COMPLETIONS-MODELS ...)
# Rules: ((:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER)
#         (:DEFINITION DOUBLE-REWRITE)
#         (:DEFINITION ENDP)
#         (:DEFINITION NOT)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE MODEL-INFO-LIST-P-OF-CDR-WHEN-MODEL-INFO-LIST-P)
#         (:REWRITE MODEL-INFO-P-OF-CAR-WHEN-MODEL-INFO-LIST-P)
#         (:REWRITE MODEL-INFO-P-OF-MODEL-INFO-FIX))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  132
#  FILTER-COMPLETIONS-MODELS

# %%
(defun filter-loaded-completions-models (models)
  (declare (xargs :guard (model-info-list-p models)))
  (filter-loaded-models (filter-completions-models models)))
# Out:
# Since FILTER-LOADED-COMPLETIONS-MODELS is non-recursive, its admission
# is trivial.  We observe that the type of FILTER-LOADED-COMPLETIONS-MODELS
# is described by the theorem
# (TRUE-LISTP (FILTER-LOADED-COMPLETIONS-MODELS MODELS)).  We used the
# :type-prescription rule FILTER-LOADED-MODELS.
#
# Computing the guard conjecture for FILTER-LOADED-COMPLETIONS-MODELS....
#
# The non-trivial part of the guard conjecture for
# FILTER-LOADED-COMPLETIONS-MODELS is
#
# Goal
# (IMPLIES (MODEL-INFO-LIST-P MODELS)
#          (MODEL-INFO-LIST-P (FILTER-COMPLETIONS-MODELS MODELS))).
# Goal'
#
# ([ A key checkpoint:
#
# Goal'
# (IMPLIES (MODEL-INFO-LIST-P MODELS)
#          (MODEL-INFO-LIST-P (FILTER-COMPLETIONS-MODELS MODELS)))
#
# *1 (Goal') is pushed for proof by induction.
#
# ])
#
# Perhaps we can prove *1 by induction.  One induction scheme is suggested
# by this conjecture.
#
# We will induct according to a scheme suggested by
# (FILTER-COMPLETIONS-MODELS MODELS).
#
# This suggestion was produced using the :induction rule
# FILTER-COMPLETIONS-MODELS.  If we let (:P MODELS) denote *1 above then
# the induction scheme we'll use is
# (AND
#    (IMPLIES (AND (NOT (ENDP MODELS))
#                  (NOT (MODEL-IS-COMPLETIONS-P (MODEL-INFO-FIX (CAR MODELS))))
#                  (:P (CDR MODELS)))
#             (:P MODELS))
#    (IMPLIES (AND (NOT (ENDP MODELS))
#                  (MODEL-IS-COMPLETIONS-P (MODEL-INFO-FIX (CAR MODELS)))
#                  (:P (CDR MODELS)))
#             (:P MODELS))
#    (IMPLIES (ENDP MODELS) (:P MODELS))).
# This induction is justified by the same argument used to admit
# FILTER-COMPLETIONS-MODELS.  When applied to the goal at hand the above
# induction scheme produces five nontautological subgoals.
# Subgoal *1/5
# Subgoal *1/5'
# Subgoal *1/4
# Subgoal *1/4'
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
#
# *1 is COMPLETED!
# Thus key checkpoint Goal' is COMPLETED!
#
# Q.E.D.
#
# That completes the proof of the guard theorem for
# FILTER-LOADED-COMPLETIONS-MODELS.  FILTER-LOADED-COMPLETIONS-MODELS
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN FILTER-LOADED-COMPLETIONS-MODELS ...)
# Rules: ((:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-MODEL-INFO-LIST-P-COMPOUND-RECOGNIZER)
#         (:DEFINITION DOUBLE-REWRITE)
#         (:DEFINITION ENDP)
#         (:DEFINITION FILTER-COMPLETIONS-MODELS)
#         (:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART FILTER-COMPLETIONS-MODELS)
#         (:EXECUTABLE-COUNTERPART MODEL-INFO-LIST-P)
#         (:INDUCTION FILTER-COMPLETIONS-MODELS)
#         (:REWRITE MODEL-INFO-FIX-WHEN-MODEL-INFO-P)
#         (:REWRITE MODEL-INFO-LIST-P-OF-CDR-WHEN-MODEL-INFO-LIST-P)
#         (:REWRITE MODEL-INFO-LIST-P-OF-CONS)
#         (:REWRITE MODEL-INFO-LIST-P-WHEN-NOT-CONSP)
#         (:REWRITE MODEL-INFO-P-OF-CAR-WHEN-MODEL-INFO-LIST-P)
#         (:TYPE-PRESCRIPTION FILTER-LOADED-MODELS)
#         (:TYPE-PRESCRIPTION MODEL-IS-COMPLETIONS-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  648
#  FILTER-LOADED-COMPLETIONS-MODELS

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; LLM Provider
# ;;
# ;; Specifies which LLM provider to use: local (LM Studio) or cloud (OpenAI, etc.)
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(fty::deftagsum llm-provider
  (:local ())       ; Local LM Studio instance
  (:openai ())      ; OpenAI API (gpt-4, gpt-3.5-turbo, etc.)
  (:anthropic ())   ; Anthropic API (claude-3, etc.) - future
  (:azure ())       ; Azure OpenAI - future
  (:custom ()))     ; Custom OpenAI-compatible endpoint
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN LLM-PROVIDER-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM CONSP-WHEN-LLM-PROVIDER-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-KIND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN LLM-PROVIDER-KIND$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM LLM-PROVIDER-KIND-POSSIBILITIES ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE RULESET-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-KIND-POSSIBILITIES ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-CASE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-KIND-EQ ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN LLM-PROVIDER-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 6
# Subgoal 5
# Subgoal 5'
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM LLM-PROVIDER-P-OF-LLM-PROVIDER-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-P-OF-LLM-PROVIDER-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM LLM-PROVIDER-FIX-WHEN-LLM-PROVIDER-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS LLM-PROVIDER-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 6
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM LLM-PROVIDER-KIND$INLINE-OF-LLM-PROVIDER-FIX-X ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM CONSP-OF-LLM-PROVIDER-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TAG-WHEN-LLM-PROVIDER-P-FORWARD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM TAG-OF-LLM-PROVIDER-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE RULESET-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN LLM-PROVIDER-LOCAL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-LOCAL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-FIX-WHEN-LOCAL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-LLM-PROVIDER-LOCAL ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFMACRO PATBIND-LLM-PROVIDER-LOCAL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-LLM-PROVIDER-LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-LLM-PROVIDER-LOCAL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-LLM-PROVIDER-LOCAL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-FIX-WHEN-LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN LLM-PROVIDER-OPENAI ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-OPENAI ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-OPENAI ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-FIX-WHEN-OPENAI ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-LLM-PROVIDER-OPENAI ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFMACRO PATBIND-LLM-PROVIDER-OPENAI ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-LLM-PROVIDER-OPENAI ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-LLM-PROVIDER-OPENAI ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-LLM-PROVIDER-OPENAI ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-FIX-WHEN-OPENAI ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN LLM-PROVIDER-ANTHROPIC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-ANTHROPIC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-ANTHROPIC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-FIX-WHEN-ANTHROPIC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-LLM-PROVIDER-ANTHROPIC ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFMACRO PATBIND-LLM-PROVIDER-ANTHROPIC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-LLM-PROVIDER-ANTHROPIC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-LLM-PROVIDER-ANTHROPIC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-LLM-PROVIDER-ANTHROPIC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-FIX-WHEN-ANTHROPIC ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN LLM-PROVIDER-AZURE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-AZURE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-AZURE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-FIX-WHEN-AZURE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-LLM-PROVIDER-AZURE ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFMACRO PATBIND-LLM-PROVIDER-AZURE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-LLM-PROVIDER-AZURE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-LLM-PROVIDER-AZURE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-LLM-PROVIDER-AZURE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-FIX-WHEN-AZURE ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN LLM-PROVIDER-CUSTOM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-CUSTOM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-LLM-PROVIDER-CUSTOM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-FIX-WHEN-CUSTOM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-LLM-PROVIDER-CUSTOM ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFMACRO PATBIND-LLM-PROVIDER-CUSTOM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-LLM-PROVIDER-CUSTOM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-LLM-PROVIDER-CUSTOM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-LLM-PROVIDER-CUSTOM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-FIX-WHEN-CUSTOM ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 6
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM LLM-PROVIDER-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC LLM-PROVIDER ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC LLM-PROVIDER ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.12 seconds (prove: 0.01, print: 0.00, other: 0.11)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.13 seconds (prove: 0.01, print: 0.00, other: 0.11)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFTAGSUM-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.13 seconds (prove: 0.01, print: 0.00, other: 0.11)
# Prover steps counted:  4001
#  T

# %%
(define llm-provider-to-string ((p llm-provider-p))
  :returns (s stringp)
  (llm-provider-case p
    :local "local"
    :openai "openai"
    :anthropic "anthropic"
    :azure "azure"
    :custom "custom"))
# Out:
# Since LLM-PROVIDER-TO-STRING is non-recursive, its admission is trivial.
# We observe that the type of LLM-PROVIDER-TO-STRING is described by
# the theorem (STRINGP (LLM-PROVIDER-TO-STRING P)).
#
# Computing the guard conjecture for LLM-PROVIDER-TO-STRING....
#
# The guard conjecture for LLM-PROVIDER-TO-STRING is trivial to prove,
# given the :compound-recognizer rule CONSP-WHEN-LLM-PROVIDER-P and the
# :executable-counterpart of EQLABLEP.  LLM-PROVIDER-TO-STRING is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-PROVIDER-TO-STRING ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-LLM-PROVIDER-P)
#         (:EXECUTABLE-COUNTERPART EQLABLEP))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#
#
# ACL2 !>>(DEFTHM STRINGP-OF-LLM-PROVIDER-TO-STRING
#           (B* ((S (LLM-PROVIDER-TO-STRING P)))
#             (STRINGP S))
#           :HINTS
#           ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'LLM-PROVIDER-TO-STRING
#                                                  ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM STRINGP-OF-LLM-PROVIDER-TO-STRING
# ...):  A :REWRITE rule generated from STRINGP-OF-LLM-PROVIDER-TO-STRING
# will be triggered only by terms containing the function symbol
# LLM-PROVIDER-TO-STRING, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of STRINGP-OF-LLM-PROVIDER-TO-STRING depends upon the :type-
# prescription rule LLM-PROVIDER-TO-STRING.
#
# Summary
# Form:  ( DEFTHM STRINGP-OF-LLM-PROVIDER-TO-STRING ...)
# Rules: ((:TYPE-PRESCRIPTION LLM-PROVIDER-TO-STRING))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# STRINGP-OF-LLM-PROVIDER-TO-STRING
#
# Summary
# Form:  ( PROGN (DEFTHM STRINGP-OF-LLM-PROVIDER-TO-STRING ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  LLM-PROVIDER-TO-STRING

# %%
(define string-to-llm-provider ((s stringp))
  :returns (p llm-provider-p)
  (cond ((equal s "local") (llm-provider-local))
        ((equal s "openai") (llm-provider-openai))
        ((equal s "anthropic") (llm-provider-anthropic))
        ((equal s "azure") (llm-provider-azure))
        ((equal s "custom") (llm-provider-custom))
        ;; Default to local for unknown
        (t (llm-provider-local))))
# Out:
# Since STRING-TO-LLM-PROVIDER is non-recursive, its admission is trivial.
# We observe that the type of STRING-TO-LLM-PROVIDER is described by
# the theorem
# (AND (CONSP (STRING-TO-LLM-PROVIDER S))
#      (TRUE-LISTP (STRING-TO-LLM-PROVIDER S))).
# We used the :type-prescription rules LLM-PROVIDER-ANTHROPIC,
# LLM-PROVIDER-AZURE, LLM-PROVIDER-CUSTOM, LLM-PROVIDER-LOCAL and
# LLM-PROVIDER-OPENAI.
#
# Computing the guard conjecture for STRING-TO-LLM-PROVIDER....
#
# The guard conjecture for STRING-TO-LLM-PROVIDER is trivial to prove.
# STRING-TO-LLM-PROVIDER is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN STRING-TO-LLM-PROVIDER ...)
# Rules: ((:TYPE-PRESCRIPTION LLM-PROVIDER-ANTHROPIC)
#         (:TYPE-PRESCRIPTION LLM-PROVIDER-AZURE)
#         (:TYPE-PRESCRIPTION LLM-PROVIDER-CUSTOM)
#         (:TYPE-PRESCRIPTION LLM-PROVIDER-LOCAL)
#         (:TYPE-PRESCRIPTION LLM-PROVIDER-OPENAI))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM LLM-PROVIDER-P-OF-STRING-TO-LLM-PROVIDER
#           (B* ((P (STRING-TO-LLM-PROVIDER S)))
#             (LLM-PROVIDER-P P))
#           :HINTS
#           ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'STRING-TO-LLM-PROVIDER
#                                                  ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM LLM-PROVIDER-P-OF-STRING-TO-LLM-PROVIDER
# ...):  A :REWRITE rule generated from
# LLM-PROVIDER-P-OF-STRING-TO-LLM-PROVIDER will be triggered only by
# terms containing the function symbol STRING-TO-LLM-PROVIDER, which
# has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
# Goal'
# Subgoal 6
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of LLM-PROVIDER-P-OF-STRING-TO-LLM-PROVIDER depends upon
# the :compound-recognizer rule CONSP-WHEN-LLM-PROVIDER-P and the :type-
# prescription rule LLM-PROVIDER-P.
#
# Summary
# Form:  ( DEFTHM LLM-PROVIDER-P-OF-STRING-TO-LLM-PROVIDER ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-LLM-PROVIDER-P)
#         (:DEFINITION STRING-TO-LLM-PROVIDER)
#         (:EXECUTABLE-COUNTERPART LLM-PROVIDER-ANTHROPIC)
#         (:EXECUTABLE-COUNTERPART LLM-PROVIDER-AZURE)
#         (:EXECUTABLE-COUNTERPART LLM-PROVIDER-CUSTOM)
#         (:EXECUTABLE-COUNTERPART LLM-PROVIDER-LOCAL)
#         (:EXECUTABLE-COUNTERPART LLM-PROVIDER-OPENAI)
#         (:EXECUTABLE-COUNTERPART LLM-PROVIDER-P)
#         (:TYPE-PRESCRIPTION LLM-PROVIDER-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  156
# LLM-PROVIDER-P-OF-STRING-TO-LLM-PROVIDER
#
# Summary
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-P-OF-STRING-TO-LLM-PROVIDER ...)
# ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  156
#  STRING-TO-LLM-PROVIDER

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;; LLM Provider Config
# ;;
# ;; Configuration for an LLM provider including endpoint, API key, etc.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(fty::defprod llm-provider-config
  ((provider llm-provider-p "Provider type")
   (endpoint stringp "API endpoint URL" :default "")
   (api-key stringp "API key (empty for local)" :default "")
   (model stringp "Default model to use" :default "")
   (org-id stringp "Organization ID (optional)" :default ""))
  :layout :list)
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TMP-DEFTYPES-STRINGP-OF-STR-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFUN LLM-PROVIDER-CONFIG-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONSP-WHEN-LLM-PROVIDER-CONFIG-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-CONFIG-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN LLM-PROVIDER-CONFIG-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-P-OF-LLM-PROVIDER-CONFIG-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-CONFIG-P-OF-LLM-PROVIDER-CONFIG-FIX
# ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-FIX-WHEN-LLM-PROVIDER-CONFIG-P
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS LLM-PROVIDER-CONFIG-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-CONFIG->PROVIDER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN LLM-PROVIDER-CONFIG->PROVIDER$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM LLM-PROVIDER-P-OF-LLM-PROVIDER-CONFIG->PROVIDER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-P-OF-LLM-PROVIDER-CONFIG->PROVIDER
# ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM
# LLM-PROVIDER-CONFIG->PROVIDER$INLINE-OF-LLM-PROVIDER-CONFIG-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV LLM-PROVIDER-CONFIG->PROVIDER ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-CONFIG->ENDPOINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN LLM-PROVIDER-CONFIG->ENDPOINT$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-LLM-PROVIDER-CONFIG->ENDPOINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-LLM-PROVIDER-CONFIG->ENDPOINT ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM
# LLM-PROVIDER-CONFIG->ENDPOINT$INLINE-OF-LLM-PROVIDER-CONFIG-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV LLM-PROVIDER-CONFIG->ENDPOINT ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-CONFIG->API-KEY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN LLM-PROVIDER-CONFIG->API-KEY$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-LLM-PROVIDER-CONFIG->API-KEY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-LLM-PROVIDER-CONFIG->API-KEY ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM
# LLM-PROVIDER-CONFIG->API-KEY$INLINE-OF-LLM-PROVIDER-CONFIG-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV LLM-PROVIDER-CONFIG->API-KEY ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-CONFIG->MODEL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN LLM-PROVIDER-CONFIG->MODEL$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-LLM-PROVIDER-CONFIG->MODEL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-LLM-PROVIDER-CONFIG->MODEL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM
# LLM-PROVIDER-CONFIG->MODEL$INLINE-OF-LLM-PROVIDER-CONFIG-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV LLM-PROVIDER-CONFIG->MODEL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO LLM-PROVIDER-CONFIG->ORG-ID ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN LLM-PROVIDER-CONFIG->ORG-ID$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-LLM-PROVIDER-CONFIG->ORG-ID ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-LLM-PROVIDER-CONFIG->ORG-ID ...)
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM
# LLM-PROVIDER-CONFIG->ORG-ID$INLINE-OF-LLM-PROVIDER-CONFIG-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV LLM-PROVIDER-CONFIG->ORG-ID ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN LLM-PROVIDER-CONFIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-P-OF-LLM-PROVIDER-CONFIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-CONFIG-P-OF-LLM-PROVIDER-CONFIG
# ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG->PROVIDER-OF-LLM-PROVIDER-CONFIG
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG->ENDPOINT-OF-LLM-PROVIDER-CONFIG
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG->API-KEY-OF-LLM-PROVIDER-CONFIG
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG->MODEL-OF-LLM-PROVIDER-CONFIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG->ORG-ID-OF-LLM-PROVIDER-CONFIG
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-OF-FIELDS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-FIX-WHEN-LLM-PROVIDER-CONFIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 7
# Subgoal 7'
# Subgoal 7''
# Subgoal 6
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM EQUAL-OF-LLM-PROVIDER-CONFIG ...)
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-OF-LLM-PROVIDER-FIX-PROVIDER ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-OF-STR-FIX-ENDPOINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-OF-STR-FIX-API-KEY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-OF-STR-FIX-MODEL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-OF-STR-FIX-ORG-ID ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFMACRO PATBIND-LLM-PROVIDER-CONFIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-LLM-PROVIDER-CONFIG ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-LLM-PROVIDER-CONFIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-LLM-PROVIDER-CONFIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM LLM-PROVIDER-CONFIG->PROVIDER-OF-LLM-PROVIDER-CONFIG
# ...) ...)
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM LLM-PROVIDER-CONFIG-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC LLM-PROVIDER-CONFIG ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC LLM-PROVIDER-CONFIG ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.10 seconds (prove: 0.02, print: 0.00, other: 0.08)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.11 seconds (prove: 0.02, print: 0.00, other: 0.09)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFPROD-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.11 seconds (prove: 0.02, print: 0.00, other: 0.09)
# Prover steps counted:  8819
#  T

# %%
;; Predefined provider configurations
(defmacro make-local-config (&key (model '""))
  `(make-llm-provider-config
    :provider (llm-provider-local)
    :endpoint "http://host.docker.internal:1234/v1/chat/completions"
    :api-key ""
    :model ,model
    :org-id ""))
# Out:
# Summary
# Form:  ( DEFMACRO MAKE-LOCAL-CONFIG ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MAKE-LOCAL-CONFIG

# %%
(defmacro make-openai-config (&key api-key (model '"gpt-4o-mini") (org-id '""))
  `(make-llm-provider-config
    :provider (llm-provider-openai)
    :endpoint "https://api.openai.com/v1/chat/completions"
    :api-key ,api-key
    :model ,model
    :org-id ,org-id))
# Out:
# Summary
# Form:  ( DEFMACRO MAKE-OPENAI-CONFIG ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MAKE-OPENAI-CONFIG

# %%
(defmacro make-custom-config (&key endpoint api-key model)
  `(make-llm-provider-config
    :provider (llm-provider-custom)
    :endpoint ,endpoint
    :api-key ,api-key
    :model ,model
    :org-id ""))
# Out:
# Summary
# Form:  ( DEFMACRO MAKE-CUSTOM-CONFIG ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MAKE-CUSTOM-CONFIG

# %%
;; Helper to check if provider requires API key
(define provider-requires-api-key-p ((config llm-provider-config-p))
  :returns (requires booleanp)
  (let ((prov (llm-provider-config->provider config)))
    (llm-provider-case prov
      :local nil
      :openai t
      :anthropic t
      :azure t
      :custom t)))
# Out:
# Since PROVIDER-REQUIRES-API-KEY-P is non-recursive, its admission is
# trivial.  We observe that the type of PROVIDER-REQUIRES-API-KEY-P is
# described by the theorem
# (OR (EQUAL (PROVIDER-REQUIRES-API-KEY-P CONFIG)
#            T)
#     (EQUAL (PROVIDER-REQUIRES-API-KEY-P CONFIG)
#            NIL)).
#
# Computing the guard conjecture for PROVIDER-REQUIRES-API-KEY-P....
#
# The non-trivial part of the guard conjecture for PROVIDER-REQUIRES-API-KEY-P,
# given the :executable-counterpart of EQLABLEP, is
#
# Goal
# (IMPLIES (LLM-PROVIDER-CONFIG-P CONFIG)
#          (AND (LLM-PROVIDER-CONFIG-P CONFIG)
#               (LET ((PROV (LLM-PROVIDER-CONFIG->PROVIDER CONFIG)))
#                 (AND (LLM-PROVIDER-P PROV)
#                      (LET ((PROV.KIND (LLM-PROVIDER-KIND PROV)))
#                        T))))).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for
# PROVIDER-REQUIRES-API-KEY-P.  PROVIDER-REQUIRES-API-KEY-P is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN PROVIDER-REQUIRES-API-KEY-P ...)
# Rules: ((:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART EQLABLEP)
#         (:REWRITE LLM-PROVIDER-P-OF-LLM-PROVIDER-CONFIG->PROVIDER))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  28
#
#
# ACL2 !>>(DEFTHM BOOLEANP-OF-PROVIDER-REQUIRES-API-KEY-P
#           (B* ((REQUIRES (PROVIDER-REQUIRES-API-KEY-P CONFIG)))
#             (BOOLEANP REQUIRES))
#           :HINTS
#           ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'PROVIDER-REQUIRES-API-KEY-P
#                                                  ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM BOOLEANP-OF-PROVIDER-REQUIRES-API-KEY-P
# ...):  A :REWRITE rule generated from BOOLEANP-OF-PROVIDER-REQUIRES-API-KEY-P
# will be triggered only by terms containing the function symbol
# PROVIDER-REQUIRES-API-KEY-P, which has a non-recursive definition.
# Unless this definition is disabled, this rule is unlikely ever to be
# used.
#
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-PROVIDER-REQUIRES-API-KEY-P depends upon
# the :compound-recognizer rule BOOLEANP-COMPOUND-RECOGNIZER and the
# :type-prescription rule PROVIDER-REQUIRES-API-KEY-P.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-PROVIDER-REQUIRES-API-KEY-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION PROVIDER-REQUIRES-API-KEY-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# BOOLEANP-OF-PROVIDER-REQUIRES-API-KEY-P
#
# Summary
# Form:  ( PROGN (DEFTHM BOOLEANP-OF-PROVIDER-REQUIRES-API-KEY-P ...)
# ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  PROVIDER-REQUIRES-API-KEY-P

# %%
;; Helper to check if config is valid (has API key if needed)
(define llm-config-valid-p ((config llm-provider-config-p))
  :returns (valid booleanp)
  (and (not (equal "" (llm-provider-config->endpoint config)))
       (or (not (provider-requires-api-key-p config))
           (not (equal "" (llm-provider-config->api-key config))))))
# Out:
# Since LLM-CONFIG-VALID-P is non-recursive, its admission is trivial.
# We observe that the type of LLM-CONFIG-VALID-P is described by the
# theorem
# (OR (EQUAL (LLM-CONFIG-VALID-P CONFIG) T)
#     (EQUAL (LLM-CONFIG-VALID-P CONFIG)
#            NIL)).
#
# Computing the guard conjecture for LLM-CONFIG-VALID-P....
#
# The guard conjecture for LLM-CONFIG-VALID-P is trivial to prove, given
# the :compound-recognizer rule CONSP-WHEN-LLM-PROVIDER-CONFIG-P.
# LLM-CONFIG-VALID-P is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-CONFIG-VALID-P ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-LLM-PROVIDER-CONFIG-P))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#
#
# ACL2 !>>(DEFTHM BOOLEANP-OF-LLM-CONFIG-VALID-P
#           (B* ((VALID (LLM-CONFIG-VALID-P CONFIG)))
#             (BOOLEANP VALID))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'LLM-CONFIG-VALID-P
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM BOOLEANP-OF-LLM-CONFIG-VALID-P ...):
# A :REWRITE rule generated from BOOLEANP-OF-LLM-CONFIG-VALID-P will
# be triggered only by terms containing the function symbol LLM-CONFIG-VALID-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-LLM-CONFIG-VALID-P depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER and the :type-prescription
# rule LLM-CONFIG-VALID-P.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-LLM-CONFIG-VALID-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION LLM-CONFIG-VALID-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# BOOLEANP-OF-LLM-CONFIG-VALID-P
#
# Summary
# Form:  ( PROGN (DEFTHM BOOLEANP-OF-LLM-CONFIG-VALID-P ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  LLM-CONFIG-VALID-P
