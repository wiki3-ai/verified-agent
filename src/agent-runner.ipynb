# %% [raw]
# ; agent-runner.lisp - Runtime driver for verified agent with MCP code execution
# ;
# ; Copyright (C) 2025
# ;
# ; License: See LICENSE file
# ;
# ; This book provides the runtime integration between:
# ; - verified-agent.lisp (decision logic, state management)
# ; - llm-client.lisp (LLM chat completions)
# ; - mcp-client.lisp (code execution via acl2-mcp)
# ; - parinfer-fixer.lisp (fix unbalanced parens in LLM output)
# ;
# ; The verified agent decides what to do; this runner executes it.

# %%
(in-package "ACL2")
# Out:
#  "ACL2"

# %% [raw]
# ;;;============================================================================
# ;;; Imports
# ;;;============================================================================

# %%
(include-book "verified-agent")
(include-book "llm-client"
              :ttags ((:quicklisp) (:quicklisp.osicat) (:quicklisp.dexador) 
                      (:http-json) (:llm-client)))
(include-book "mcp-client"
              :ttags ((:quicklisp) (:quicklisp.dexador) (:http-json) (:mcp-client)))
# Out:
# Note (from clause-processors/equality): disabling DISJOIN, DISJOIN2,
# CONJOIN and CONJOIN2.
#
#
# Summary
# Form:  ( INCLUDE-BOOK "verified-agent" ...)
# Rules: NIL
# Time:  0.85 seconds (prove: 0.00, print: 0.00, other: 0.85)
#  "/workspaces/verified-agent/src/verified-agent.lisp"
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP from book /home/acl2/books/quicklisp/base.
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP.DEXADOR from book /home/acl2/books/quicklisp/dexador.
#
# TTAG NOTE (for included book): Adding ttag :HTTP-JSON from book /workspaces/verified-agent/src/http-json.
#
# TTAG NOTE (for included book): Adding ttag :LLM-CLIENT from book /workspaces/verified-agent/src/llm-client.
#
# Summary
# Form:  ( INCLUDE-BOOK "llm-client" ...)
# Rules: NIL
# Time:  0.27 seconds (prove: 0.00, print: 0.00, other: 0.27)
#  "/workspaces/verified-agent/src/llm-client.lisp"
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP from book /home/acl2/books/quicklisp/base.
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP.DEXADOR from book /home/acl2/books/quicklisp/dexador.
#
# TTAG NOTE (for included book): Adding ttag :HTTP-JSON from book /workspaces/verified-agent/src/http-json.
#
# TTAG NOTE (for included book): Adding ttag :MCP-CLIENT from book /workspaces/verified-agent/src/mcp-client.
#
# Summary
# Form:  ( INCLUDE-BOOK "mcp-client" ...)
# Rules: NIL
# Time:  0.03 seconds (prove: 0.00, print: 0.00, other: 0.03)
#  "/workspaces/verified-agent/src/mcp-client.lisp"

# %% [raw]
# ;; Parinfer fixer is loaded separately since it uses sys-call+
# ;; which requires trust tags. We'll include it conditionally.
# ;; For now, define the interface here and it can be loaded at runtime.

# %% [raw]
# ;;;============================================================================
# ;;; Tool Specifications for Code Execution
# ;;;============================================================================

# %%
;; ACL2 evaluate tool - runs arbitrary ACL2 expressions
(defconst *tool-acl2-evaluate*
  (make-tool-spec
    :name 'acl2-evaluate
    :required-access 0           ; No file access needed
    :requires-execute t          ; Requires execute permission
    :token-cost 100              ; Estimated tokens for result
    :time-cost 5))               ; Estimated seconds
# Out:
# Summary
# Form:  ( DEFCONST *TOOL-ACL2-EVALUATE* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *TOOL-ACL2-EVALUATE*

# %%
;; ACL2 admit tool - test function definitions
(defconst *tool-acl2-admit*
  (make-tool-spec
    :name 'acl2-admit
    :required-access 0
    :requires-execute t
    :token-cost 200
    :time-cost 10))
# Out:
# Summary
# Form:  ( DEFCONST *TOOL-ACL2-ADMIT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *TOOL-ACL2-ADMIT*

# %%
;; ACL2 prove tool - attempt theorem proofs
(defconst *tool-acl2-prove*
  (make-tool-spec
    :name 'acl2-prove
    :required-access 0
    :requires-execute t
    :token-cost 500
    :time-cost 30))
# Out:
# Summary
# Form:  ( DEFCONST *TOOL-ACL2-PROVE* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *TOOL-ACL2-PROVE*

# %% [raw]
# ;;;============================================================================
# ;;; System Prompt for Code Execution Agent
# ;;;============================================================================

# %%
(defconst *code-agent-system-prompt*
  "You are a helpful AI assistant with access to ACL2 code execution.

You can execute ACL2 code by putting it in a fenced code block with language 'acl2' or 'lisp'.

EXAMPLES:

To evaluate an expression:
```acl2
(+ 1 2 3)
```

To define and test a function:
```acl2
(defun factorial (n)
  (if (zp n) 1 (* n (factorial (1- n)))))
```

To prove a theorem:
```lisp
(defthm plus-comm
  (equal (+ a b) (+ b a)))
```

I will execute each code block and show you the result. You can then:
- Write more code blocks to continue exploring
- Give a final answer when you have enough information

Be concise. Show your reasoning.")
# Out:
# Summary
# Form:  ( DEFCONST *CODE-AGENT-SYSTEM-PROMPT* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *CODE-AGENT-SYSTEM-PROMPT*

# %% [raw]
# ;;;============================================================================
# ;;; Runtime State - Holds MCP connection alongside agent state
# ;;;============================================================================

# %%
;; Runtime state bundles agent state with MCP connection
;; We use a simple product for now
(fty::defprod runtime-state
  ((agent agent-state-p)
   (mcp-conn t)           ; nil or mcp-connection-p (use t for flexibility)
   (model-id stringp :default ""))
  :layout :list)
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TMP-DEFTYPES-STRINGP-OF-STR-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFUN RUNTIME-STATE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONSP-WHEN-RUNTIME-STATE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO RUNTIME-STATE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN RUNTIME-STATE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM RUNTIME-STATE-P-OF-RUNTIME-STATE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RUNTIME-STATE-P-OF-RUNTIME-STATE-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RUNTIME-STATE-FIX-WHEN-RUNTIME-STATE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS RUNTIME-STATE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO RUNTIME-STATE->AGENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN RUNTIME-STATE->AGENT$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM AGENT-STATE-P-OF-RUNTIME-STATE->AGENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM AGENT-STATE-P-OF-RUNTIME-STATE->AGENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM RUNTIME-STATE->AGENT$INLINE-OF-RUNTIME-STATE-FIX-X
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV RUNTIME-STATE->AGENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO RUNTIME-STATE->MCP-CONN ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN RUNTIME-STATE->MCP-CONN$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM RUNTIME-STATE->MCP-CONN$INLINE-OF-RUNTIME-STATE-FIX-X
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV RUNTIME-STATE->MCP-CONN ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO RUNTIME-STATE->MODEL-ID ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN RUNTIME-STATE->MODEL-ID$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM STRINGP-OF-RUNTIME-STATE->MODEL-ID ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM STRINGP-OF-RUNTIME-STATE->MODEL-ID ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM RUNTIME-STATE->MODEL-ID$INLINE-OF-RUNTIME-STATE-FIX-X
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV RUNTIME-STATE->MODEL-ID ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN RUNTIME-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM RUNTIME-STATE-P-OF-RUNTIME-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RUNTIME-STATE-P-OF-RUNTIME-STATE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM RUNTIME-STATE->AGENT-OF-RUNTIME-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM RUNTIME-STATE->MCP-CONN-OF-RUNTIME-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM RUNTIME-STATE->MODEL-ID-OF-RUNTIME-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM RUNTIME-STATE-OF-FIELDS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM RUNTIME-STATE-FIX-WHEN-RUNTIME-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 5
# Subgoal 5'
# Subgoal 5''
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM EQUAL-OF-RUNTIME-STATE ...)
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Goal'
# Form:  ( DEFTHM RUNTIME-STATE-OF-AGENT-STATE-FIX-AGENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM RUNTIME-STATE-OF-STR-FIX-MODEL-ID ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFMACRO PATBIND-RUNTIME-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-RUNTIME-STATE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-RUNTIME-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-RUNTIME-STATE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RUNTIME-STATE->AGENT-OF-RUNTIME-STATE ...) ...)
# Time:  0.03 seconds (prove: 0.01, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RUNTIME-STATE-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC RUNTIME-STATE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC RUNTIME-STATE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.13 seconds (prove: 0.02, print: 0.00, other: 0.11)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.14 seconds (prove: 0.02, print: 0.00, other: 0.12)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFPROD-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.14 seconds (prove: 0.02, print: 0.00, other: 0.12)
# Prover steps counted:  3752
#  T

# %% [raw]
# ;;;============================================================================
# ;;; Tool Call Parsing
# ;;;============================================================================

# %%
;; Helper: strip leading whitespace characters from list
(defun strip-leading-ws (lst)
  (declare (xargs :mode :program))
  (if (endp lst)
      nil
    (if (member (car lst) '(#\Space #\Tab #\Newline #\Return))
        (strip-leading-ws (cdr lst))
      lst)))
# Out:
# Summary
# Form:  ( DEFUN STRIP-LEADING-WS ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  STRIP-LEADING-WS

# %%
;; Strip leading/trailing whitespace from a string
(defun my-string-trim (str)
  (declare (xargs :mode :program))
  (let* ((chars (coerce str 'list))
         (trimmed (strip-leading-ws chars))
         (rev-trimmed (strip-leading-ws (reverse trimmed))))
    (coerce (reverse rev-trimmed) 'string)))
# Out:
# Summary
# Form:  ( DEFUN MY-STRING-TRIM ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  MY-STRING-TRIM

# %%
;; Extract first code block from LLM response
;; Looks for ```acl2 or ```lisp fenced blocks
;; Returns (mv found? code) where found? indicates if a code block was found
(defun extract-code-block (response)
  (declare (xargs :mode :program))
  (let* (;; Try ```acl2 first
         (acl2-start (search "```acl2" response))
         (lisp-start (search "```lisp" response))
         ;; Use whichever comes first (or exists)
         (start-marker (cond ((and acl2-start lisp-start)
                              (if (< acl2-start lisp-start) "```acl2" "```lisp"))
                             (acl2-start "```acl2")
                             (lisp-start "```lisp")
                             (t nil)))
         (start-pos (cond ((and acl2-start lisp-start)
                           (min acl2-start lisp-start))
                          (acl2-start acl2-start)
                          (lisp-start lisp-start)
                          (t nil))))
    (if (not start-pos)
        (mv nil "")
      ;; Found a code block start - find the content
      (let* ((content-start (+ start-pos (length start-marker)))
             ;; Skip to newline after ```acl2 or ```lisp
             (newline-pos (search (coerce '(#\Newline) 'string) 
                                  (subseq response content-start (length response))))
             (code-start (if newline-pos 
                             (+ content-start newline-pos 1)
                           content-start))
             ;; Find closing ```
             (rest (subseq response code-start (length response)))
             (end-pos (search "```" rest)))
        (if (not end-pos)
            (mv nil "")  ; No closing fence
          (mv t (my-string-trim (subseq rest 0 end-pos))))))))
# Out:
# Summary
# Form:  ( DEFUN EXTRACT-CODE-BLOCK ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  EXTRACT-CODE-BLOCK

# %% [raw]
# ;;;============================================================================
# ;;; Parinfer Integration - Fix Unbalanced Parens in LLM Output
# ;;;============================================================================

# %%
;; Trust tag required for sys-call+ (shell command execution)
(defttag :parinfer)
# Out:
# TTAG NOTE: Adding ttag :PARINFER from the top level loop.
#  :PARINFER

# %%
;; Configuration
(defconst *parinfer-rust-cmd* "parinfer-rust")
(defconst *parinfer-default-mode* "indent")  ; Infer parens from indentation
(defconst *parinfer-lisp-options* "--lisp-block-comments")
# Out:
# Summary
# Form:  ( DEFCONST *PARINFER-RUST-CMD* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *PARINFER-RUST-CMD*
#
# Summary
# Form:  ( DEFCONST *PARINFER-DEFAULT-MODE* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *PARINFER-DEFAULT-MODE*
#
# Summary
# Form:  ( DEFCONST *PARINFER-LISP-OPTIONS* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *PARINFER-LISP-OPTIONS*

# %%
;; Enable/disable parinfer fixing (can be set to nil to disable)
(defconst *use-parinfer* t)
# Out:
# Summary
# Form:  ( DEFCONST *USE-PARINFER* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *USE-PARINFER*

# %%
;; Helper: check paren balance recursively (must be defined before caller)
(defun parens-balanced-aux (chars parens brackets braces)
  (declare (xargs :mode :program))
  (if (endp chars)
      (and (= parens 0) (= brackets 0) (= braces 0))
    (let ((ch (car chars)))
      (cond
        ((eql ch #\() (parens-balanced-aux (cdr chars) (1+ parens) brackets braces))
        ((eql ch #\)) (if (> parens 0)
                          (parens-balanced-aux (cdr chars) (1- parens) brackets braces)
                        nil))
        ((eql ch #\[) (parens-balanced-aux (cdr chars) parens (1+ brackets) braces))
        ((eql ch #\]) (if (> brackets 0)
                          (parens-balanced-aux (cdr chars) parens (1- brackets) braces)
                        nil))
        ((eql ch #\{) (parens-balanced-aux (cdr chars) parens brackets (1+ braces)))
        ((eql ch #\}) (if (> braces 0)
                          (parens-balanced-aux (cdr chars) parens brackets (1- braces))
                        nil))
        (t (parens-balanced-aux (cdr chars) parens brackets braces))))))
# Out:
# Summary
# Form:  ( DEFUN PARENS-BALANCED-AUX ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  PARENS-BALANCED-AUX

# %%
;; Simple paren balance check (doesn't handle strings/comments)
(defun parens-balanced-p (str)
  (declare (xargs :mode :program))
  (parens-balanced-aux (coerce str 'list) 0 0 0))
# Out:
# Summary
# Form:  ( DEFUN PARENS-BALANCED-P ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  PARENS-BALANCED-P

# %%
;; Run parinfer-rust to fix code
;; Returns (mv error-string fixed-code state)
(defun run-parinfer (code state)
  (declare (xargs :mode :program :stobjs state))
  (let* ((temp-in "/tmp/parinfer-input.lisp")
         (temp-out "/tmp/parinfer-output.lisp"))
    (mv-let (channel state)
      (open-output-channel temp-in :character state)
      (if (not channel)
          (mv "Failed to open temp input file" code state)
        (let* ((state (princ$ code channel state))
               (state (close-output-channel channel state))
               (cmd (concatenate 'string 
                                 ". \"$HOME/.cargo/env\" && "
                                 *parinfer-rust-cmd*
                                 " -m " *parinfer-default-mode*
                                 " " *parinfer-lisp-options*
                                 " < " temp-in " > " temp-out " 2>&1")))
          ;; Run command - sys-call+ returns (mv erp val state)
          (mv-let (exit-code cmd-output state)
            (sys-call+ "sh" (list "-c" cmd) state)
            (declare (ignore cmd-output))
            ;; Read output from file - read-file-into-string2 returns just a string (not mv)
            (let ((output (read-file-into-string2 temp-out 0 nil :default state)))
              (if (and (not exit-code) output)
                  (mv nil output state)
                (mv (concatenate 'string "Parinfer failed (exit " 
                                 (coerce (explode-atom (or exit-code -1) 10) 'string) ")")
                    code state)))))))))
# Out:
# Summary
# Form:  ( DEFUN RUN-PARINFER ...)
# Rules: NIL
# Time:  0.08 seconds (prove: 0.00, print: 0.00, other: 0.08)
#  RUN-PARINFER

# %%
;; Fix code using parinfer if enabled and needed
;; Returns (mv was-fixed error fixed-code state)
(defun maybe-fix-code (code state)
  (declare (xargs :mode :program :stobjs state))
  (if (not *use-parinfer*)
      (mv nil nil code state)
    (b* (;; Quick check if parens look balanced (unused but could short-circuit)
         (?looks-ok (parens-balanced-p code))
         ;; Run parinfer regardless to fix structure
         ((mv err fixed state) (run-parinfer code state))
         ((when err)
          ;; Log warning but continue with original code
          (prog2$ (cw "~%[Warning] ~s0~%" err)
                  (mv nil err code state)))
         ;; Check if code changed
         (was-fixed (not (equal (my-string-trim code) (my-string-trim fixed))))
         ;; Log if fixed (use prog2$ since 'when' is not in ACL2)
         (- (if was-fixed
                (cw "~%[Parinfer] Fixed code structure~%")
              nil)))
      (mv was-fixed nil (my-string-trim fixed) state))))
# Out:
# Summary
# Form:  ( DEFUN MAYBE-FIX-CODE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MAYBE-FIX-CODE

# %% [raw]
# ;;;============================================================================
# ;;; Execute Code via MCP
# ;;;============================================================================

# %%
;; Determine what kind of ACL2 form this is and execute appropriately
;; Returns (mv error-string result-string state)
(defun execute-acl2-code (code mcp-conn state)
  (declare (xargs :mode :program :stobjs state))
  (if (not (mcp-connection-p mcp-conn))
      (mv "No MCP connection" "" state)
    ;; Detect form type from code
    (let* ((trimmed (my-string-trim code))
           (is-defun (and (>= (length trimmed) 6)
                          (equal (subseq trimmed 0 6) "(defun")))
           (is-defthm (and (>= (length trimmed) 7)
                           (equal (subseq trimmed 0 7) "(defthm")))
           (is-thm (and (>= (length trimmed) 4)
                        (equal (subseq trimmed 0 4) "(thm"))))
      (cond
        ;; Use admit for defun (test without saving)
        (is-defun
         (mcp-acl2-admit mcp-conn code state))
        ;; Use prove for defthm/thm
        ((or is-defthm is-thm)
         (mcp-acl2-prove mcp-conn code state))
        ;; Default: evaluate expression
        (t
         (mcp-acl2-evaluate mcp-conn code state)))))))))
# Out:
# Summary
# Form:  ( DEFUN EXECUTE-ACL2-CODE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  EXECUTE-ACL2-CODE
#
# ***********************************************
# ************ ABORTING from raw Lisp ***********
# ********** (see :DOC raw-lisp-error) **********
# Error:  unmatched close parenthesis
#
#           Stream: #<SYNONYM-STREAM :SYMBOL SB-SYS:*STDIN* {10000BBCC3}>
# ***********************************************
#
# The message above might explain the error.  If not, and
# if you didn't cause an explicit interrupt (Control-C),
# then it may help to see :DOC raw-lisp-error.
#
# To enable breaks into the debugger (also see :DOC acl2-customization):
# (SET-DEBUGGER-ENABLE T)

# %% [raw]
# ;;;============================================================================
# ;;; Single Agent Step
# ;;;============================================================================

# %%
;; Execute one step of the agent loop:
;; 1. Call LLM with current conversation
;; 2. Parse response for tool call
;; 3. If tool call, execute and add result to conversation
;; 4. Update agent state
;; Returns (mv continue? error runtime-state acl2-state)
;; continue? is T if agent made a tool call, NIL if agent gave final answer
(defun agent-step (rst state)
  (declare (xargs :mode :program :stobjs state))
  (b* ((agent-st (runtime-state->agent rst))
       (mcp-conn (runtime-state->mcp-conn rst))
       (model-id (runtime-state->model-id rst))
       
       ;; Check if agent should continue
       ((when (must-respond-p agent-st))
        (mv nil nil rst state))
       
       ;; Get LLM response
       ((mv llm-err response state)
        (llm-chat-completion model-id (get-messages agent-st) state))
       
       ((when llm-err)
        (mv nil llm-err rst state))
       
       (- (cw "~%Assistant: ~s0~%" response))
       
       ;; Extract code block from response
       ((mv found? code) (extract-code-block response))
       
       ;; Add assistant message to conversation
       (agent-st (add-assistant-msg response agent-st)))
    
    (if (not found?)
        ;; No code block - agent is done, return final response
        (mv nil nil (change-runtime-state rst :agent agent-st) state)
      ;; Fix code using parinfer if needed, then execute
      (b* (;; Apply parinfer to fix any paren issues from LLM
           ((mv was-fixed fix-err fixed-code state) (maybe-fix-code code state))
           (code-to-run (if fix-err code fixed-code))
           ;; Log original and fixed code if changed (use progn$/if since 'when' not in ACL2)
           (- (if was-fixed 
                  (prog2$ (cw "~%[Original code:]~%~s0~%" code)
                          (cw "~%[Fixed code:]~%~s0~%" code-to-run))
                nil))
           (- (cw "~%[Executing ACL2 code:]~%~s0~%" code-to-run))
           ((mv tool-err result state)
            (execute-acl2-code code-to-run mcp-conn state))
           
           (tool-result (if tool-err
                            (concatenate 'string "Error: " tool-err)
                          result))
           (- (cw "~%Result: ~s0~%" 
                  (if (> (length tool-result) 200)
                      (concatenate 'string (subseq tool-result 0 200) "...")
                    tool-result)))
           
           ;; Add tool result to conversation
           (agent-st (add-tool-result tool-result agent-st))
           
           ;; Increment step counter
           (agent-st (increment-step agent-st)))
        ;; Continue since we executed code
        (mv t nil (change-runtime-state rst :agent agent-st) state)))))
# Out:
# Summary
# Form:  ( DEFUN AGENT-STEP ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  AGENT-STEP

# %% [raw]
# ;;;============================================================================
# ;;; Agent Loop
# ;;;============================================================================

# %%
;; Run agent loop until done or max steps
;; Returns (mv error runtime-state acl2-state)
(defun agent-loop (rst max-iterations state)
  (declare (xargs :mode :program :stobjs state))
  (if (zp max-iterations)
      (mv "Max iterations reached" rst state)
    (b* ((agent-st (runtime-state->agent rst))
         ((when (must-respond-p agent-st))
          (mv nil rst state))
         ;; agent-step returns (mv continue? err rst state)
         ((mv continue? err rst state) (agent-step rst state))
         ((when err)
          (mv err rst state))
         ;; If agent didn't make a tool call, it's done
         ((unless continue?)
          (mv nil rst state)))
      (agent-loop rst (1- max-iterations) state))))
# Out:
# Summary
# Form:  ( DEFUN AGENT-LOOP ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  AGENT-LOOP

# %% [raw]
# ;;;============================================================================
# ;;; Main Entry Point
# ;;;============================================================================

# %%
;; Initialize and run the code execution agent
;; Returns (mv error final-runtime-state acl2-state)
(defun run-code-agent (user-query model-id state)
  (declare (xargs :mode :program :stobjs state))
  (b* (;; Connect to MCP server
       (- (cw "~%Connecting to MCP server...~%"))
       ((mv mcp-err mcp-conn state)
        (mcp-connect *mcp-default-endpoint* state))
       
       ((when mcp-err)
        (prog2$ (cw "~%MCP connection failed: ~s0~%" mcp-err)
                (mv mcp-err nil state)))
       
       (- (cw "MCP connected: ~x0~%" mcp-conn))
       
       ;; Create initial agent state with code execution enabled
       (agent-st (make-agent-state
                   :max-steps 20
                   :token-budget 50000
                   :time-budget 3600
                   :file-access 0
                   :execute-allowed t    ; Enable code execution!
                   :max-context-tokens 8000
                   :satisfaction 0))
       
       ;; Initialize conversation
       (agent-st (init-agent-conversation *code-agent-system-prompt* agent-st))
       
       ;; Add user query
       (agent-st (add-user-msg user-query agent-st))
       
       ;; Create runtime state
       (rst (make-runtime-state
              :agent agent-st
              :mcp-conn mcp-conn
              :model-id model-id))
       
       (- (cw "~%Starting agent loop...~%"))
       (- (cw "~%User: ~s0~%" user-query))
       
       ;; Run the agent loop
       ((mv err rst state) (agent-loop rst 10 state)))
    
    (prog2$ (if err
                (cw "~%Agent finished with error: ~s0~%" err)
              (cw "~%Agent completed successfully.~%"))
            (mv err rst state))))
# Out:
# Summary
# Form:  ( DEFUN RUN-CODE-AGENT ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  RUN-CODE-AGENT

# %% [raw]
# ;;;============================================================================
# ;;; Quick Test Macro
# ;;;============================================================================

# %%
;; Usage: (test-code-agent "What is (+ 1 2 3)?" "your-model-id")
(defmacro test-code-agent (query model-id)
  `(make-event
    (mv-let (err rst state)
      (run-code-agent ,query ,model-id state)
      (declare (ignore err rst))
      (mv nil '(value-triple :agent-done) state))))
# Out:
# Summary
# Form:  ( DEFMACRO TEST-CODE-AGENT ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TEST-CODE-AGENT
